# %%
import pandas as pd
import numpy as np
import os

# %%
from datetime import datetime
import pytz
import time

tz = pytz.timezone('Asia/Shanghai')
def ts_to_date(timestamp):
    return datetime.fromtimestamp(timestamp//1000, tz).strftime('%Y-%m-%d')

def time_to_ts(ctime):
    try:
        timeArray = time.strptime(ctime, '%Y-%m-%d %H:%M:%S.%f')
    except:
        timeArray = time.strptime(ctime, '%Y-%m-%d %H:%M:%S')
    return int(time.mktime(timeArray))*1000

# %%
from multiprocessing import Process
import json
        
# log
class LogAnalysis(Process):
    def __init__(self, cases, log_dir, pid, load , anomaly_templates, dataset='gaia'):
        super().__init__()
        self.id = pid
        self.cases = cases.iloc[pid*load: (pid+1)*load]
        self.dataset = dataset
        self.data_dir = log_dir
        self.res = dict(zip(list(self.cases.index), [set() for _ in range(len(self.cases))]))
        self.time_used = 0
        self.anomaly_templates = anomaly_templates
        self.services = [service.split('.')[0] for service in os.listdir(
            self.data_dir) if service.split('.')[-1] == 'csv']
        
    def read_by_service(self, service):
        data = pd.read_csv(os.path.join(self.data_dir, f'{service}.csv'))
        if data['timestamp'].values[0] < 1e12:
            data['timestamp'] *= 1000
        print(data)
        return data
    
    def analysis(self):
        for service in self.services:
            log_data = self.read_by_service(service)
            start_time = time.time()
            for case_id, case in self.cases.iterrows():
                start_ts = time_to_ts(case['start'])
                end_ts = time_to_ts(case['end'])
                sub_data = log_data[(log_data['timestamp']>=start_ts)&(log_data['timestamp']<end_ts)]
#                 print(len(sub_data))
                for _, row in sub_data.iterrows():
                    if row['template_id'] in self.anomaly_templates:
                        self.res[case_id].add(service)
            end_time = time.time()
            self.time_used += (end_time - start_time)
    
    def save_res(self, savepath):
        for key in self.res:
            self.res[key] = list(self.res[key])
        with open(savepath, 'w') as f:
            json.dump(self.res, f)
        print(f'{self.id} Time used: ', self.time_used)
        print('Save successfully!')
    
    def run(self):
        self.analysis()
        self.save_res(f'{self.dataset}/log/{self.dataset}_log_{self.id}.json')
        with open(f'{self.dataset}/log/time_used_{self.id}', 'w') as f:
            f.write(f'{self.time_used}')

# %%
# 配置
log_path = '/home/u2120210568/jupyterfiles/xiasibo/GAIA/data/logs'
label_path = '/home/u2120210568/multi_rca/case/gaia_resplit.csv' # 故障case的路径
demo_labels = pd.read_csv(label_path, index_col=0)
demo_labels = demo_labels[demo_labels['data_type']=='test']
processes = []
# 获取异常模板id
anomaly_templates = []
for _, row in templates.iterrows():
    if row['EventTemplate'] is not np.nan and 'ERROR' in row['EventTemplate']:
        anomaly_templates.append(row['EventId'])
for pid in range(20):
    processes.append(LogAnalysis(demo_labels, log_path, pid, 47, anomaly_templates))
    processes[-1].start()
    print(f'process {pid} starts...')
for pid in range(20):
    processes[pid].join()
    print(f'process {pid} ends.')
# Out:
# process 0 starts...
# process 1 starts...
# process 2 starts...
# process 3 starts...
# process 4 starts...
# process 5 starts...
# process 6 starts...
# process 7 starts...
# process 8 starts...
# process 9 starts...
# process 10 starts...
# process 11 starts...
# process 12 starts...
# process 13 starts...
# process 14 starts...
# process 15 starts...
# process 16 starts...
# process 17 starts...
# process 18 starts...
# process 19 starts...
# 0 Time used:  31.25292706489563
# Save successfully!
# 19 Time used:  38.30712270736694
# Save successfully!
# process 0 ends.
# 2 Time used:  33.56461548805237
# Save successfully!
# 13 Time used:  37.67681074142456
# Save successfully!
# 1 Time used:  41.45724177360535
# Save successfully!
# process 1 ends.
# process 2 ends.
# 16 Time used:  45.684730529785156
# Save successfully!
# 12 Time used:  44.28771781921387
# Save successfully!
# 3 Time used:  44.11557483673096
# Save successfully!
# 7 Time used:  45.50486993789673
# Save successfully!
# process 3 ends.
# 17 Time used:  49.17467164993286
# Save successfully!
# 15 Time used:  47.882484674453735
# Save successfully!
# 14 Time used:  50.08847093582153
# Save successfully!
# 9 Time used:  51.17931938171387
# Save successfully!
# 5 Time used:  50.43928599357605
# Save successfully!
# 8 Time used:  48.825780153274536
# Save successfully!
# 18 Time used:  52.994284868240356
# Save successfully!
# 11 Time used:  54.21292424201965
# Save successfully!
# 6 Time used:  50.19464993476868
# Save successfully!
# 10 Time used:  53.174580335617065
# Save successfully!
# 4 Time used:  58.571579456329346
# Save successfully!
# process 4 ends.
# process 5 ends.
# process 6 ends.
# process 7 ends.
# process 8 ends.
# process 9 ends.
# process 10 ends.
# process 11 ends.
# process 12 ends.
# process 13 ends.
# process 14 ends.
# process 15 ends.
# process 16 ends.
# process 17 ends.
# process 18 ends.
# process 19 ends.

# %%
# 21aiops 日志提取
log_path = '/home/u2120210568/jupyterfiles/xiasibo/GAIA/2021-aiops-lab/log/log_event/logs_data'
label_path = '/home/u2120210568/multi_rca/case/21aiops_resplit.csv' # 故障case的路径
demo_labels = pd.read_csv(label_path, index_col=0)
processes = []
# 获取异常模板id
templates = pd.read_csv('/home/u2120210568/jupyterfiles/xiasibo/GAIA/2021-aiops-lab/log/event.csv')
# templates
anomaly_templates = []
for _, row in templates.iterrows():
    if row['EventTemplate'] is not np.nan and ('error' in row['EventTemplate'].lower() or 'full gc' in 
                                              row['EventTemplate'].lower()):
        anomaly_templates.append(row['EventId'])
        
for pid in range(10):
    processes.append(LogAnalysis(demo_labels[demo_labels['data_type']=='test'], 
                                 log_path, pid, 8, anomaly_templates, '21aiops'))
    processes[-1].start()
    print(f'process {pid} starts...')
for pid in range(10):
    processes[pid].join()
    print(f'process {pid} ends.')
# Out:
# process 0 starts...
# process 1 starts...
# process 2 starts...
# process 3 starts...
# process 4 starts...
# process 5 starts...
# process 6 starts...
# process 7 starts...
# process 8 starts...
# process 9 starts...
# 6 Time used:  3.7700648307800293
# Save successfully!
# 3 Time used:  3.8404808044433594
# Save successfully!
# 1 Time used:  3.9609546661376953
# Save successfully!
# 2 Time used:  4.259798049926758
# Save successfully!
# 9 Time used:  4.153200149536133
# Save successfully!
# 8 Time used:  4.273096561431885
# Save successfully!
# 7 Time used:  4.515991449356079
# Save successfully!
# 4 Time used:  4.68925142288208
# Save successfully!
# 5 Time used:  4.904574632644653
# Save successfully!
# 0 Time used:  5.290997266769409
# Save successfully!
# process 0 ends.
# process 1 ends.
# process 2 ends.
# process 3 ends.
# process 4 ends.
# process 5 ends.
# process 6 ends.
# process 7 ends.
# process 8 ends.
# process 9 ends.

# %%
anomaly_templates
# Out:
# ['401c9a52',
#  '766aa0b9',
#  'a7a05dc2',
#  'c7292f56',
#  '3a0ce66a',
#  'c64fd57a',
#  '67714984',
#  '9b4042ac',
#  'f8850338',
#  '14e0243a',
#  'bc136ae9',
#  'e9280385',
#  'c621672d',
#  '7d387233',
#  'f9c50996',
#  '74e5810b',
#  'e0b38a21',
#  'ee8dd416',
#  '440738bd',
#  '307579ca',
#  '8bd25b3f',
#  'f50e1ae1',
#  '68b99a12',
#  'b3cb8198',
#  '41021fe9',
#  '7a2d7715',
#  '1b19c2eb',
#  '91265f0e',
#  'ef76367a']

# %%
# 22aiops日志模板提取
# 处理日志
log_data = '/Users/fengxiaoyu/Desktop/PDiagnose/template_log_filebeat-testbed-log-service.csv'
df = pd.read_csv(log_data)

# 合并 template_id 和 value 列
df['EventId_EventTemplate'] = df['template_id'].astype(str) + '_' + df['value']

# 计算每个 template_id 的出现次数
template_counts = df['EventId_EventTemplate'].value_counts().reset_index()

# 重命名列名
template_counts.columns = ['EventId_EventTemplate', 'Occurrences']

# 拆分 EventId_EventTemplate 列为 EventId 和 EventTemplate 列
template_counts[['EventId', 'EventTemplate']] = template_counts['EventId_EventTemplate'].str.split('_', n=1, expand=True)

# 重新排列列的顺序并删除不需要的列
template_counts = template_counts[['EventId', 'EventTemplate', 'Occurrences']]

# %%
template_counts
# Out:
#          EventId                                      EventTemplate  \
# 0       0x29d8e8  severity: info, message: conversion request su...
# 1       0x29d8e8  severity: info, message: received conversion r...
# 2       0x79a34c         severity: debug, message: request complete
# 3       0x79a34c          severity: debug, message: request started
# 4       0x19743d  info: Microsoft.AspNet...
# ...          ...                                                ...
# 528722  0x18a1e2  ddItemAsync called with userId=7b7dbd36-9846-4...
# 528723  0x6dc4b1  EVERE: Exception while executing runnable io.g...
# 528724  0x6dc4b1  EVERE: Exception while executing runnable io.g...
# 528725  0x6dc4b1  EVERE: Exception while executing runnable io.g...
# 528726  0x18a1e2  ddItemAsync called with userId=14ec1e6b-9e61-4...
#
#         Occurrences
# 0           2863426
# 1           2863419
# 2           1292178
# 3           1292172
# 4           1239758
# ...             ...
# 528722            1
# 528723            1
# 528724            1
# 528725            1
# 528726            1
#
# [528727 rows x 3 columns]

# %%
import pandas as pd
import os

# 将日志按照cmdb_id分组

def save_by_cmdb_id(file_path, output_dir):
    # 读取 CSV 文件
    data = pd.read_csv(file_path)
    
    # 检查输出目录是否存在，如果不存在，则创建
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    # 按照 'cmdb_id' 列分组
    grouped = data.groupby('cmdb_id')

    # 遍历每个分组
    for name, group in grouped:
        print(group)
        # 将分组数据保存到对应的文件中
        group.to_csv(os.path.join(output_dir, f"{name}.csv"), index=False)

# 使用函数
file_path = '/Users/fengxiaoyu/Desktop/PDiagnose/template_log_filebeat-testbed-log-service.csv'  # CSV文件的路径
output_dir = '/Users/fengxiaoyu/Desktop/PDiagnose/22aiops/log'  # 输出目录的路径
save_by_cmdb_id(file_path, output_dir)
# Out:
#                         log_id   timestamp      cmdb_id  \
# 16        iZ6Bt38B8vQa58bZrQW0  1651507200  adservice-0
# 17        ip6Bt38B8vQa58bZrQW0  1651507200  adservice-0
# 18        jJ6Bt38B8vQa58bZrQW0  1651507200  adservice-0
# 19        m56Bt38B8vQa58bZrQXG  1651507200  adservice-0
# 20        mp6Bt38B8vQa58bZrQXG  1651507200  adservice-0
# ...                        ...         ...          ...
# 11702535  3I7OwX8B8vQa58bZWM4g  1651766397  adservice-0
# 11702536  3Y7OwX8B8vQa58bZWM4g  1651766397  adservice-0
# 11702552  zo7OwX8B8vQa58bZWM4g  1651766397  adservice-0
# 11702553  2o7OwX8B8vQa58bZWM4g  1651766397  adservice-0
# 11702554  y47OwX8B8vQa58bZWM4g  1651766397  adservice-0
#
#                                    log_name  \
# 16        log_adservice-service_application
# 17        log_adservice-service_application
# 18        log_adservice-service_application
# 19        log_adservice-service_application
# 20        log_adservice-service_application
# ...                                     ...
# 11702535  log_adservice-service_application
# 11702536  log_adservice-service_application
# 11702552  log_adservice-service_application
# 11702553  log_adservice-service_application
# 11702554  log_adservice-service_application
#
#                                                       value template_id
# 16        ar 23, 2022 4:00:00 PM io.grpc.internal.Serial...    0x543dec
# 17        EVERE: Exception while executing runnable io.g...    0x6dc4b1
# 18        at hipstershop.AdService.getAdsByCategory(AdSe...    0x6a62be
# 19                 at java.lang.Thread.run(Thread.java:748)    0x6a62be
# 20        at java.util.concurrent.ThreadPoolExecutor$Wor...    0x6a62be
# ...                                                     ...         ...
# 11702535  at java.util.concurrent.ThreadPoolExecutor$Wor...    0x6a62be
# 11702536           at java.lang.Thread.run(Thread.java:748)    0x6a62be
# 11702552  at hipstershop.AdService.getRandomAds(AdServic...    0x6a62be
# 11702553  at io.grpc.internal.SerializingExecutor.run(Se...    0x6a62be
# 11702554  ar 25, 2022 3:59:57 PM io.grpc.internal.Serial...    0x543dec
#
# [2059580 rows x 6 columns]
#                         log_id   timestamp        cmdb_id  \
# 156       0Z6Bt38B8vQa58bZvAZk  1651507204  cartservice-0
# 157       zp6Bt38B8vQa58bZvAZk  1651507204  cartservice-0
# 158       zZ6Bt38B8vQa58bZvAZk  1651507204  cartservice-0
# 159       zJ6Bt38B8vQa58bZvAZk  1651507204  cartservice-0
# 162       y56Bt38B8vQa58bZvAZk  1651507204  cartservice-0
# ...                        ...         ...            ...
# 26029705  CpPOwX8BXUazOxyeWxTS  1651939198  cartservice-0
# 26029710  DpPOwX8BXUazOxyeWxTS  1651939198  cartservice-0
# 26029713  CZPOwX8BXUazOxyeWxTS  1651939198  cartservice-0
# 26029714  DZPOwX8BXUazOxyeWxTS  1651939198  cartservice-0
# 26029715  D5POwX8BXUazOxyeWxTS  1651939198  cartservice-0
#
#                                      log_name  \
# 156       log_cartservice-service_application
# 157       log_cartservice-service_application
# 158       log_cartservice-service_application
# 159       log_cartservice-service_application
# 162       log_cartservice-service_application
# ...                                       ...
# 26029705  log_cartservice-service_application
# 26029710  log_cartservice-service_application
# 26029713  log_cartservice-service_application
# 26029714  log_cartservice-service_application
# 26029715  log_cartservice-service_application
#
#                                                       value template_id
# 156            Request finished in 0.6242ms 200 applicat...    0x59f5c6
# 157       info: Microsoft.AspNet...    0x19743d
# 158       etCartAsync called with userId=27f98443-272d-4...    0x310733
# 159            Executing endpoint 'gRPC - /hipstershop.C...    0xebd4fc
# 162       info: Microsoft.AspNet...    0x19743d
# ...                                                     ...         ...
# 26029705       Request starting HTTP/2 POST http://carts...    0x357c64
# 26029710  info: Microsoft.AspNet...    0x19743d
# 26029713  info: Microsoft.AspNet...    0x19743d
# 26029714  etCartAsync called with userId=1eea59f4-e388-4...    0x310733
# 26029715       Executed endpoint 'gRPC - /hipstershop.Ca...    0xe4cc98
#
# [3720646 rows x 6 columns]
#                         log_id   timestamp        cmdb_id  \
# 76        1J6Bt38B8vQa58bZvAZl  1651507202  cartservice-1
# 77        0p6Bt38B8vQa58bZvAZk  1651507202  cartservice-1
# 81        156Bt38B8vQa58bZvAZl  1651507202  cartservice-1
# 89        2p6Bt38B8vQa58bZvAZl  1651507202  cartservice-1
# 91        1Z6Bt38B8vQa58bZvAZl  1651507202  cartservice-1
# ...                        ...         ...            ...
# 26029712  OpPOwX8BXUazOxyeVxPq  1651939198  cartservice-1
# 26029716  M5POwX8BXUazOxyeVxPq  1651939198  cartservice-1
# 26029718  OJPOwX8BXUazOxyeVxPq  1651939198  cartservice-1
# 26029719  NpPOwX8BXUazOxyeVxPq  1651939198  cartservice-1
# 26029720  NZPOwX8BXUazOxyeVxPq  1651939198  cartservice-1
#
#                                      log_name  \
# 76        log_cartservice-service_application
# 77        log_cartservice-service_application
# 81        log_cartservice-service_application
# 89        log_cartservice-service_application
# 91        log_cartservice-service_application
# ...                                       ...
# 26029712  log_cartservice-service_application
# 26029716  log_cartservice-service_application
# 26029718  log_cartservice-service_application
# 26029719  log_cartservice-service_application
# 26029720  log_cartservice-service_application
#
#                                                       value template_id
# 76        info: Microsoft.AspNet...    0x19743d
# 77        info: Microsoft.AspNet...    0x19743d
# 81        info: Microsoft.AspNet...    0x19743d
# 89             Request finished in 0.6621ms 200 applicat...    0x59f5c6
# 91             Executing endpoint 'gRPC - /hipstershop.C...    0xebd4fc
# ...                                                     ...         ...
# 26029712       Request finished in 0.6187ms 200 applicat...    0x59f5c6
# 26029716       Request starting HTTP/2 POST http://carts...    0x357c64
# 26029718       Executed endpoint 'gRPC - /hipstershop.Ca...    0xe4cc98
# 26029719  etCartAsync called with userId=c5940228-bd63-4...    0x310733
# 26029720       Executing endpoint 'gRPC - /hipstershop.C...    0xebd4fc
#
# [3720579 rows x 6 columns]
#                         log_id   timestamp        cmdb_id  \
# 1         EZ6Bt38B8vQa58bZqQWr  1651507200  cartservice-2
# 2         FZ6Bt38B8vQa58bZqQWr  1651507200  cartservice-2
# 3         Fp6Bt38B8vQa58bZqQWr  1651507200  cartservice-2
# 4         F56Bt38B8vQa58bZqQWr  1651507200  cartservice-2
# 5         GJ6Bt38B8vQa58bZqQWr  1651507200  cartservice-2
# ...                        ...         ...            ...
# 26029747  ipPOwX8BXUazOxyeVxP7  1651939199  cartservice-2
# 26029748  iZPOwX8BXUazOxyeVxP7  1651939199  cartservice-2
# 26029749  iJPOwX8BXUazOxyeVxP7  1651939199  cartservice-2
# 26029750  h5POwX8BXUazOxyeVxP7  1651939199  cartservice-2
# 26029751  HpPOwX8BXUazOxyeWxTS  1651939199  cartservice-2
#
#                                      log_name  \
# 1         log_cartservice-service_application
# 2         log_cartservice-service_application
# 3         log_cartservice-service_application
# 4         log_cartservice-service_application
# 5         log_cartservice-service_application
# ...                                       ...
# 26029747  log_cartservice-service_application
# 26029748  log_cartservice-service_application
# 26029749  log_cartservice-service_application
# 26029750  log_cartservice-service_application
# 26029751  log_cartservice-service_application
#
#                                                       value template_id
# 1              Executing endpoint 'gRPC - /hipstershop.C...    0xebd4fc
# 2         info: Microsoft.AspNet...    0x19743d
# 3              Request finished in 0.6231ms 200 applicat...    0x59f5c6
# 4         info: Microsoft.AspNet...    0x19743d
# 5              Request starting HTTP/2 POST http://carts...    0x357c64
# ...                                                     ...         ...
# 26029747  info: Microsoft.AspNet...    0x19743d
# 26029748       Executed endpoint 'gRPC - /hipstershop.Ca...    0xe4cc98
# 26029749  info: Microsoft.AspNet...    0x19743d
# 26029750  etCartAsync called with userId=e59ed6e2-4167-4...    0x310733
# 26029751  info: Microsoft.AspNet...    0x19743d
#
# [3721082 rows x 6 columns]
#                         log_id   timestamp            cmdb_id  \
# 4117      vp6Dt38B8vQa58bZiixo  1651507320  checkoutservice-0
# 4118      vZ6Dt38B8vQa58bZiixo  1651507320  checkoutservice-0
# 4126      v56Dt38B8vQa58bZiixo  1651507320  checkoutservice-0
# 4148      wJ6Dt38B8vQa58bZiixo  1651507322  checkoutservice-0
# 4149      wp6Dt38B8vQa58bZiixo  1651507322  checkoutservice-0
# ...                        ...         ...                ...
# 26027033  6pLNwX8BXUazOxyeJuog  1651939119  checkoutservice-0
# 26027035  65LNwX8BXUazOxyeJuog  1651939119  checkoutservice-0
# 26027246  tZLNwX8BXUazOxyeQu9X  1651939123  checkoutservice-0
# 26027250  tJLNwX8BXUazOxyeQu9X  1651939123  checkoutservice-0
# 26027251  s5LNwX8BXUazOxyeQu9X  1651939123  checkoutservice-0
#
#                                          log_name  \
# 4117      log_checkoutservice-service_application
# 4118      log_checkoutservice-service_application
# 4126      log_checkoutservice-service_application
# 4148      log_checkoutservice-service_application
# 4149      log_checkoutservice-service_application
# ...                                           ...
# 26027033  log_checkoutservice-service_application
# 26027035  log_checkoutservice-service_application
# 26027246  log_checkoutservice-service_application
# 26027250  log_checkoutservice-service_application
# 26027251  log_checkoutservice-service_application
#
#                                                       value template_id
# 4117      severity: info, message: payment went through ...    0x5f05fb
# 4118      severity: info, message: [PlaceOrder] user_id=...    0x29d8e8
# 4126      severity: info, message: order confirmation em...    0x729fc4
# 4148      severity: info, message: [PlaceOrder] user_id=...    0x29d8e8
# 4149      severity: info, message: order confirmation em...    0x729fc4
# ...                                                     ...         ...
# 26027033  severity: info, message: [PlaceOrder] user_id=...    0x29d8e8
# 26027035  severity: info, message: payment went through ...    0x5f05fb
# 26027246  severity: info, message: order confirmation em...    0x729fc4
# 26027250  severity: info, message: payment went through ...    0x5f05fb
# 26027251  severity: info, message: [PlaceOrder] user_id=...    0x29d8e8
#
# [51569 rows x 6 columns]
#                         log_id   timestamp            cmdb_id  \
# 4065      fZ6Dt38B8vQa58bZpC6b  1651507320  checkoutservice-1
# 4095      fJ6Dt38B8vQa58bZpC6b  1651507320  checkoutservice-1
# 4127      e56Dt38B8vQa58bZpC6b  1651507320  checkoutservice-1
# 4962      N56Dt38B8vQa58bZ3zU0  1651507339  checkoutservice-1
# 5007      Np6Dt38B8vQa58bZ3zU0  1651507339  checkoutservice-1
# ...                        ...         ...                ...
# 26027545  JpLNwX8BXUazOxyeTvFX  1651939128  checkoutservice-1
# 26027546  JJLNwX8BXUazOxyeTvFX  1651939128  checkoutservice-1
# 26027926  gJLNwX8BXUazOxyehPln  1651939140  checkoutservice-1
# 26027952  f5LNwX8BXUazOxyehPln  1651939140  checkoutservice-1
# 26027953  gZLNwX8BXUazOxyehPln  1651939140  checkoutservice-1
#
#                                          log_name  \
# 4065      log_checkoutservice-service_application
# 4095      log_checkoutservice-service_application
# 4127      log_checkoutservice-service_application
# 4962      log_checkoutservice-service_application
# 5007      log_checkoutservice-service_application
# ...                                           ...
# 26027545  log_checkoutservice-service_application
# 26027546  log_checkoutservice-service_application
# 26027926  log_checkoutservice-service_application
# 26027952  log_checkoutservice-service_application
# 26027953  log_checkoutservice-service_application
#
#                                                       value template_id
# 4065      severity: info, message: order confirmation em...    0x729fc4
# 4095      severity: info, message: payment went through ...    0x5f05fb
# 4127      severity: info, message: [PlaceOrder] user_id=...    0x29d8e8
# 4962      severity: info, message: payment went through ...    0x5f05fb
# 5007      severity: info, message: [PlaceOrder] user_id=...    0x29d8e8
# ...                                                     ...         ...
# 26027545  severity: info, message: order confirmation em...    0x729fc4
# 26027546  severity: info, message: [PlaceOrder] user_id=...    0x29d8e8
# 26027926  severity: info, message: payment went through ...    0x5f05fb
# 26027952  severity: info, message: [PlaceOrder] user_id=...    0x29d8e8
# 26027953  severity: info, message: order confirmation em...    0x729fc4
#
# [51557 rows x 6 columns]
#                         log_id   timestamp            cmdb_id  \
# 3994      hp6Dt38B8vQa58bZdSu4  1651507317  checkoutservice-2
# 3995      hZ6Dt38B8vQa58bZdSu4  1651507317  checkoutservice-2
# 3999      hJ6Dt38B8vQa58bZdSu4  1651507317  checkoutservice-2
# 4326      2p6Dt38B8vQa58bZsC9X  1651507327  checkoutservice-2
# 4339      256Dt38B8vQa58bZsC9X  1651507327  checkoutservice-2
# ...                        ...         ...                ...
# 26026487  LZLMwX8BXUazOxye7-L0  1651939105  checkoutservice-2
# 26026488  LJLMwX8BXUazOxye7-L0  1651939105  checkoutservice-2
# 26029231  rJPOwX8BXUazOxyeOQ-O  1651939185  checkoutservice-2
# 26029281  rZPOwX8BXUazOxyeOQ-O  1651939185  checkoutservice-2
# 26029284  q5POwX8BXUazOxyeOQ-O  1651939185  checkoutservice-2
#
#                                          log_name  \
# 3994      log_checkoutservice-service_application
# 3995      log_checkoutservice-service_application
# 3999      log_checkoutservice-service_application
# 4326      log_checkoutservice-service_application
# 4339      log_checkoutservice-service_application
# ...                                           ...
# 26026487  log_checkoutservice-service_application
# 26026488  log_checkoutservice-service_application
# 26029231  log_checkoutservice-service_application
# 26029281  log_checkoutservice-service_application
# 26029284  log_checkoutservice-service_application
#
#                                                       value template_id
# 3994      severity: info, message: order confirmation em...    0x729fc4
# 3995      severity: info, message: payment went through ...    0x5f05fb
# 3999      severity: info, message: [PlaceOrder] user_id=...    0x29d8e8
# 4326      severity: info, message: payment went through ...    0x5f05fb
# 4339      severity: info, message: order confirmation em...    0x729fc4
# ...                                                     ...         ...
# 26026487  severity: info, message: order confirmation em...    0x729fc4
# 26026488  severity: info, message: payment went through ...    0x5f05fb
# 26029231  severity: info, message: payment went through ...    0x5f05fb
# 26029281  severity: info, message: order confirmation em...    0x729fc4
# 26029284  severity: info, message: [PlaceOrder] user_id=...    0x29d8e8
#
# [51563 rows x 6 columns]
#                         log_id   timestamp            cmdb_id  \
# 10        IJ6Bt38B8vQa58bZqQWr  1651507200  currencyservice-0
# 11        IZ6Bt38B8vQa58bZqQWr  1651507200  currencyservice-0
# 60        qZ6Bt38B8vQa58bZrQXG  1651507201  currencyservice-0
# 73        qp6Bt38B8vQa58bZrQXG  1651507201  currencyservice-0
# 82        356Bt38B8vQa58bZsQWd  1651507202  currencyservice-0
# ...                        ...         ...                ...
# 26029642  eJPOwX8BXUazOxyeVxP7  1651939197  currencyservice-0
# 26029643  eZPOwX8BXUazOxyeVxP7  1651939197  currencyservice-0
# 26029675  e5POwX8BXUazOxyeVxP7  1651939197  currencyservice-0
# 26029680  epPOwX8BXUazOxyeVxP7  1651939197  currencyservice-0
# 26029744  GJPOwX8BXUazOxyeWxTS  1651939199  currencyservice-0
#
#                                          log_name  \
# 10        log_currencyservice-service_application
# 11        log_currencyservice-service_application
# 60        log_currencyservice-service_application
# 73        log_currencyservice-service_application
# 82        log_currencyservice-service_application
# ...                                           ...
# 26029642  log_currencyservice-service_application
# 26029643  log_currencyservice-service_application
# 26029675  log_currencyservice-service_application
# 26029680  log_currencyservice-service_application
# 26029744  log_currencyservice-service_application
#
#                                                       value template_id
# 10        severity: info, message: received conversion r...    0x29d8e8
# 11        severity: info, message: conversion request su...    0x29d8e8
# 60        severity: info, message: received conversion r...    0x29d8e8
# 73        severity: info, message: conversion request su...    0x29d8e8
# 82        severity: info, message: conversion request su...    0x29d8e8
# ...                                                     ...         ...
# 26029642  severity: info, message: conversion request su...    0x29d8e8
# 26029643  severity: info, message: Getting supported cur...    0x29d8e8
# 26029675  severity: info, message: conversion request su...    0x29d8e8
# 26029680  severity: info, message: received conversion r...    0x29d8e8
# 26029744  severity: info, message: Getting supported cur...    0x29d8e8
#
# [2270328 rows x 6 columns]
#                         log_id   timestamp            cmdb_id  \
# 14        I56Bt38B8vQa58bZqQWr  1651507200  currencyservice-1
# 44        Ip6Bt38B8vQa58bZqQWr  1651507200  currencyservice-1
# 57        JJ6Bt38B8vQa58bZqQWr  1651507200  currencyservice-1
# 75        rJ6Bt38B8vQa58bZrQXG  1651507202  currencyservice-1
# 88        rp6Bt38B8vQa58bZrQXG  1651507202  currencyservice-1
# ...                        ...         ...                ...
# 26029698  FJPOwX8BXUazOxyeWxTS  1651939198  currencyservice-1
# 26029699  EpPOwX8BXUazOxyeWxTS  1651939198  currencyservice-1
# 26029721  J5POwX8BXUazOxyeXxS8  1651939199  currencyservice-1
# 26029733  JZPOwX8BXUazOxyeXxS8  1651939199  currencyservice-1
# 26029743  JpPOwX8BXUazOxyeXxS8  1651939199  currencyservice-1
#
#                                          log_name  \
# 14        log_currencyservice-service_application
# 44        log_currencyservice-service_application
# 57        log_currencyservice-service_application
# 75        log_currencyservice-service_application
# 88        log_currencyservice-service_application
# ...                                           ...
# 26029698  log_currencyservice-service_application
# 26029699  log_currencyservice-service_application
# 26029721  log_currencyservice-service_application
# 26029733  log_currencyservice-service_application
# 26029743  log_currencyservice-service_application
#
#                                                       value template_id
# 14        severity: info, message: conversion request su...    0x29d8e8
# 44        severity: info, message: received conversion r...    0x29d8e8
# 57        severity: info, message: Getting supported cur...    0x29d8e8
# 75        severity: info, message: conversion request su...    0x29d8e8
# 88        severity: info, message: conversion request su...    0x29d8e8
# ...                                                     ...         ...
# 26029698  severity: info, message: Getting supported cur...    0x29d8e8
# 26029699  severity: info, message: Getting supported cur...    0x29d8e8
# 26029721  severity: info, message: Getting supported cur...    0x29d8e8
# 26029733  severity: info, message: received conversion r...    0x29d8e8
# 26029743  severity: info, message: conversion request su...    0x29d8e8
#
# [2270910 rows x 6 columns]
#                         log_id   timestamp            cmdb_id  \
# 15        Xp6Bt38B8vQa58bZrQW0  1651507200  currencyservice-2
# 31        -p6Bt38B8vQa58bZqQSr  1651507200  currencyservice-2
# 32        -56Bt38B8vQa58bZqQSr  1651507200  currencyservice-2
# 33        _J6Bt38B8vQa58bZqQSr  1651507200  currencyservice-2
# 46        X56Bt38B8vQa58bZrQW0  1651507200  currencyservice-2
# ...                        ...         ...                ...
# 26029696  F5POwX8BXUazOxyeWxTS  1651939198  currencyservice-2
# 26029697  FZPOwX8BXUazOxyeWxTS  1651939198  currencyservice-2
# 26029717  FpPOwX8BXUazOxyeWxTS  1651939198  currencyservice-2
# 26029741  KZPOwX8BXUazOxyeXxS8  1651939199  currencyservice-2
# 26029742  KJPOwX8BXUazOxyeXxS8  1651939199  currencyservice-2
#
#                                          log_name  \
# 15        log_currencyservice-service_application
# 31        log_currencyservice-service_application
# 32        log_currencyservice-service_application
# 33        log_currencyservice-service_application
# 46        log_currencyservice-service_application
# ...                                           ...
# 26029696  log_currencyservice-service_application
# 26029697  log_currencyservice-service_application
# 26029717  log_currencyservice-service_application
# 26029741  log_currencyservice-service_application
# 26029742  log_currencyservice-service_application
#
#                                                       value template_id
# 15        severity: info, message: received conversion r...    0x29d8e8
# 31        severity: info, message: Getting supported cur...    0x29d8e8
# 32        severity: info, message: received conversion r...    0x29d8e8
# 33        severity: info, message: conversion request su...    0x29d8e8
# 46        severity: info, message: conversion request su...    0x29d8e8
# ...                                                     ...         ...
# 26029696  severity: info, message: conversion request su...    0x29d8e8
# 26029697  severity: info, message: conversion request su...    0x29d8e8
# 26029717  severity: info, message: received conversion r...    0x29d8e8
# 26029741  severity: info, message: conversion request su...    0x29d8e8
# 26029742  severity: info, message: received conversion r...    0x29d8e8
#
# [2270599 rows x 6 columns]
#                         log_id   timestamp         cmdb_id  \
# 4005      Y56Dt38B8vQa58bZhixv  1651507317  emailservice-0
# 4174      ZJ6Dt38B8vQa58bZhixv  1651507322  emailservice-0
# 4947      hJ6Dt38B8vQa58bZ6zUV  1651507339  emailservice-0
# 8176      V56Ft38B8vQa58bZXlMU  1651507439  emailservice-0
# 8461      6p6Ft38B8vQa58bZeVSI  1651507446  emailservice-0
# ...                        ...         ...             ...
# 26023610  mZLLwX8BXUazOxyeo7JV  1651939018  emailservice-0
# 26024579  OZLMwX8BXUazOxyeBcGR  1651939044  emailservice-0
# 26026996  TZLNwX8BXUazOxyeKuxn  1651939118  emailservice-0
# 26027940  H5LNwX8BXUazOxyei_q2  1651939140  emailservice-0
# 26029300  GZPOwX8BXUazOxyePRCr  1651939185  emailservice-0
#
#                                       log_name  \
# 4005      log_emailservice-service_application
# 4174      log_emailservice-service_application
# 4947      log_emailservice-service_application
# 8176      log_emailservice-service_application
# 8461      log_emailservice-service_application
# ...                                        ...
# 26023610  log_emailservice-service_application
# 26024579  log_emailservice-service_application
# 26026996  log_emailservice-service_application
# 26027940  log_emailservice-service_application
# 26029300  log_emailservice-service_application
#
#                                                       value template_id
# 4005      severity: INFO, message: A request to send ord...    0x516822
# 4174      severity: INFO, message: A request to send ord...    0x516822
# 4947      severity: INFO, message: A request to send ord...    0x516822
# 8176      severity: INFO, message: A request to send ord...    0x516822
# 8461      severity: INFO, message: A request to send ord...    0x516822
# ...                                                     ...         ...
# 26023610  severity: INFO, message: A request to send ord...    0x516822
# 26024579  severity: INFO, message: A request to send ord...    0x516822
# 26026996  severity: INFO, message: A request to send ord...    0x516822
# 26027940  severity: INFO, message: A request to send ord...    0x516822
# 26029300  severity: INFO, message: A request to send ord...    0x516822
#
# [17274 rows x 6 columns]
#                         log_id   timestamp         cmdb_id  \
# 4114      M56Dt38B8vQa58bZky1b  1651507320  emailservice-1
# 4116      Mp6Dt38B8vQa58bZky1b  1651507320  emailservice-1
# 7517      kp6Ft38B8vQa58bZBUzZ  1651507418  emailservice-1
# 7567      k56Ft38B8vQa58bZBUzZ  1651507420  emailservice-1
# 8790      O56Ft38B8vQa58bZjlcO  1651507455  emailservice-1
# ...                        ...         ...             ...
# 26023036  75LLwX8BXUazOxyecaqY  1651939004  emailservice-1
# 26023313  FJLLwX8BXUazOxyeia_L  1651939012  emailservice-1
# 26024167  C5LLwX8BXUazOxye7r5y  1651939033  emailservice-1
# 26026489  RZLNwX8BXUazOxyeE-ij  1651939105  emailservice-1
# 26027464  J5LNwX8BXUazOxyeTvFX  1651939128  emailservice-1
#
#                                       log_name  \
# 4114      log_emailservice-service_application
# 4116      log_emailservice-service_application
# 7517      log_emailservice-service_application
# 7567      log_emailservice-service_application
# 8790      log_emailservice-service_application
# ...                                        ...
# 26023036  log_emailservice-service_application
# 26023313  log_emailservice-service_application
# 26024167  log_emailservice-service_application
# 26026489  log_emailservice-service_application
# 26027464  log_emailservice-service_application
#
#                                                       value template_id
# 4114      severity: INFO, message: A request to send ord...    0x516822
# 4116      severity: INFO, message: A request to send ord...    0x516822
# 7517      severity: INFO, message: A request to send ord...    0x516822
# 7567      severity: INFO, message: A request to send ord...    0x516822
# 8790      severity: INFO, message: A request to send ord...    0x516822
# ...                                                     ...         ...
# 26023036  severity: INFO, message: A request to send ord...    0x516822
# 26023313  severity: INFO, message: A request to send ord...    0x516822
# 26024167  severity: INFO, message: A request to send ord...    0x516822
# 26026489  severity: INFO, message: A request to send ord...    0x516822
# 26027464  severity: INFO, message: A request to send ord...    0x516822
#
# [17272 rows x 6 columns]
#                         log_id   timestamp         cmdb_id  \
# 4268      e56Dt38B8vQa58bZsDB6  1651507326  emailservice-2
# 4331      fJ6Dt38B8vQa58bZsDB6  1651507327  emailservice-2
# 8332      1p6Ft38B8vQa58bZdFTe  1651507440  emailservice-2
# 11953     wJ6Ht38B8vQa58bZDXZj  1651507547  emailservice-2
# 12085     wZ6Ht38B8vQa58bZDXZj  1651507553  emailservice-2
# ...                        ...         ...             ...
# 26023273  pZLLwX8BXUazOxyega34  1651939011  emailservice-2
# 26026440  X5LMwX8BXUazOxye9-Py  1651939104  emailservice-2
# 26027025  RZLNwX8BXUazOxyeL-2S  1651939119  emailservice-2
# 26027172  RpLNwX8BXUazOxyeL-2S  1651939120  emailservice-2
# 26027284  0pLNwX8BXUazOxyeNe2b  1651939123  emailservice-2
#
#                                       log_name  \
# 4268      log_emailservice-service_application
# 4331      log_emailservice-service_application
# 8332      log_emailservice-service_application
# 11953     log_emailservice-service_application
# 12085     log_emailservice-service_application
# ...                                        ...
# 26023273  log_emailservice-service_application
# 26026440  log_emailservice-service_application
# 26027025  log_emailservice-service_application
# 26027172  log_emailservice-service_application
# 26027284  log_emailservice-service_application
#
#                                                       value template_id
# 4268      severity: INFO, message: A request to send ord...    0x516822
# 4331      severity: INFO, message: A request to send ord...    0x516822
# 8332      severity: INFO, message: A request to send ord...    0x516822
# 11953     severity: INFO, message: A request to send ord...    0x516822
# 12085     severity: INFO, message: A request to send ord...    0x516822
# ...                                                     ...         ...
# 26023273  severity: INFO, message: A request to send ord...    0x516822
# 26026440  severity: INFO, message: A request to send ord...    0x516822
# 26027025  severity: INFO, message: A request to send ord...    0x516822
# 26027172  severity: INFO, message: A request to send ord...    0x516822
# 26027284  severity: INFO, message: A request to send ord...    0x516822
#
# [17520 rows x 6 columns]
#                         log_id   timestamp     cmdb_id  \
# 62        nZ6Bt38B8vQa58bZrQXG  1651507201  frontend-0
# 63        np6Bt38B8vQa58bZrQXG  1651507201  frontend-0
# 68        n56Bt38B8vQa58bZrQXG  1651507201  frontend-0
# 109       JJ6Bt38B8vQa58bZtwZd  1651507203  frontend-0
# 110       Ip6Bt38B8vQa58bZtwZd  1651507203  frontend-0
# ...                        ...         ...         ...
# 26029644  fJPOwX8BXUazOxyeVxP7  1651939197  frontend-0
# 26029664  vJPOwX8BXUazOxyeVBIB  1651939197  frontend-0
# 26029702  f5POwX8BXUazOxyeVxP7  1651939198  frontend-0
# 26029708  fpPOwX8BXUazOxyeVxP7  1651939198  frontend-0
# 26029709  fZPOwX8BXUazOxyeVxP7  1651939198  frontend-0
#
#                                   log_name  \
# 62        log_frontend-service_application
# 63        log_frontend-service_application
# 68        log_frontend-service_application
# 109       log_frontend-service_application
# 110       log_frontend-service_application
# ...                                    ...
# 26029644  log_frontend-service_application
# 26029664  log_frontend-service_application
# 26029702  log_frontend-service_application
# 26029708  log_frontend-service_application
# 26029709  log_frontend-service_application
#
#                                                    value template_id
# 62             severity: debug, message: request started    0x79a34c
# 63        severity: debug, message: serving product page    0x60a8ce
# 68            severity: debug, message: request complete    0x79a34c
# 109           severity: debug, message: request complete    0x79a34c
# 110            severity: debug, message: request started    0x79a34c
# ...                                                  ...         ...
# 26029644      severity: debug, message: request complete    0x79a34c
# 26029664        severity: debug, message: view user cart    0x60a8ce
# 26029702      severity: debug, message: request complete    0x79a34c
# 26029708  severity: debug, message: serving product page    0x60a8ce
# 26029709       severity: debug, message: request started    0x79a34c
#
# [1323058 rows x 6 columns]
#                         log_id   timestamp     cmdb_id  \
# 0         Cp6Bt38B8vQa58bZsQau  1651507200  frontend-1
# 54        CZ6Bt38B8vQa58bZsQau  1651507200  frontend-1
# 55        CJ6Bt38B8vQa58bZsQau  1651507200  frontend-1
# 115       Gp6Bt38B8vQa58bZtwZd  1651507203  frontend-1
# 116       GZ6Bt38B8vQa58bZtwZd  1651507203  frontend-1
# ...                        ...         ...         ...
# 26029686  O5POwX8BXUazOxyeVxPq  1651939197  frontend-1
# 26029687  PZPOwX8BXUazOxyeVxPq  1651939197  frontend-1
# 26029725  dZPOwX8BXUazOxyeZBS_  1651939199  frontend-1
# 26029732  dpPOwX8BXUazOxyeZBS_  1651939199  frontend-1
# 26029738  dJPOwX8BXUazOxyeZBS_  1651939199  frontend-1
#
#                                   log_name  \
# 0         log_frontend-service_application
# 54        log_frontend-service_application
# 55        log_frontend-service_application
# 115       log_frontend-service_application
# 116       log_frontend-service_application
# ...                                    ...
# 26029686  log_frontend-service_application
# 26029687  log_frontend-service_application
# 26029725  log_frontend-service_application
# 26029732  log_frontend-service_application
# 26029738  log_frontend-service_application
#
#                                                    value template_id
# 0             severity: debug, message: request complete    0x79a34c
# 54              severity: debug, message: view user cart    0x60a8ce
# 55             severity: debug, message: request started    0x79a34c
# 115             severity: debug, message: adding to cart    0x60a8ce
# 116            severity: debug, message: request started    0x79a34c
# ...                                                  ...         ...
# 26029686       severity: debug, message: request started    0x79a34c
# 26029687      severity: debug, message: request complete    0x79a34c
# 26029725  severity: debug, message: serving product page    0x60a8ce
# 26029732      severity: debug, message: request complete    0x79a34c
# 26029738       severity: debug, message: request started    0x79a34c
#
# [1335341 rows x 6 columns]
#                         log_id   timestamp     cmdb_id  \
# 29        DZ6Bt38B8vQa58bZqQWr  1651507200  frontend-2
# 30        C56Bt38B8vQa58bZqQWr  1651507200  frontend-2
# 34        Cp6Bt38B8vQa58bZqQWr  1651507200  frontend-2
# 43        DJ6Bt38B8vQa58bZqQWr  1651507200  frontend-2
# 78        EJ6Bt38B8vQa58bZtwZd  1651507202  frontend-2
# ...                        ...         ...         ...
# 26029706  gpPOwX8BXUazOxyeVxP7  1651939198  frontend-2
# 26029707  gJPOwX8BXUazOxyeVxP7  1651939198  frontend-2
# 26029723  GpPOwX8BXUazOxyeWxTS  1651939199  frontend-2
# 26029724  G5POwX8BXUazOxyeWxTS  1651939199  frontend-2
# 26029745  GZPOwX8BXUazOxyeWxTS  1651939199  frontend-2
#
#                                   log_name  \
# 29        log_frontend-service_application
# 30        log_frontend-service_application
# 34        log_frontend-service_application
# 43        log_frontend-service_application
# 78        log_frontend-service_application
# ...                                    ...
# 26029706  log_frontend-service_application
# 26029707  log_frontend-service_application
# 26029723  log_frontend-service_application
# 26029724  log_frontend-service_application
# 26029745  log_frontend-service_application
#
#                                                       value template_id
# 29               severity: debug, message: request complete    0x79a34c
# 30           severity: debug, message: serving product page    0x60a8ce
# 34                severity: debug, message: request started    0x79a34c
# 43        severity: warning, message: failed to retrieve...    0x110723
# 78               severity: debug, message: request complete    0x79a34c
# ...                                                     ...         ...
# 26029706         severity: debug, message: request complete    0x79a34c
# 26029707          severity: debug, message: request started    0x79a34c
# 26029723     severity: debug, message: serving product page    0x60a8ce
# 26029724         severity: debug, message: request complete    0x79a34c
# 26029745          severity: debug, message: request started    0x79a34c
#
# [1375078 rows x 6 columns]
#                         log_id   timestamp           cmdb_id  \
# 7507      ap6Ft38B8vQa58bZBUzZ  1651507418  paymentservice-0
# 7521      a56Ft38B8vQa58bZBUzZ  1651507418  paymentservice-0
# 7593      bZ6Ft38B8vQa58bZBUzZ  1651507420  paymentservice-0
# 7601      bJ6Ft38B8vQa58bZBUzZ  1651507420  paymentservice-0
# 8232      Qp6Ft38B8vQa58bZZlQF  1651507440  paymentservice-0
# ...                        ...         ...               ...
# 26026526  _JLNwX8BXUazOxyeA-S4  1651939105  paymentservice-0
# 26027259  tpLNwX8BXUazOxyePu5R  1651939123  paymentservice-0
# 26027274  tZLNwX8BXUazOxyePu5R  1651939123  paymentservice-0
# 26027910  05LNwX8BXUazOxyedfb_  1651939140  paymentservice-0
# 26027947  0pLNwX8BXUazOxyedfb_  1651939140  paymentservice-0
#
#                                         log_name  \
# 7507      log_paymentservice-service_application
# 7521      log_paymentservice-service_application
# 7593      log_paymentservice-service_application
# 7601      log_paymentservice-service_application
# 8232      log_paymentservice-service_application
# ...                                          ...
# 26026526  log_paymentservice-service_application
# 26027259  log_paymentservice-service_application
# 26027274  log_paymentservice-service_application
# 26027910  log_paymentservice-service_application
# 26027947  log_paymentservice-service_application
#
#                                                       value template_id
# 7507      severity: info, message: PaymentService#Charge...    0x65f886
# 7521      severity: info, message: Transaction processed...    0x3b056f
# 7593      severity: info, message: Transaction processed...    0x3b056f
# 7601      severity: info, message: PaymentService#Charge...    0x65f886
# 8232      severity: info, message: Transaction processed...    0x3b056f
# ...                                                     ...         ...
# 26026526  severity: info, message: PaymentService#Charge...    0x65f886
# 26027259  severity: info, message: Transaction processed...    0x3b056f
# 26027274  severity: info, message: PaymentService#Charge...    0x65f886
# 26027910  severity: info, message: Transaction processed...    0x3b056f
# 26027947  severity: info, message: PaymentService#Charge...    0x65f886
#
# [34370 rows x 6 columns]
#                         log_id   timestamp           cmdb_id  \
# 3986      Zp6Dt38B8vQa58bZhixv  1651507317  paymentservice-1
# 3990      ZZ6Dt38B8vQa58bZhixv  1651507317  paymentservice-1
# 4042      aZ6Dt38B8vQa58bZhixv  1651507320  paymentservice-1
# 4084      ap6Dt38B8vQa58bZhixv  1651507320  paymentservice-1
# 4085      aJ6Dt38B8vQa58bZhixv  1651507320  paymentservice-1
# ...                        ...         ...               ...
# 26026986  Q5LNwX8BXUazOxyeOu5p  1651939118  paymentservice-1
# 26027080  RZLNwX8BXUazOxyeOu5p  1651939120  paymentservice-1
# 26027150  RpLNwX8BXUazOxyeOu5p  1651939120  paymentservice-1
# 26029232  gJPOwX8BXUazOxyeNA_k  1651939185  paymentservice-1
# 26029285  gZPOwX8BXUazOxyeNA_k  1651939185  paymentservice-1
#
#                                         log_name  \
# 3986      log_paymentservice-service_application
# 3990      log_paymentservice-service_application
# 4042      log_paymentservice-service_application
# 4084      log_paymentservice-service_application
# 4085      log_paymentservice-service_application
# ...                                          ...
# 26026986  log_paymentservice-service_application
# 26027080  log_paymentservice-service_application
# 26027150  log_paymentservice-service_application
# 26029232  log_paymentservice-service_application
# 26029285  log_paymentservice-service_application
#
#                                                       value template_id
# 3986      severity: info, message: Transaction processed...    0x3b056f
# 3990      severity: info, message: PaymentService#Charge...    0x65f886
# 4042      severity: info, message: PaymentService#Charge...    0x65f886
# 4084      severity: info, message: Transaction processed...    0x3b056f
# 4085      severity: info, message: Transaction processed...    0x3b056f
# ...                                                     ...         ...
# 26026986  severity: info, message: PaymentService#Charge...    0x65f886
# 26027080  severity: info, message: PaymentService#Charge...    0x65f886
# 26027150  severity: info, message: Transaction processed...    0x3b056f
# 26029232  severity: info, message: PaymentService#Charge...    0x65f886
# 26029285  severity: info, message: Transaction processed...    0x3b056f
#
# [34359 rows x 6 columns]
#                         log_id   timestamp           cmdb_id  \
# 4168      RJ6Dt38B8vQa58bZgiyH  1651507322  paymentservice-2
# 4191      Q56Dt38B8vQa58bZgiyH  1651507322  paymentservice-2
# 4272      KZ6Dt38B8vQa58bZny7O  1651507326  paymentservice-2
# 4280      KJ6Dt38B8vQa58bZny7O  1651507326  paymentservice-2
# 4325      K56Dt38B8vQa58bZny7O  1651507327  paymentservice-2
# ...                        ...         ...               ...
# 26026463  UpLMwX8BXUazOxye8OIM  1651939104  paymentservice-2
# 26027031  MJLNwX8BXUazOxyeL-2S  1651939119  paymentservice-2
# 26027058  L5LNwX8BXUazOxyeL-2S  1651939119  paymentservice-2
# 26027436  WpLNwX8BXUazOxyeRvBv  1651939128  paymentservice-2
# 26027489  WZLNwX8BXUazOxyeRvBv  1651939128  paymentservice-2
#
#                                         log_name  \
# 4168      log_paymentservice-service_application
# 4191      log_paymentservice-service_application
# 4272      log_paymentservice-service_application
# 4280      log_paymentservice-service_application
# 4325      log_paymentservice-service_application
# ...                                          ...
# 26026463  log_paymentservice-service_application
# 26027031  log_paymentservice-service_application
# 26027058  log_paymentservice-service_application
# 26027436  log_paymentservice-service_application
# 26027489  log_paymentservice-service_application
#
#                                                       value template_id
# 4168      severity: info, message: Transaction processed...    0x3b056f
# 4191      severity: info, message: PaymentService#Charge...    0x65f886
# 4272      severity: info, message: Transaction processed...    0x3b056f
# 4280      severity: info, message: PaymentService#Charge...    0x65f886
# 4325      severity: info, message: Transaction processed...    0x3b056f
# ...                                                     ...         ...
# 26026463  severity: info, message: Transaction processed...    0x3b056f
# 26027031  severity: info, message: Transaction processed...    0x3b056f
# 26027058  severity: info, message: PaymentService#Charge...    0x65f886
# 26027436  severity: info, message: Transaction processed...    0x3b056f
# 26027489  severity: info, message: PaymentService#Charge...    0x65f886
#
# [34363 rows x 6 columns]
#                         log_id   timestamp                  cmdb_id  \
# 2850122   1RXGun8B8vQa58bZ6Rgk  1651562065  productcatalogservice-0
# 2850123   1xXGun8B8vQa58bZ6Rgk  1651562065  productcatalogservice-0
# 2850124   2RXGun8B8vQa58bZ6Rgk  1651562065  productcatalogservice-0
# 2850311   IBXHun8B8vQa58bZlRrZ  1651562114  productcatalogservice-0
# 2850312   IhXHun8B8vQa58bZlRrZ  1651562114  productcatalogservice-0
# ...                        ...         ...                      ...
# 20557260  7JL8vH8BXUazOxye9xSs  1651858358  productcatalogservice-0
# 20557936  8pL-vH8BXUazOxyeahrm  1651858455  productcatalogservice-0
# 20557939  75L-vH8BXUazOxyeahrm  1651858455  productcatalogservice-0
# 20557941  8JL-vH8BXUazOxyeahrm  1651858455  productcatalogservice-0
# 20557942  8ZL-vH8BXUazOxyeahrm  1651858455  productcatalogservice-0
#
#                                                log_name  \
# 2850122   log_productcatalogservice-service_application
# 2850123   log_productcatalogservice-service_application
# 2850124   log_productcatalogservice-service_application
# 2850311   log_productcatalogservice-service_application
# 2850312   log_productcatalogservice-service_application
# ...                                                 ...
# 20557260  log_productcatalogservice-service_application
# 20557936  log_productcatalogservice-service_application
# 20557939  log_productcatalogservice-service_application
# 20557941  log_productcatalogservice-service_application
# 20557942  log_productcatalogservice-service_application
#
#                                                       value template_id
# 2850122   severity: warning, message: failed to query pr...    0x4aa889
# 2850123   severity: warning, message: failed to query pr...    0x4aa889
# 2850124   severity: warning, message: failed to query pr...    0x4aa889
# 2850311   severity: warning, message: failed to query pr...    0x4aa889
# 2850312   severity: warning, message: failed to query pr...    0x4aa889
# ...                                                     ...         ...
# 20557260  severity: warning, message: failed to query pr...    0x4fd1de
# 20557936  severity: warning, message: failed to query pr...    0x4fd1de
# 20557939  severity: warning, message: failed to query pr...    0x4fd1de
# 20557941  severity: warning, message: failed to query pr...    0x4fd1de
# 20557942  severity: warning, message: failed to query pr...    0x4fd1de
#
# [337 rows x 6 columns]
#                         log_id   timestamp                  cmdb_id  \
# 2850127   2hXGun8B8vQa58bZ6Rgk  1651562066  productcatalogservice-1
# 2850128   1hXGun8B8vQa58bZ6Rgk  1651562066  productcatalogservice-1
# 2850129   2BXGun8B8vQa58bZ6Rgk  1651562066  productcatalogservice-1
# 2850467   EBXIun8B8vQa58bZ0Rxu  1651562190  productcatalogservice-1
# 2850523   pRXJun8B8vQa58bZCBw9  1651562202  productcatalogservice-1
# ...                        ...         ...                      ...
# 20557905  8JL-vH8BXUazOxyeThmf  1651858453  productcatalogservice-1
# 20557911  9ZL-vH8BXUazOxyeThmf  1651858453  productcatalogservice-1
# 20557912  9JL-vH8BXUazOxyeThmf  1651858453  productcatalogservice-1
# 20557913  85L-vH8BXUazOxyeThmf  1651858453  productcatalogservice-1
# 20557919  8pL-vH8BXUazOxyeThmf  1651858453  productcatalogservice-1
#
#                                                log_name  \
# 2850127   log_productcatalogservice-service_application
# 2850128   log_productcatalogservice-service_application
# 2850129   log_productcatalogservice-service_application
# 2850467   log_productcatalogservice-service_application
# 2850523   log_productcatalogservice-service_application
# ...                                                 ...
# 20557905  log_productcatalogservice-service_application
# 20557911  log_productcatalogservice-service_application
# 20557912  log_productcatalogservice-service_application
# 20557913  log_productcatalogservice-service_application
# 20557919  log_productcatalogservice-service_application
#
#                                                       value template_id
# 2850127   severity: warning, message: failed to query pr...    0x4aa889
# 2850128   severity: warning, message: failed to query pr...    0x4aa889
# 2850129   severity: warning, message: failed to query pr...    0x4aa889
# 2850467   022/03/24 07:16:30 failed to upload traces; HT...    0x8af3c5
# 2850523   severity: warning, message: failed to query pr...    0x4aa889
# ...                                                     ...         ...
# 20557905  severity: warning, message: failed to query pr...    0x4aa889
# 20557911  severity: warning, message: failed to query pr...    0x4aa889
# 20557912  severity: warning, message: failed to query pr...    0x4aa889
# 20557913  severity: warning, message: failed to query pr...    0x4aa889
# 20557919  severity: warning, message: failed to query pr...    0x4aa889
#
# [72 rows x 6 columns]
#                         log_id   timestamp                  cmdb_id  \
# 2850119   xBXGun8B8vQa58bZwhgU  1651562056  productcatalogservice-2
# 2850120   xRXGun8B8vQa58bZwhgU  1651562056  productcatalogservice-2
# 2850121   xhXGun8B8vQa58bZwhgU  1651562056  productcatalogservice-2
# ...
# 2850119   log_productcatalogservice-service_application
# 2850120   log_productcatalogservice-service_application
# 2850121   log_productcatalogservice-service_application
# 2850267   log_productcatalogservice-service_application
# 2850268   log_productcatalogservice-service_application
# ...                                                 ...
# 20557666  log_productcatalogservice-service_application
# 20557669  log_productcatalogservice-service_application
# 20557670  log_productcatalogservice-service_application
# 20557671  log_productcatalogservice-service_application
# 20557924  log_productcatalogservice-service_application
#
#                                                       value template_id
# 2850119   mysql] 2022/03/24 07:14:16 packets.go:37: unex...    0x3ba2aa
# 2850120   mysql] 2022/03/24 07:14:16 packets.go:37: unex...    0x3ba2aa
# 2850121   mysql] 2022/03/24 07:14:16 packets.go:37: unex...    0x3ba2aa
# 2850267   severity: warning, message: failed to query pr...    0x4aa889
# 2850268   severity: warning, message: failed to query pr...    0x4aa889
# ...                                                     ...         ...
# 20557666  severity: warning, message: failed to query pr...    0x4fd1de
# 20557669  severity: warning, message: failed to query pr...    0x4fd1de
# 20557670  severity: warning, message: failed to query pr...    0x4fd1de
# 20557671  severity: warning, message: failed to query pr...    0x4fd1de
# 20557924  severity: warning, message: failed to query pr...    0x4fd1de
#
# [84 rows x 6 columns]
#                         log_id   timestamp                  cmdb_id  \
# 45        KJ6Bt38B8vQa58bZqQW8  1651507200  recommendationservice-0
# 277       cJ6Bt38B8vQa58bZxQck  1651507207  recommendationservice-0
# 335       uJ6Bt38B8vQa58bZyQcl  1651507208  recommendationservice-0
# 1169      9Z6Ct38B8vQa58bZLRCN  1651507224  recommendationservice-0
# 1373      956Ct38B8vQa58bZLRCN  1651507230  recommendationservice-0
# ...                        ...         ...                      ...
# 26029470  EpPOwX8BXUazOxyeRxFA  1651939192  recommendationservice-0
# 26029558  pJPOwX8BXUazOxyeSxEo  1651939194  recommendationservice-0
# 26029591  o5POwX8BXUazOxyeSxEo  1651939194  recommendationservice-0
# 26029689  gZPOwX8BXUazOxyeZBS_  1651939198  recommendationservice-0
# 26029695  gpPOwX8BXUazOxyeZBS_  1651939198  recommendationservice-0
#
#                                                log_name  \
# 45        log_recommendationservice-service_application
# 277       log_recommendationservice-service_application
# 335       log_recommendationservice-service_application
# 1169      log_recommendationservice-service_application
# 1373      log_recommendationservice-service_application
# ...                                                 ...
# 26029470  log_recommendationservice-service_application
# 26029558  log_recommendationservice-service_application
# 26029591  log_recommendationservice-service_application
# 26029689  log_recommendationservice-service_application
# 26029695  log_recommendationservice-service_application
#
#                                                       value template_id
# 45        severity: INFO, message: [Recv ListRecommendat...    0x51b371
# 277       severity: INFO, message: [Recv ListRecommendat...    0x51b371
# 335       severity: INFO, message: [Recv ListRecommendat...    0x51b371
# 1169      severity: INFO, message: [Recv ListRecommendat...    0x51b371
# 1373      severity: INFO, message: [Recv ListRecommendat...    0x51b371
# ...                                                     ...         ...
# 26029470  severity: INFO, message: [Recv ListRecommendat...    0x51b371
# 26029558  severity: INFO, message: [Recv ListRecommendat...    0x51b371
# 26029591  severity: INFO, message: [Recv ListRecommendat...    0x51b371
# 26029689  severity: INFO, message: [Recv ListRecommendat...    0x51b371
# 26029695  severity: INFO, message: [Recv ListRecommendat...    0x51b371
#
# [310020 rows x 6 columns]
#                         log_id   timestamp                  cmdb_id  \
# 74        4J6Bt38B8vQa58bZsQWd  1651507201  recommendationservice-1
# 153       GJ6Bt38B8vQa58bZtwZd  1651507204  recommendationservice-1
# 289       4J6Bt38B8vQa58bZ0wf8  1651507208  recommendationservice-1
# 1193      C56Ct38B8vQa58bZCw95  1651507224  recommendationservice-1
# 1254      DJ6Ct38B8vQa58bZCw95  1651507226  recommendationservice-1
# ...                        ...         ...                      ...
# 26029452  r5POwX8BXUazOxyeQhBK  1651939191  recommendationservice-1
# 26029507  EZPOwX8BXUazOxyeRxFA  1651939193  recommendationservice-1
# 26029601  MJPOwX8BXUazOxyeXxS8  1651939196  recommendationservice-1
# 26029663  MZPOwX8BXUazOxyeXxS8  1651939197  recommendationservice-1
# 26029752  MpPOwX8BXUazOxyeXxS8  1651939199  recommendationservice-1
#
#                                                log_name  \
# 74        log_recommendationservice-service_application
# 153       log_recommendationservice-service_application
# 289       log_recommendationservice-service_application
# 1193      log_recommendationservice-service_application
# 1254      log_recommendationservice-service_application
# ...                                                 ...
# 26029452  log_recommendationservice-service_application
# 26029507  log_recommendationservice-service_application
# 26029601  log_recommendationservice-service_application
# 26029663  log_recommendationservice-service_application
# 26029752  log_recommendationservice-service_application
#
#                                                       value template_id
# 74        severity: INFO, message: [Recv ListRecommendat...    0x51b371
# 153       severity: INFO, message: [Recv ListRecommendat...    0x51b371
# 289       severity: INFO, message: [Recv ListRecommendat...    0x51b371
# 1193      severity: INFO, message: [Recv ListRecommendat...    0x51b371
# 1254      severity: INFO, message: [Recv ListRecommendat...    0x51b371
# ...                                                     ...         ...
# 26029452  severity: INFO, message: [Recv ListRecommendat...    0x51b371
# 26029507  severity: INFO, message: [Recv ListRecommendat...    0x51b371
# 26029601  severity: INFO, message: [Recv ListRecommendat...    0x51b371
# 26029663  severity: INFO, message: [Recv ListRecommendat...    0x51b371
# 26029752  severity: INFO, message: [Recv ListRecommendat...    0x51b371
#
# [310407 rows x 6 columns]
#                         log_id   timestamp                  cmdb_id  \
# 27        Jp6Bt38B8vQa58bZqQW8  1651507200  recommendationservice-2
# 198       bp6Bt38B8vQa58bZxQck  1651507206  recommendationservice-2
# 270       b56Bt38B8vQa58bZxQck  1651507207  recommendationservice-2
# 1163      WZ6Ct38B8vQa58bZKBCu  1651507224  recommendationservice-2
# 1305      Wp6Ct38B8vQa58bZKBCu  1651507226  recommendationservice-2
# ...                        ...         ...                      ...
# 26029437  GpPOwX8BXUazOxyePRCr  1651939191  recommendationservice-2
# 26029501  opPOwX8BXUazOxyeSxEo  1651939193  recommendationservice-2
# 26029628  tpPOwX8BXUazOxyeVBIB  1651939196  recommendationservice-2
# 26029665  t5POwX8BXUazOxyeVBIB  1651939197  recommendationservice-2
# 26029739  NJPOwX8BXUazOxyeXxS8  1651939199  recommendationservice-2
#
#                                                log_name  \
# 27        log_recommendationservice-service_application
# 198       log_recommendationservice-service_application
# 270       log_recommendationservice-service_application
# 1163      log_recommendationservice-service_application
# 1305      log_recommendationservice-service_application
# ...                                                 ...
# 26029437  log_recommendationservice-service_application
# 26029501  log_recommendationservice-service_application
# 26029628  log_recommendationservice-service_application
# 26029665  log_recommendationservice-service_application
# 26029739  log_recommendationservice-service_application
#
#                                                       value template_id
# 27        severity: INFO, message: [Recv ListRecommendat...    0x51b371
# 198       severity: INFO, message: [Recv ListRecommendat...    0x51b371
# 270       severity: INFO, message: [Recv ListRecommendat...    0x51b371
# 1163      severity: INFO, message: [Recv ListRecommendat...    0x51b371
# 1305      severity: INFO, message: [Recv ListRecommendat...    0x51b371
# ...                                                     ...         ...
# 26029437  severity: INFO, message: [Recv ListRecommendat...    0x51b371
# 26029501  severity: INFO, message: [Recv ListRecommendat...    0x51b371
# 26029628  severity: INFO, message: [Recv ListRecommendat...    0x51b371
# 26029665  severity: INFO, message: [Recv ListRecommendat...    0x51b371
# 26029739  severity: INFO, message: [Recv ListRecommendat...    0x51b371
#
# [309975 rows x 6 columns]
#                         log_id   timestamp            cmdb_id  \
# 12        t56Bt38B8vQa58bZsQWd  1651507200  shippingservice-0
# 56        uJ6Bt38B8vQa58bZsQWd  1651507200  shippingservice-0
# 2896      CZ6Ct38B8vQa58bZ_iEK  1651507282  shippingservice-0
# 2935      CJ6Ct38B8vQa58bZ_iEK  1651507282  shippingservice-0
# 3063      Cp6Ct38B8vQa58bZ_iEK  1651507285  shippingservice-0
# ...                        ...         ...                ...
# 26029487  x5POwX8BXUazOxyeQhBK  1651939192  shippingservice-0
# 26029660  KpPOwX8BXUazOxyeXxS8  1651939197  shippingservice-0
# 26029661  LJPOwX8BXUazOxyeXxS8  1651939197  shippingservice-0
# 26029662  LZPOwX8BXUazOxyeXxS8  1651939197  shippingservice-0
# 26029666  K5POwX8BXUazOxyeXxS8  1651939197  shippingservice-0
#
#                                          log_name  \
# 12        log_shippingservice-service_application
# 56        log_shippingservice-service_application
# 2896      log_shippingservice-service_application
# 2935      log_shippingservice-service_application
# 3063      log_shippingservice-service_application
# ...                                           ...
# 26029487  log_shippingservice-service_application
# 26029660  log_shippingservice-service_application
# 26029661  log_shippingservice-service_application
# 26029662  log_shippingservice-service_application
# 26029666  log_shippingservice-service_application
#
#                                                       value template_id
# 12        severity: info, message: [GetQuote] received r...    0x29d8e8
# 56        severity: info, message: [GetQuote] completed ...    0x29d8e8
# 2896      severity: info, message: [GetQuote] completed ...    0x29d8e8
# 2935      severity: info, message: [GetQuote] received r...    0x29d8e8
# 3063      severity: info, message: [GetQuote] received r...    0x29d8e8
# ...                                                     ...         ...
# 26029487  severity: info, message: [GetQuote] received r...    0x29d8e8
# 26029660  severity: info, message: [GetQuote] received r...    0x29d8e8
# 26029661  severity: info, message: [GetQuote] received r...    0x29d8e8
# 26029662  severity: info, message: [GetQuote] completed ...    0x29d8e8
# 26029666  severity: info, message: [GetQuote] completed ...    0x29d8e8
#
# [240610 rows x 6 columns]
#                         log_id   timestamp            cmdb_id  \
# 338       C56Bt38B8vQa58bZ3AmW  1651507208  shippingservice-1
# 339       Cp6Bt38B8vQa58bZ3AmW  1651507208  shippingservice-1
# 2902      TJ6Dt38B8vQa58bZAiHT  1651507282  shippingservice-1
# 2907      S56Dt38B8vQa58bZAiHT  1651507282  shippingservice-1
# 2954      Tp6Dt38B8vQa58bZAiHT  1651507283  shippingservice-1
# ...                        ...         ...                ...
# 26029238  zZPOwX8BXUazOxyeKQ4J  1651939185  shippingservice-1
# 26029311  FZPOwX8BXUazOxyeLA_x  1651939186  shippingservice-1
# 26029327  FJPOwX8BXUazOxyeLA_x  1651939186  shippingservice-1
# 26029615  2pPOwX8BXUazOxyeZBTc  1651939196  shippingservice-1
# 26029620  25POwX8BXUazOxyeZBTc  1651939196  shippingservice-1
#
#                                          log_name  \
# 338       log_shippingservice-service_application
# 339       log_shippingservice-service_application
# 2902      log_shippingservice-service_application
# 2907      log_shippingservice-service_application
# 2954      log_shippingservice-service_application
# ...                                           ...
# 26029238  log_shippingservice-service_application
# 26029311  log_shippingservice-service_application
# 26029327  log_shippingservice-service_application
# 26029615  log_shippingservice-service_application
# 26029620  log_shippingservice-service_application
#
#                                                       value template_id
# 338       severity: info, message: [GetQuote] completed ...    0x29d8e8
# 339       severity: info, message: [GetQuote] received r...    0x29d8e8
# 2902      severity: info, message: [GetQuote] completed ...    0x29d8e8
# 2907      severity: info, message: [GetQuote] received r...    0x29d8e8
# 2954      severity: info, message: [GetQuote] completed ...    0x29d8e8
# ...                                                     ...         ...
# 26029238  severity: info, message: [ShipOrder] completed...    0x29d8e8
# 26029311  severity: info, message: [GetQuote] completed ...    0x29d8e8
# 26029327  severity: info, message: [GetQuote] received r...    0x29d8e8
# 26029615  severity: info, message: [GetQuote] received r...    0x29d8e8
# 26029620  severity: info, message: [GetQuote] completed ...    0x29d8e8
#
# [240598 rows x 6 columns]
#                         log_id   timestamp            cmdb_id  \
# 160       2p6Bt38B8vQa58bZzAf1  1651507204  shippingservice-2
# 161       256Bt38B8vQa58bZzAf1  1651507204  shippingservice-2
# 3124      wZ6Dt38B8vQa58bZGyPc  1651507287  shippingservice-2
# 3131      wp6Dt38B8vQa58bZGyPc  1651507287  shippingservice-2
# 3184      xJ6Dt38B8vQa58bZGyPc  1651507288  shippingservice-2
# ...                        ...         ...                ...
# 26028832  PpPNwX8BXUazOxye5AZ-  1651939168  shippingservice-2
# 26029020  lZPOwX8BXUazOxyeHA1G  1651939176  shippingservice-2
# 26029028  lJPOwX8BXUazOxyeHA1G  1651939176  shippingservice-2
# 26029566  jJPOwX8BXUazOxyeVxP7  1651939194  shippingservice-2
# 26029567  jZPOwX8BXUazOxyeVxP7  1651939194  shippingservice-2
#
#                                          log_name  \
# 160       log_shippingservice-service_application
# 161       log_shippingservice-service_application
# 3124      log_shippingservice-service_application
# 3131      log_shippingservice-service_application
# 3184      log_shippingservice-service_application
# ...                                           ...
# 26028832  log_shippingservice-service_application
# 26029020  log_shippingservice-service_application
# 26029028  log_shippingservice-service_application
# 26029566  log_shippingservice-service_application
# 26029567  log_shippingservice-service_application
#
#                                                       value template_id
# 160       severity: info, message: [GetQuote] received r...    0x29d8e8
# 161       severity: info, message: [GetQuote] completed ...    0x29d8e8
# 3124      severity: info, message: [GetQuote] received r...    0x29d8e8
# 3131      severity: info, message: [GetQuote] completed ...    0x29d8e8
# 3184      severity: info, message: [GetQuote] completed ...    0x29d8e8
# ...                                                     ...         ...
# 26028832  severity: info, message: [GetQuote] received r...    0x29d8e8
# 26029020  severity: info, message: [GetQuote] completed ...    0x29d8e8
# 26029028  severity: info, message: [GetQuote] received r...    0x29d8e8
# 26029566  severity: info, message: [GetQuote] received r...    0x29d8e8
# 26029567  severity: info, message: [GetQuote] completed ...    0x29d8e8
#
# [240602 rows x 6 columns]

# %%
import os
import pandas as pd
import time
import json

from datetime import datetime
import pytz
import time

tz = pytz.timezone('Asia/Shanghai')
def ts_to_date(timestamp):
    return datetime.fromtimestamp(timestamp//1000, tz).strftime('%Y-%m-%d')

def time_to_ts(ctime):
    try:
        # 先尝试解析包含小时和分钟的格式
        timeArray = time.strptime(ctime, '%Y/%m/%d %H:%M')
    except ValueError:
        try:
            # 如果失败，尝试只有日期的格式
            timeArray = time.strptime(ctime, '%Y/%m/%d')
        except ValueError:
            # 如果仍然失败，记录错误或返回一个默认值
            print(f"Failed to parse date: {ctime}")
            return None
    return int(time.mktime(timeArray))*1000

class LogAnalysis:
    def __init__(self, cases, log_dir, pid, load , anomaly_templates, dataset='gaia'):
        self.id = pid
        self.cases = cases.iloc[pid*load: (pid+1)*load]
        self.dataset = dataset
        self.data_dir = log_dir
        self.res = dict(zip(list(self.cases.index), [set() for _ in range(len(self.cases))]))
        self.time_used = 0
        self.anomaly_templates = anomaly_templates
        self.services = [service.split('.')[0] for service in os.listdir(
            self.data_dir) if service.split('.')[-1] == 'csv']
        
    def read_by_service(self, service):
        data = pd.read_csv(os.path.join(self.data_dir, f'{service}.csv'))
        if data['timestamp'].values[0] < 1e12:
            data['timestamp'] *= 1000
        return data
    
    def analysis(self):
        for service in self.services:
            log_data = self.read_by_service(service)
            start_time = time.time()
            print(self.cases)
            for case_id, case in self.cases.iterrows():
                start_ts = time_to_ts(case['start'])
                end_ts = time_to_ts(case['end'])
                sub_data = log_data[(log_data['timestamp']>=start_ts)&(log_data['timestamp']<end_ts)]
                for _, row in sub_data.iterrows():
                    if row['template_id'] in self.anomaly_templates:
                        self.res[case_id].add(service)
            end_time = time.time()
            self.time_used += (end_time - start_time)
    
    def save_res(self, savepath):
        for key in self.res:
            self.res[key] = list(self.res[key])
        with open(savepath, 'w') as f:
            json.dump(self.res, f)
        print(f'{self.id} Time used: ', self.time_used)
        print('Save successfully!')


import pandas as pd
import numpy as np

# 加载数据
log_path = '/Users/fengxiaoyu/Desktop/PDiagnose/22aiops/log'
label_path = '/Users/fengxiaoyu/Desktop/PDiagnose/22AIOps_run_table.csv'
demo_labels = pd.read_csv(label_path, index_col=0)
processes = []
# 获取异常模板id
# templates
anomaly_templates = []
for _, row in template_counts.iterrows():
    if row['EventTemplate'] is not np.nan and ('error' in row['EventTemplate'].lower()):
        anomaly_templates.append(row['EventId'])
        
# 只创建一个实例
pid = 0
load = len(demo_labels)
analyzer = LogAnalysis(demo_labels[(demo_labels['type'] == 'test') & (demo_labels['level'] == 'pod')], log_path, pid, load, anomaly_templates, '22aiops')
analyzer.analysis()
analyzer.save_res(f'{analyzer.dataset}/log/{analyzer.dataset}_log_{analyzer.id}.json')
# Out:
#       timestamp level                   cmdb_id failure_type           start  \
# 80   1651366271   pod         checkoutservice-0   k8s容器cpu负载   2022/5/1 8:51
# 135  1651379795   pod   productcatalogservice-2    k8s容器进程中止  2022/5/1 12:36
# 121  1651382580   pod                frontend-0   k8s容器写io负载  2022/5/1 13:23
# 84   1651398576   pod                frontend-0   k8s容器cpu负载  2022/5/1 17:49
# 86   1651407633   pod         shippingservice-0   k8s容器cpu负载  2022/5/1 20:20
# 64   1651564006   pod         shippingservice-1    k8s容器内存负载  2022/5/3 15:46
# 126  1651692556   pod   productcatalogservice-0   k8s容器写io负载   2022/5/5 3:29
# 111  1651716458   pod   recommendationservice-2   k8s容器读io负载  2022/5/5 10:07
# 129  1651920562   pod               adservice-0   k8s容器写io负载  2022/5/7 18:49
# 95   1652032391   pod         shippingservice-1   k8s容器cpu负载   2022/5/9 1:53
# 132  1652060333   pod  recommendationservice2-0   k8s容器写io负载   2022/5/9 9:39
# 120  1652089514   pod               adservice-1   k8s容器读io负载  2022/5/9 17:45
#
#                 end  type
# 80    2022/5/1 8:58  test
# 135  2022/5/1 12:42  test
# 121  2022/5/1 13:30  test
# 84   2022/5/1 17:55  test
# 86   2022/5/1 20:26  test
# 64   2022/5/3 15:54  test
# 126   2022/5/5 3:33  test
# 111  2022/5/5 10:14  test
# 129  2022/5/7 18:52  test
# 95    2022/5/9 2:01  test
# 132   2022/5/9 9:44  test
# 120  2022/5/9 17:52  test
#       timestamp level                   cmdb_id failure_type           start  \
# 80   1651366271   pod         checkoutservice-0   k8s容器cpu负载   2022/5/1 8:51
# 135  1651379795   pod   productcatalogservice-2    k8s容器进程中止  2022/5/1 12:36
# 121  1651382580   pod                frontend-0   k8s容器写io负载  2022/5/1 13:23
# 84   1651398576   pod                frontend-0   k8s容器cpu负载  2022/5/1 17:49
# 86   1651407633   pod         shippingservice-0   k8s容器cpu负载  2022/5/1 20:20
# 64   1651564006   pod         shippingservice-1    k8s容器内存负载  2022/5/3 15:46
# 126  1651692556   pod   productcatalogservice-0   k8s容器写io负载   2022/5/5 3:29
# 111  1651716458   pod   recommendationservice-2   k8s容器读io负载  2022/5/5 10:07
# 129  1651920562   pod               adservice-0   k8s容器写io负载  2022/5/7 18:49
# 95   1652032391   pod         shippingservice-1   k8s容器cpu负载   2022/5/9 1:53
# 132  1652060333   pod  recommendationservice2-0   k8s容器写io负载   2022/5/9 9:39
# 120  1652089514   pod               adservice-1   k8s容器读io负载  2022/5/9 17:45
#
#                 end  type
# 80    2022/5/1 8:58  test
# 135  2022/5/1 12:42  test
# 121  2022/5/1 13:30  test
# 84   2022/5/1 17:55  test
# 86   2022/5/1 20:26  test
# 64   2022/5/3 15:54  test
# 126   2022/5/5 3:33  test
# 111  2022/5/5 10:14  test
# 129  2022/5/7 18:52  test
# 95    2022/5/9 2:01  test
# 132   2022/5/9 9:44  test
# 120  2022/5/9 17:52  test
#       timestamp level                   cmdb_id failure_type           start  \
# 80   1651366271   pod         checkoutservice-0   k8s容器cpu负载   2022/5/1 8:51
# 135  1651379795   pod   productcatalogservice-2    k8s容器进程中止  2022/5/1 12:36
# 121  1651382580   pod                frontend-0   k8s容器写io负载  2022/5/1 13:23
# 84   1651398576   pod                frontend-0   k8s容器cpu负载  2022/5/1 17:49
# 86   1651407633   pod         shippingservice-0   k8s容器cpu负载  2022/5/1 20:20
# 64   1651564006   pod         shippingservice-1    k8s容器内存负载  2022/5/3 15:46
# 126  1651692556   pod   productcatalogservice-0   k8s容器写io负载   2022/5/5 3:29
# 111  1651716458   pod   recommendationservice-2   k8s容器读io负载  2022/5/5 10:07
# 129  1651920562   pod               adservice-0   k8s容器写io负载  2022/5/7 18:49
# 95   1652032391   pod         shippingservice-1   k8s容器cpu负载   2022/5/9 1:53
# 132  1652060333   pod  recommendationservice2-0   k8s容器写io负载   2022/5/9 9:39
# 120  1652089514   pod               adservice-1   k8s容器读io负载  2022/5/9 17:45
#
#                 end  type
# 80    2022/5/1 8:58  test
# 135  2022/5/1 12:42  test
# 121  2022/5/1 13:30  test
# 84   2022/5/1 17:55  test
# 86   2022/5/1 20:26  test
# 64   2022/5/3 15:54  test
# 126   2022/5/5 3:33  test
# 111  2022/5/5 10:14  test
# 129  2022/5/7 18:52  test
# 95    2022/5/9 2:01  test
# 132   2022/5/9 9:44  test
# 120  2022/5/9 17:52  test
#       timestamp level                   cmdb_id failure_type           start  \
# 80   1651366271   pod         checkoutservice-0   k8s容器cpu负载   2022/5/1 8:51
# 135  1651379795   pod   productcatalogservice-2    k8s容器进程中止  2022/5/1 12:36
# 121  1651382580   pod                frontend-0   k8s容器写io负载  2022/5/1 13:23
# 84   1651398576   pod                frontend-0   k8s容器cpu负载  2022/5/1 17:49
# 86   1651407633   pod         shippingservice-0   k8s容器cpu负载  2022/5/1 20:20
# 64   1651564006   pod         shippingservice-1    k8s容器内存负载  2022/5/3 15:46
# 126  1651692556   pod   productcatalogservice-0   k8s容器写io负载   2022/5/5 3:29
# 111  1651716458   pod   recommendationservice-2   k8s容器读io负载  2022/5/5 10:07
# 129  1651920562   pod               adservice-0   k8s容器写io负载  2022/5/7 18:49
# 95   1652032391   pod         shippingservice-1   k8s容器cpu负载   2022/5/9 1:53
# 132  1652060333   pod  recommendationservice2-0   k8s容器写io负载   2022/5/9 9:39
# 120  1652089514   pod               adservice-1   k8s容器读io负载  2022/5/9 17:45
#
#                 end  type
# 80    2022/5/1 8:58  test
# 135  2022/5/1 12:42  test
# 121  2022/5/1 13:30  test
# 84   2022/5/1 17:55  test
# 86   2022/5/1 20:26  test
# 64   2022/5/3 15:54  test
# 126   2022/5/5 3:33  test
# 111  2022/5/5 10:14  test
# 129  2022/5/7 18:52  test
# 95    2022/5/9 2:01  test
# 132   2022/5/9 9:44  test
# 120  2022/5/9 17:52  test
#       timestamp level                   cmdb_id failure_type           start  \
# 80   1651366271   pod         checkoutservice-0   k8s容器cpu负载   2022/5/1 8:51
# 135  1651379795   pod   productcatalogservice-2    k8s容器进程中止  2022/5/1 12:36
# 121  1651382580   pod                frontend-0   k8s容器写io负载  2022/5/1 13:23
# 84   1651398576   pod                frontend-0   k8s容器cpu负载  2022/5/1 17:49
# 86   1651407633   pod         shippingservice-0   k8s容器cpu负载  2022/5/1 20:20
# 64   1651564006   pod         shippingservice-1    k8s容器内存负载  2022/5/3 15:46
# 126  1651692556   pod   productcatalogservice-0   k8s容器写io负载   2022/5/5 3:29
# 111  1651716458   pod   recommendationservice-2   k8s容器读io负载  2022/5/5 10:07
# 129  1651920562   pod               adservice-0   k8s容器写io负载  2022/5/7 18:49
# 95   1652032391   pod         shippingservice-1   k8s容器cpu负载   2022/5/9 1:53
# 132  1652060333   pod  recommendationservice2-0   k8s容器写io负载   2022/5/9 9:39
# 120  1652089514   pod               adservice-1   k8s容器读io负载  2022/5/9 17:45
#
#                 end  type
# 80    2022/5/1 8:58  test
# 135  2022/5/1 12:42  test
# 121  2022/5/1 13:30  test
# 84   2022/5/1 17:55  test
# 86   2022/5/1 20:26  test
# 64   2022/5/3 15:54  test
# 126   2022/5/5 3:33  test
# 111  2022/5/5 10:14  test
# 129  2022/5/7 18:52  test
# 95    2022/5/9 2:01  test
# 132   2022/5/9 9:44  test
# 120  2022/5/9 17:52  test
#       timestamp level                   cmdb_id failure_type           start  \
# 80   1651366271   pod         checkoutservice-0   k8s容器cpu负载   2022/5/1 8:51
# 135  1651379795   pod   productcatalogservice-2    k8s容器进程中止  2022/5/1 12:36
# 121  1651382580   pod                frontend-0   k8s容器写io负载  2022/5/1 13:23
# 84   1651398576   pod                frontend-0   k8s容器cpu负载  2022/5/1 17:49
# 86   1651407633   pod         shippingservice-0   k8s容器cpu负载  2022/5/1 20:20
# 64   1651564006   pod         shippingservice-1    k8s容器内存负载  2022/5/3 15:46
# 126  1651692556   pod   productcatalogservice-0   k8s容器写io负载   2022/5/5 3:29
# 111  1651716458   pod   recommendationservice-2   k8s容器读io负载  2022/5/5 10:07
# 129  1651920562   pod               adservice-0   k8s容器写io负载  2022/5/7 18:49
# 95   1652032391   pod         shippingservice-1   k8s容器cpu负载   2022/5/9 1:53
# 132  1652060333   pod  recommendationservice2-0   k8s容器写io负载   2022/5/9 9:39
# 120  1652089514   pod               adservice-1   k8s容器读io负载  2022/5/9 17:45
#
#                 end  type
# 80    2022/5/1 8:58  test
# 135  2022/5/1 12:42  test
# 121  2022/5/1 13:30  test
# 84   2022/5/1 17:55  test
# 86   2022/5/1 20:26  test
# 64   2022/5/3 15:54  test
# 126   2022/5/5 3:33  test
# 111  2022/5/5 10:14  test
# 129  2022/5/7 18:52  test
# 95    2022/5/9 2:01  test
# 132   2022/5/9 9:44  test
# 120  2022/5/9 17:52  test
#       timestamp level                   cmdb_id failure_type           start  \
# 80   1651366271   pod         checkoutservice-0   k8s容器cpu负载   2022/5/1 8:51
# 135  1651379795   pod   productcatalogservice-2    k8s容器进程中止  2022/5/1 12:36
# 121  1651382580   pod                frontend-0   k8s容器写io负载  2022/5/1 13:23
# 84   1651398576   pod                frontend-0   k8s容器cpu负载  2022/5/1 17:49
# 86   1651407633   pod         shippingservice-0   k8s容器cpu负载  2022/5/1 20:20
# 64   1651564006   pod         shippingservice-1    k8s容器内存负载  2022/5/3 15:46
# 126  1651692556   pod   productcatalogservice-0   k8s容器写io负载   2022/5/5 3:29
# 111  1651716458   pod   recommendationservice-2   k8s容器读io负载  2022/5/5 10:07
# 129  1651920562   pod               adservice-0   k8s容器写io负载  2022/5/7 18:49
# 95   1652032391   pod         shippingservice-1   k8s容器cpu负载   2022/5/9 1:53
# 132  1652060333   pod  recommendationservice2-0   k8s容器写io负载   2022/5/9 9:39
# 120  1652089514   pod               adservice-1   k8s容器读io负载  2022/5/9 17:45
#
#                 end  type
# 80    2022/5/1 8:58  test
# 135  2022/5/1 12:42  test
# 121  2022/5/1 13:30  test
# 84   2022/5/1 17:55  test
# 86   2022/5/1 20:26  test
# 64   2022/5/3 15:54  test
# 126   2022/5/5 3:33  test
# 111  2022/5/5 10:14  test
# 129  2022/5/7 18:52  test
# 95    2022/5/9 2:01  test
# 132   2022/5/9 9:44  test
# 120  2022/5/9 17:52  test
#       timestamp level                   cmdb_id failure_type           start  \
# 80   1651366271   pod         checkoutservice-0   k8s容器cpu负载   2022/5/1 8:51
# 135  1651379795   pod   productcatalogservice-2    k8s容器进程中止  2022/5/1 12:36
# 121  1651382580   pod                frontend-0   k8s容器写io负载  2022/5/1 13:23
# 84   1651398576   pod                frontend-0   k8s容器cpu负载  2022/5/1 17:49
# 86   1651407633   pod         shippingservice-0   k8s容器cpu负载  2022/5/1 20:20
# 64   1651564006   pod         shippingservice-1    k8s容器内存负载  2022/5/3 15:46
# 126  1651692556   pod   productcatalogservice-0   k8s容器写io负载   2022/5/5 3:29
# 111  1651716458   pod   recommendationservice-2   k8s容器读io负载  2022/5/5 10:07
# 129  1651920562   pod               adservice-0   k8s容器写io负载  2022/5/7 18:49
# 95   1652032391   pod         shippingservice-1   k8s容器cpu负载   2022/5/9 1:53
# 132  1652060333   pod  recommendationservice2-0   k8s容器写io负载   2022/5/9 9:39
# 120  1652089514   pod               adservice-1   k8s容器读io负载  2022/5/9 17:45
#
#                 end  type
# 80    2022/5/1 8:58  test
# 135  2022/5/1 12:42  test
# 121  2022/5/1 13:30  test
# 84   2022/5/1 17:55  test
# 86   2022/5/1 20:26  test
# 64   2022/5/3 15:54  test
# 126   2022/5/5 3:33  test
# 111  2022/5/5 10:14  test
# 129  2022/5/7 18:52  test
# 95    2022/5/9 2:01  test
# 132   2022/5/9 9:44  test
# 120  2022/5/9 17:52  test
#       timestamp level                   cmdb_id failure_type           start  \
# 80   1651366271   pod         checkoutservice-0   k8s容器cpu负载   2022/5/1 8:51
# 135  1651379795   pod   productcatalogservice-2    k8s容器进程中止  2022/5/1 12:36
# 121  1651382580   pod                frontend-0   k8s容器写io负载  2022/5/1 13:23
# 84   1651398576   pod                frontend-0   k8s容器cpu负载  2022/5/1 17:49
# 86   1651407633   pod         shippingservice-0   k8s容器cpu负载  2022/5/1 20:20
# 64   1651564006   pod         shippingservice-1    k8s容器内存负载  2022/5/3 15:46
# 126  1651692556   pod   productcatalogservice-0   k8s容器写io负载   2022/5/5 3:29
# 111  1651716458   pod   recommendationservice-2   k8s容器读io负载  2022/5/5 10:07
# 129  1651920562   pod               adservice-0   k8s容器写io负载  2022/5/7 18:49
# 95   1652032391   pod         shippingservice-1   k8s容器cpu负载   2022/5/9 1:53
# 132  1652060333   pod  recommendationservice2-0   k8s容器写io负载   2022/5/9 9:39
# 120  1652089514   pod               adservice-1   k8s容器读io负载  2022/5/9 17:45
#
#                 end  type
# 80    2022/5/1 8:58  test
# 135  2022/5/1 12:42  test
# 121  2022/5/1 13:30  test
# 84   2022/5/1 17:55  test
# 86   2022/5/1 20:26  test
# 64   2022/5/3 15:54  test
# 126   2022/5/5 3:33  test
# 111  2022/5/5 10:14  test
# 129  2022/5/7 18:52  test
# 95    2022/5/9 2:01  test
# 132   2022/5/9 9:44  test
# 120  2022/5/9 17:52  test
#       timestamp level                   cmdb_id failure_type           start  \
# 80   1651366271   pod         checkoutservice-0   k8s容器cpu负载   2022/5/1 8:51
# 135  1651379795   pod   productcatalogservice-2    k8s容器进程中止  2022/5/1 12:36
# 121  1651382580   pod                frontend-0   k8s容器写io负载  2022/5/1 13:23
# 84   1651398576   pod                frontend-0   k8s容器cpu负载  2022/5/1 17:49
# 86   1651407633   pod         shippingservice-0   k8s容器cpu负载  2022/5/1 20:20
# 64   1651564006   pod         shippingservice-1    k8s容器内存负载  2022/5/3 15:46
# 126  1651692556   pod   productcatalogservice-0   k8s容器写io负载   2022/5/5 3:29
# 111  1651716458   pod   recommendationservice-2   k8s容器读io负载  2022/5/5 10:07
# 129  1651920562   pod               adservice-0   k8s容器写io负载  2022/5/7 18:49
# 95   1652032391   pod         shippingservice-1   k8s容器cpu负载   2022/5/9 1:53
# 132  1652060333   pod  recommendationservice2-0   k8s容器写io负载   2022/5/9 9:39
# 120  1652089514   pod               adservice-1   k8s容器读io负载  2022/5/9 17:45
#
#                 end  type
# 80    2022/5/1 8:58  test
# 135  2022/5/1 12:42  test
# 121  2022/5/1 13:30  test
# 84   2022/5/1 17:55  test
# 86   2022/5/1 20:26  test
# 64   2022/5/3 15:54  test
# 126   2022/5/5 3:33  test
# 111  2022/5/5 10:14  test
# 129  2022/5/7 18:52  test
# 95    2022/5/9 2:01  test
# 132   2022/5/9 9:44  test
# 120  2022/5/9 17:52  test
#       timestamp level                   cmdb_id failure_type           start  \
# 80   1651366271   pod         checkoutservice-0   k8s容器cpu负载   2022/5/1 8:51
# 135  1651379795   pod   productcatalogservice-2    k8s容器进程中止  2022/5/1 12:36
# 121  1651382580   pod                frontend-0   k8s容器写io负载  2022/5/1 13:23
# 84   1651398576   pod                frontend-0   k8s容器cpu负载  2022/5/1 17:49
# 86   1651407633   pod         shippingservice-0   k8s容器cpu负载  2022/5/1 20:20
# 64   1651564006   pod         shippingservice-1    k8s容器内存负载  2022/5/3 15:46
# 126  1651692556   pod   productcatalogservice-0   k8s容器写io负载   2022/5/5 3:29
# 111  1651716458   pod   recommendationservice-2   k8s容器读io负载  2022/5/5 10:07
# 129  1651920562   pod               adservice-0   k8s容器写io负载  2022/5/7 18:49
# 95   1652032391   pod         shippingservice-1   k8s容器cpu负载   2022/5/9 1:53
# 132  1652060333   pod  recommendationservice2-0   k8s容器写io负载   2022/5/9 9:39
# 120  1652089514   pod               adservice-1   k8s容器读io负载  2022/5/9 17:45
#
#                 end  type
# 80    2022/5/1 8:58  test
# 135  2022/5/1 12:42  test
# 121  2022/5/1 13:30  test
# 84   2022/5/1 17:55  test
# 86   2022/5/1 20:26  test
# 64   2022/5/3 15:54  test
# 126   2022/5/5 3:33  test
# 111  2022/5/5 10:14  test
# 129  2022/5/7 18:52  test
# 95    2022/5/9 2:01  test
# 132   2022/5/9 9:44  test
# 120  2022/5/9 17:52  test
#       timestamp level                   cmdb_id failure_type           start  \
# 80   1651366271   pod         checkoutservice-0   k8s容器cpu负载   2022/5/1 8:51
# 135  1651379795   pod   productcatalogservice-2    k8s容器进程中止  2022/5/1 12:36
# 121  1651382580   pod                frontend-0   k8s容器写io负载  2022/5/1 13:23
# 84   1651398576   pod                frontend-0   k8s容器cpu负载  2022/5/1 17:49
# 86   1651407633   pod         shippingservice-0   k8s容器cpu负载  2022/5/1 20:20
# 64   1651564006   pod         shippingservice-1    k8s容器内存负载  2022/5/3 15:46
# 126  1651692556   pod   productcatalogservice-0   k8s容器写io负载   2022/5/5 3:29
# 111  1651716458   pod   recommendationservice-2   k8s容器读io负载  2022/5/5 10:07
# 129  1651920562   pod               adservice-0   k8s容器写io负载  2022/5/7 18:49
# 95   1652032391   pod         shippingservice-1   k8s容器cpu负载   2022/5/9 1:53
# 132  1652060333   pod  recommendationservice2-0   k8s容器写io负载   2022/5/9 9:39
# 120  1652089514   pod               adservice-1   k8s容器读io负载  2022/5/9 17:45
#
#                 end  type
# 80    2022/5/1 8:58  test
# 135  2022/5/1 12:42  test
# 121  2022/5/1 13:30  test
# 84   2022/5/1 17:55  test
# 86   2022/5/1 20:26  test
# 64   2022/5/3 15:54  test
# 126   2022/5/5 3:33  test
# 111  2022/5/5 10:14  test
# 129  2022/5/7 18:52  test
# 95    2022/5/9 2:01  test
# 132   2022/5/9 9:44  test
# 120  2022/5/9 17:52  test
#       timestamp level                   cmdb_id failure_type           start  \
# 80   1651366271   pod         checkoutservice-0   k8s容器cpu负载   2022/5/1 8:51
# 135  1651379795   pod   productcatalogservice-2    k8s容器进程中止  2022/5/1 12:36
# 121  1651382580   pod                frontend-0   k8s容器写io负载  2022/5/1 13:23
# 84   1651398576   pod                frontend-0   k8s容器cpu负载  2022/5/1 17:49
# 86   1651407633   pod         shippingservice-0   k8s容器cpu负载  2022/5/1 20:20
# 64   1651564006   pod         shippingservice-1    k8s容器内存负载  2022/5/3 15:46
# 126  1651692556   pod   productcatalogservice-0   k8s容器写io负载   2022/5/5 3:29
# 111  1651716458   pod   recommendationservice-2   k8s容器读io负载  2022/5/5 10:07
# 129  1651920562   pod               adservice-0   k8s容器写io负载  2022/5/7 18:49
# 95   1652032391   pod         shippingservice-1   k8s容器cpu负载   2022/5/9 1:53
# 132  1652060333   pod  recommendationservice2-0   k8s容器写io负载   2022/5/9 9:39
# 120  1652089514   pod               adservice-1   k8s容器读io负载  2022/5/9 17:45
#
#                 end  type
# 80    2022/5/1 8:58  test
# 135  2022/5/1 12:42  test
# 121  2022/5/1 13:30  test
# 84   2022/5/1 17:55  test
# 86   2022/5/1 20:26  test
# 64   2022/5/3 15:54  test
# 126   2022/5/5 3:33  test
# 111  2022/5/5 10:14  test
# 129  2022/5/7 18:52  test
# 95    2022/5/9 2:01  test
# 132   2022/5/9 9:44  test
# 120  2022/5/9 17:52  test
#       timestamp level                   cmdb_id failure_type           start  \
# 80   1651366271   pod         checkoutservice-0   k8s容器cpu负载   2022/5/1 8:51
# 135  1651379795   pod   productcatalogservice-2    k8s容器进程中止  2022/5/1 12:36
# 121  1651382580   pod                frontend-0   k8s容器写io负载  2022/5/1 13:23
# 84   1651398576   pod                frontend-0   k8s容器cpu负载  2022/5/1 17:49
# 86   1651407633   pod         shippingservice-0   k8s容器cpu负载  2022/5/1 20:20
# 64   1651564006   pod         shippingservice-1    k8s容器内存负载  2022/5/3 15:46
# 126  1651692556   pod   productcatalogservice-0   k8s容器写io负载   2022/5/5 3:29
# 111  1651716458   pod   recommendationservice-2   k8s容器读io负载  2022/5/5 10:07
# 129  1651920562   pod               adservice-0   k8s容器写io负载  2022/5/7 18:49
# 95   1652032391   pod         shippingservice-1   k8s容器cpu负载   2022/5/9 1:53
# 132  1652060333   pod  recommendationservice2-0   k8s容器写io负载   2022/5/9 9:39
# 120  1652089514   pod               adservice-1   k8s容器读io负载  2022/5/9 17:45
#
#                 end  type
# 80    2022/5/1 8:58  test
# 135  2022/5/1 12:42  test
# 121  2022/5/1 13:30  test
# 84   2022/5/1 17:55  test
# 86   2022/5/1 20:26  test
# 64   2022/5/3 15:54  test
# 126   2022/5/5 3:33  test
# 111  2022/5/5 10:14  test
# 129  2022/5/7 18:52  test
# 95    2022/5/9 2:01  test
# 132   2022/5/9 9:44  test
# 120  2022/5/9 17:52  test
#       timestamp level                   cmdb_id failure_type           start  \
# 80   1651366271   pod         checkoutservice-0   k8s容器cpu负载   2022/5/1 8:51
# 135  1651379795   pod   productcatalogservice-2    k8s容器进程中止  2022/5/1 12:36
# 121  1651382580   pod                frontend-0   k8s容器写io负载  2022/5/1 13:23
# 84   1651398576   pod                frontend-0   k8s容器cpu负载  2022/5/1 17:49
# 86   1651407633   pod         shippingservice-0   k8s容器cpu负载  2022/5/1 20:20
# 64   1651564006   pod         shippingservice-1    k8s容器内存负载  2022/5/3 15:46
# 126  1651692556   pod   productcatalogservice-0   k8s容器写io负载   2022/5/5 3:29
# 111  1651716458   pod   recommendationservice-2   k8s容器读io负载  2022/5/5 10:07
# 129  1651920562   pod               adservice-0   k8s容器写io负载  2022/5/7 18:49
# 95   1652032391   pod         shippingservice-1   k8s容器cpu负载   2022/5/9 1:53
# 132  1652060333   pod  recommendationservice2-0   k8s容器写io负载   2022/5/9 9:39
# 120  1652089514   pod               adservice-1   k8s容器读io负载  2022/5/9 17:45
#
#                 end  type
# 80    2022/5/1 8:58  test
# 135  2022/5/1 12:42  test
# 121  2022/5/1 13:30  test
# 84   2022/5/1 17:55  test
# 86   2022/5/1 20:26  test
# 64   2022/5/3 15:54  test
# 126   2022/5/5 3:33  test
# 111  2022/5/5 10:14  test
# 129  2022/5/7 18:52  test
# 95    2022/5/9 2:01  test
# 132   2022/5/9 9:44  test
# 120  2022/5/9 17:52  test
#       timestamp level                   cmdb_id failure_type           start  \
# 80   1651366271   pod         checkoutservice-0   k8s容器cpu负载   2022/5/1 8:51
# 135  1651379795   pod   productcatalogservice-2    k8s容器进程中止  2022/5/1 12:36
# 121  1651382580   pod                frontend-0   k8s容器写io负载  2022/5/1 13:23
# 84   1651398576   pod                frontend-0   k8s容器cpu负载  2022/5/1 17:49
# 86   1651407633   pod         shippingservice-0   k8s容器cpu负载  2022/5/1 20:20
# 64   1651564006   pod         shippingservice-1    k8s容器内存负载  2022/5/3 15:46
# 126  1651692556   pod   productcatalogservice-0   k8s容器写io负载   2022/5/5 3:29
# 111  1651716458   pod   recommendationservice-2   k8s容器读io负载  2022/5/5 10:07
# 129  1651920562   pod               adservice-0   k8s容器写io负载  2022/5/7 18:49
# 95   1652032391   pod         shippingservice-1   k8s容器cpu负载   2022/5/9 1:53
# 132  1652060333   pod  recommendationservice2-0   k8s容器写io负载   2022/5/9 9:39
# 120  1652089514   pod               adservice-1   k8s容器读io负载  2022/5/9 17:45
#
#                 end  type
# 80    2022/5/1 8:58  test
# 135  2022/5/1 12:42  test
# 121  2022/5/1 13:30  test
# 84   2022/5/1 17:55  test
# 86   2022/5/1 20:26  test
# 64   2022/5/3 15:54  test
# 126   2022/5/5 3:33  test
# 111  2022/5/5 10:14  test
# 129  2022/5/7 18:52  test
# 95    2022/5/9 2:01  test
# 132   2022/5/9 9:44  test
# 120  2022/5/9 17:52  test
#       timestamp level                   cmdb_id failure_type           start  \
# 80   1651366271   pod         checkoutservice-0   k8s容器cpu负载   2022/5/1 8:51
# 135  1651379795   pod   productcatalogservice-2    k8s容器进程中止  2022/5/1 12:36
# 121  1651382580   pod                frontend-0   k8s容器写io负载  2022/5/1 13:23
# 84   1651398576   pod                frontend-0   k8s容器cpu负载  2022/5/1 17:49
# 86   1651407633   pod         shippingservice-0   k8s容器cpu负载  2022/5/1 20:20
# 64   1651564006   pod         shippingservice-1    k8s容器内存负载  2022/5/3 15:46
# 126  1651692556   pod   productcatalogservice-0   k8s容器写io负载   2022/5/5 3:29
# 111  1651716458   pod   recommendationservice-2   k8s容器读io负载  2022/5/5 10:07
# 129  1651920562   pod               adservice-0   k8s容器写io负载  2022/5/7 18:49
# 95   1652032391   pod         shippingservice-1   k8s容器cpu负载   2022/5/9 1:53
# 132  1652060333   pod  recommendationservice2-0   k8s容器写io负载   2022/5/9 9:39
# 120  1652089514   pod               adservice-1   k8s容器读io负载  2022/5/9 17:45
#
#                 end  type
# 80    2022/5/1 8:58  test
# 135  2022/5/1 12:42  test
# 121  2022/5/1 13:30  test
# 84   2022/5/1 17:55  test
# 86   2022/5/1 20:26  test
# 64   2022/5/3 15:54  test
# 126   2022/5/5 3:33  test
# 111  2022/5/5 10:14  test
# 129  2022/5/7 18:52  test
# 95    2022/5/9 2:01  test
# 132   2022/5/9 9:44  test
# 120  2022/5/9 17:52  test
#       timestamp level                   cmdb_id failure_type           start  \
# 80   1651366271   pod         checkoutservice-0   k8s容器cpu负载   2022/5/1 8:51
# 135  1651379795   pod   productcatalogservice-2    k8s容器进程中止  2022/5/1 12:36
# 121  1651382580   pod                frontend-0   k8s容器写io负载  2022/5/1 13:23
# 84   1651398576   pod                frontend-0   k8s容器cpu负载  2022/5/1 17:49
# 86   1651407633   pod         shippingservice-0   k8s容器cpu负载  2022/5/1 20:20
# 64   1651564006   pod         shippingservice-1    k8s容器内存负载  2022/5/3 15:46
# 126  1651692556   pod   productcatalogservice-0   k8s容器写io负载   2022/5/5 3:29
# 111  1651716458   pod   recommendationservice-2   k8s容器读io负载  2022/5/5 10:07
# 129  1651920562   pod               adservice-0   k8s容器写io负载  2022/5/7 18:49
# 95   1652032391   pod         shippingservice-1   k8s容器cpu负载   2022/5/9 1:53
# 132  1652060333   pod  recommendationservice2-0   k8s容器写io负载   2022/5/9 9:39
# 120  1652089514   pod               adservice-1   k8s容器读io负载  2022/5/9 17:45
#
#                 end  type
# 80    2022/5/1 8:58  test
# 135  2022/5/1 12:42  test
# 121  2022/5/1 13:30  test
# 84   2022/5/1 17:55  test
# 86   2022/5/1 20:26  test
# 64   2022/5/3 15:54  test
# 126   2022/5/5 3:33  test
# 111  2022/5/5 10:14  test
# 129  2022/5/7 18:52  test
# 95    2022/5/9 2:01  test
# 132   2022/5/9 9:44  test
# 120  2022/5/9 17:52  test
#       timestamp level                   cmdb_id failure_type           start  \
# 80   1651366271   pod         checkoutservice-0   k8s容器cpu负载   2022/5/1 8:51
# 135  1651379795   pod   productcatalogservice-2    k8s容器进程中止  2022/5/1 12:36
# 121  1651382580   pod                frontend-0   k8s容器写io负载  2022/5/1 13:23
# 84   1651398576   pod                frontend-0   k8s容器cpu负载  2022/5/1 17:49
# 86   1651407633   pod         shippingservice-0   k8s容器cpu负载  2022/5/1 20:20
# 64   1651564006   pod         shippingservice-1    k8s容器内存负载  2022/5/3 15:46
# 126  1651692556   pod   productcatalogservice-0   k8s容器写io负载   2022/5/5 3:29
# 111  1651716458   pod   recommendationservice-2   k8s容器读io负载  2022/5/5 10:07
# 129  1651920562   pod               adservice-0   k8s容器写io负载  2022/5/7 18:49
# 95   1652032391   pod         shippingservice-1   k8s容器cpu负载   2022/5/9 1:53
# 132  1652060333   pod  recommendationservice2-0   k8s容器写io负载   2022/5/9 9:39
# 120  1652089514   pod               adservice-1   k8s容器读io负载  2022/5/9 17:45
#
#                 end  type
# 80    2022/5/1 8:58  test
# 135  2022/5/1 12:42  test
# 121  2022/5/1 13:30  test
# 84   2022/5/1 17:55  test
# 86   2022/5/1 20:26  test
# 64   2022/5/3 15:54  test
# 126   2022/5/5 3:33  test
# 111  2022/5/5 10:14  test
# 129  2022/5/7 18:52  test
# 95    2022/5/9 2:01  test
# 132   2022/5/9 9:44  test
# 120  2022/5/9 17:52  test
#       timestamp level                   cmdb_id failure_type           start  \
# 80   1651366271   pod         checkoutservice-0   k8s容器cpu负载   2022/5/1 8:51
# 135  1651379795   pod   productcatalogservice-2    k8s容器进程中止  2022/5/1 12:36
# 121  1651382580   pod                frontend-0   k8s容器写io负载  2022/5/1 13:23
# 84   1651398576   pod                frontend-0   k8s容器cpu负载  2022/5/1 17:49
# 86   1651407633   pod         shippingservice-0   k8s容器cpu负载  2022/5/1 20:20
# 64   1651564006   pod         shippingservice-1    k8s容器内存负载  2022/5/3 15:46
# 126  1651692556   pod   productcatalogservice-0   k8s容器写io负载   2022/5/5 3:29
# 111  1651716458   pod   recommendationservice-2   k8s容器读io负载  2022/5/5 10:07
# 129  1651920562   pod               adservice-0   k8s容器写io负载  2022/5/7 18:49
# 95   1652032391   pod         shippingservice-1   k8s容器cpu负载   2022/5/9 1:53
# 132  1652060333   pod  recommendationservice2-0   k8s容器写io负载   2022/5/9 9:39
# 120  1652089514   pod               adservice-1   k8s容器读io负载  2022/5/9 17:45
#
#                 end  type
# 80    2022/5/1 8:58  test
# 135  2022/5/1 12:42  test
# 121  2022/5/1 13:30  test
# 84   2022/5/1 17:55  test
# 86   2022/5/1 20:26  test
# 64   2022/5/3 15:54  test
# 126   2022/5/5 3:33  test
# 111  2022/5/5 10:14  test
# 129  2022/5/7 18:52  test
# 95    2022/5/9 2:01  test
# 132   2022/5/9 9:44  test
# 120  2022/5/9 17:52  test
#       timestamp level                   cmdb_id failure_type           start  \
# 80   1651366271   pod         checkoutservice-0   k8s容器cpu负载   2022/5/1 8:51
# 135  1651379795   pod   productcatalogservice-2    k8s容器进程中止  2022/5/1 12:36
# 121  1651382580   pod                frontend-0   k8s容器写io负载  2022/5/1 13:23
# 84   1651398576   pod                frontend-0   k8s容器cpu负载  2022/5/1 17:49
# 86   1651407633   pod         shippingservice-0   k8s容器cpu负载  2022/5/1 20:20
# 64   1651564006   pod         shippingservice-1    k8s容器内存负载  2022/5/3 15:46
# 126  1651692556   pod   productcatalogservice-0   k8s容器写io负载   2022/5/5 3:29
# 111  1651716458   pod   recommendationservice-2   k8s容器读io负载  2022/5/5 10:07
# 129  1651920562   pod               adservice-0   k8s容器写io负载  2022/5/7 18:49
# 95   1652032391   pod         shippingservice-1   k8s容器cpu负载   2022/5/9 1:53
# 132  1652060333   pod  recommendationservice2-0   k8s容器写io负载   2022/5/9 9:39
# 120  1652089514   pod               adservice-1   k8s容器读io负载  2022/5/9 17:45
#
#                 end  type
# 80    2022/5/1 8:58  test
# 135  2022/5/1 12:42  test
# 121  2022/5/1 13:30  test
# 84   2022/5/1 17:55  test
# 86   2022/5/1 20:26  test
# 64   2022/5/3 15:54  test
# 126   2022/5/5 3:33  test
# 111  2022/5/5 10:14  test
# 129  2022/5/7 18:52  test
# 95    2022/5/9 2:01  test
# 132   2022/5/9 9:44  test
# 120  2022/5/9 17:52  test
#       timestamp level                   cmdb_id failure_type           start  \
# 80   1651366271   pod         checkoutservice-0   k8s容器cpu负载   2022/5/1 8:51
# 135  1651379795   pod   productcatalogservice-2    k8s容器进程中止  2022/5/1 12:36
# 121  1651382580   pod                frontend-0   k8s容器写io负载  2022/5/1 13:23
# 84   1651398576   pod                frontend-0   k8s容器cpu负载  2022/5/1 17:49
# 86   1651407633   pod         shippingservice-0   k8s容器cpu负载  2022/5/1 20:20
# 64   1651564006   pod         shippingservice-1    k8s容器内存负载  2022/5/3 15:46
# 126  1651692556   pod   productcatalogservice-0   k8s容器写io负载   2022/5/5 3:29
# 111  1651716458   pod   recommendationservice-2   k8s容器读io负载  2022/5/5 10:07
# 129  1651920562   pod               adservice-0   k8s容器写io负载  2022/5/7 18:49
# 95   1652032391   pod         shippingservice-1   k8s容器cpu负载   2022/5/9 1:53
# 132  1652060333   pod  recommendationservice2-0   k8s容器写io负载   2022/5/9 9:39
# 120  1652089514   pod               adservice-1   k8s容器读io负载  2022/5/9 17:45
#
#                 end  type
# 80    2022/5/1 8:58  test
# 135  2022/5/1 12:42  test
# 121  2022/5/1 13:30  test
# 84   2022/5/1 17:55  test
# 86   2022/5/1 20:26  test
# 64   2022/5/3 15:54  test
# 126   2022/5/5 3:33  test
# 111  2022/5/5 10:14  test
# 129  2022/5/7 18:52  test
# 95    2022/5/9 2:01  test
# 132   2022/5/9 9:44  test
# 120  2022/5/9 17:52  test
#       timestamp level                   cmdb_id failure_type           start  \
# 80   1651366271   pod         checkoutservice-0   k8s容器cpu负载   2022/5/1 8:51
# 135  1651379795   pod   productcatalogservice-2    k8s容器进程中止  2022/5/1 12:36
# 121  1651382580   pod                frontend-0   k8s容器写io负载  2022/5/1 13:23
# 84   1651398576   pod                frontend-0   k8s容器cpu负载  2022/5/1 17:49
# 86   1651407633   pod         shippingservice-0   k8s容器cpu负载  2022/5/1 20:20
# 64   1651564006   pod         shippingservice-1    k8s容器内存负载  2022/5/3 15:46
# 126  1651692556   pod   productcatalogservice-0   k8s容器写io负载   2022/5/5 3:29
# 111  1651716458   pod   recommendationservice-2   k8s容器读io负载  2022/5/5 10:07
# 129  1651920562   pod               adservice-0   k8s容器写io负载  2022/5/7 18:49
# 95   1652032391   pod         shippingservice-1   k8s容器cpu负载   2022/5/9 1:53
# 132  1652060333   pod  recommendationservice2-0   k8s容器写io负载   2022/5/9 9:39
# 120  1652089514   pod               adservice-1   k8s容器读io负载  2022/5/9 17:45
#
#                 end  type
# 80    2022/5/1 8:58  test
# 135  2022/5/1 12:42  test
# 121  2022/5/1 13:30  test
# 84   2022/5/1 17:55  test
# 86   2022/5/1 20:26  test
# 64   2022/5/3 15:54  test
# 126   2022/5/5 3:33  test
# 111  2022/5/5 10:14  test
# 129  2022/5/7 18:52  test
# 95    2022/5/9 2:01  test
# 132   2022/5/9 9:44  test
# 120  2022/5/9 17:52  test
#       timestamp level                   cmdb_id failure_type           start  \
# 80   1651366271   pod         checkoutservice-0   k8s容器cpu负载   2022/5/1 8:51
# 135  1651379795   pod   productcatalogservice-2    k8s容器进程中止  2022/5/1 12:36
# 121  1651382580   pod                frontend-0   k8s容器写io负载  2022/5/1 13:23
# 84   1651398576   pod                frontend-0   k8s容器cpu负载  2022/5/1 17:49
# 86   1651407633   pod         shippingservice-0   k8s容器cpu负载  2022/5/1 20:20
# 64   1651564006   pod         shippingservice-1    k8s容器内存负载  2022/5/3 15:46
# 126  1651692556   pod   productcatalogservice-0   k8s容器写io负载   2022/5/5 3:29
# 111  1651716458   pod   recommendationservice-2   k8s容器读io负载  2022/5/5 10:07
# 129  1651920562   pod               adservice-0   k8s容器写io负载  2022/5/7 18:49
# 95   1652032391   pod         shippingservice-1   k8s容器cpu负载   2022/5/9 1:53
# 132  1652060333   pod  recommendationservice2-0   k8s容器写io负载   2022/5/9 9:39
# 120  1652089514   pod               adservice-1   k8s容器读io负载  2022/5/9 17:45
#
#                 end  type
# 80    2022/5/1 8:58  test
# 135  2022/5/1 12:42  test
# 121  2022/5/1 13:30  test
# 84   2022/5/1 17:55  test
# 86   2022/5/1 20:26  test
# 64   2022/5/3 15:54  test
# 126   2022/5/5 3:33  test
# 111  2022/5/5 10:14  test
# 129  2022/5/7 18:52  test
# 95    2022/5/9 2:01  test
# 132   2022/5/9 9:44  test
# 120  2022/5/9 17:52  test
#       timestamp level                   cmdb_id failure_type           start  \
# 80   1651366271   pod         checkoutservice-0   k8s容器cpu负载   2022/5/1 8:51
# 135  1651379795   pod   productcatalogservice-2    k8s容器进程中止  2022/5/1 12:36
# 121  1651382580   pod                frontend-0   k8s容器写io负载  2022/5/1 13:23
# 84   1651398576   pod                frontend-0   k8s容器cpu负载  2022/5/1 17:49
# 86   1651407633   pod         shippingservice-0   k8s容器cpu负载  2022/5/1 20:20
# 64   1651564006   pod         shippingservice-1    k8s容器内存负载  2022/5/3 15:46
# 126  1651692556   pod   productcatalogservice-0   k8s容器写io负载   2022/5/5 3:29
# 111  1651716458   pod   recommendationservice-2   k8s容器读io负载  2022/5/5 10:07
# 129  1651920562   pod               adservice-0   k8s容器写io负载  2022/5/7 18:49
# 95   1652032391   pod         shippingservice-1   k8s容器cpu负载   2022/5/9 1:53
# 132  1652060333   pod  recommendationservice2-0   k8s容器写io负载   2022/5/9 9:39
# 120  1652089514   pod               adservice-1   k8s容器读io负载  2022/5/9 17:45
#
#                 end  type
# 80    2022/5/1 8:58  test
# 135  2022/5/1 12:42  test
# 121  2022/5/1 13:30  test
# 84   2022/5/1 17:55  test
# 86   2022/5/1 20:26  test
# 64   2022/5/3 15:54  test
# 126   2022/5/5 3:33  test
# 111  2022/5/5 10:14  test
# 129  2022/5/7 18:52  test
# 95    2022/5/9 2:01  test
# 132   2022/5/9 9:44  test
# 120  2022/5/9 17:52  test
#       timestamp level                   cmdb_id failure_type           start  \
# 80   1651366271   pod         checkoutservice-0   k8s容器cpu负载   2022/5/1 8:51
# 135  1651379795   pod   productcatalogservice-2    k8s容器进程中止  2022/5/1 12:36
# 121  1651382580   pod                frontend-0   k8s容器写io负载  2022/5/1 13:23
# 84   1651398576   pod                frontend-0   k8s容器cpu负载  2022/5/1 17:49
# 86   1651407633   pod         shippingservice-0   k8s容器cpu负载  2022/5/1 20:20
# 64   1651564006   pod         shippingservice-1    k8s容器内存负载  2022/5/3 15:46
# 126  1651692556   pod   productcatalogservice-0   k8s容器写io负载   2022/5/5 3:29
# 111  1651716458   pod   recommendationservice-2   k8s容器读io负载  2022/5/5 10:07
# 129  1651920562   pod               adservice-0   k8s容器写io负载  2022/5/7 18:49
# 95   1652032391   pod         shippingservice-1   k8s容器cpu负载   2022/5/9 1:53
# 132  1652060333   pod  recommendationservice2-0   k8s容器写io负载   2022/5/9 9:39
# 120  1652089514   pod               adservice-1   k8s容器读io负载  2022/5/9 17:45
#
#                 end  type
# 80    2022/5/1 8:58  test
# 135  2022/5/1 12:42  test
# 121  2022/5/1 13:30  test
# 84   2022/5/1 17:55  test
# 86   2022/5/1 20:26  test
# 64   2022/5/3 15:54  test
# 126   2022/5/5 3:33  test
# 111  2022/5/5 10:14  test
# 129  2022/5/7 18:52  test
# 95    2022/5/9 2:01  test
# 132   2022/5/9 9:44  test
# 120  2022/5/9 17:52  test
#       timestamp level                   cmdb_id failure_type           start  \
# 80   1651366271   pod         checkoutservice-0   k8s容器cpu负载   2022/5/1 8:51
# 135  1651379795   pod   productcatalogservice-2    k8s容器进程中止  2022/5/1 12:36
# 121  1651382580   pod                frontend-0   k8s容器写io负载  2022/5/1 13:23
# 84   1651398576   pod                frontend-0   k8s容器cpu负载  2022/5/1 17:49
# 86   1651407633   pod         shippingservice-0   k8s容器cpu负载  2022/5/1 20:20
# 64   1651564006   pod         shippingservice-1    k8s容器内存负载  2022/5/3 15:46
# 126  1651692556   pod   productcatalogservice-0   k8s容器写io负载   2022/5/5 3:29
# 111  1651716458   pod   recommendationservice-2   k8s容器读io负载  2022/5/5 10:07
# 129  1651920562   pod               adservice-0   k8s容器写io负载  2022/5/7 18:49
# 95   1652032391   pod         shippingservice-1   k8s容器cpu负载   2022/5/9 1:53
# 132  1652060333   pod  recommendationservice2-0   k8s容器写io负载   2022/5/9 9:39
# 120  1652089514   pod               adservice-1   k8s容器读io负载  2022/5/9 17:45
#
#                 end  type
# 80    2022/5/1 8:58  test
# 135  2022/5/1 12:42  test
# 121  2022/5/1 13:30  test
# 84   2022/5/1 17:55  test
# 86   2022/5/1 20:26  test
# 64   2022/5/3 15:54  test
# 126   2022/5/5 3:33  test
# 111  2022/5/5 10:14  test
# 129  2022/5/7 18:52  test
# 95    2022/5/9 2:01  test
# 132   2022/5/9 9:44  test
# 120  2022/5/9 17:52  test
#       timestamp level                   cmdb_id failure_type           start  \
# 80   1651366271   pod         checkoutservice-0   k8s容器cpu负载   2022/5/1 8:51
# 135  1651379795   pod   productcatalogservice-2    k8s容器进程中止  2022/5/1 12:36
# 121  1651382580   pod                frontend-0   k8s容器写io负载  2022/5/1 13:23
# 84   1651398576   pod                frontend-0   k8s容器cpu负载  2022/5/1 17:49
# 86   1651407633   pod         shippingservice-0   k8s容器cpu负载  2022/5/1 20:20
# 64   1651564006   pod         shippingservice-1    k8s容器内存负载  2022/5/3 15:46
# 126  1651692556   pod   productcatalogservice-0   k8s容器写io负载   2022/5/5 3:29
# 111  1651716458   pod   recommendationservice-2   k8s容器读io负载  2022/5/5 10:07
# 129  1651920562   pod               adservice-0   k8s容器写io负载  2022/5/7 18:49
# 95   1652032391   pod         shippingservice-1   k8s容器cpu负载   2022/5/9 1:53
# 132  1652060333   pod  recommendationservice2-0   k8s容器写io负载   2022/5/9 9:39
# 120  1652089514   pod               adservice-1   k8s容器读io负载  2022/5/9 17:45
#
#                 end  type
# 80    2022/5/1 8:58  test
# 135  2022/5/1 12:42  test
# 121  2022/5/1 13:30  test
# 84   2022/5/1 17:55  test
# 86   2022/5/1 20:26  test
# 64   2022/5/3 15:54  test
# 126   2022/5/5 3:33  test
# 111  2022/5/5 10:14  test
# 129  2022/5/7 18:52  test
# 95    2022/5/9 2:01  test
# 132   2022/5/9 9:44  test
# 120  2022/5/9 17:52  test
# 0 Time used:  3.4633266925811768
# Save successfully!

# %%
# platform日志模板提取
# 处理日志
log_data = '/Users/fengxiaoyu/Desktop/PDiagnose/平台数据集/log/platform_template.csv'
df = pd.read_csv(log_data)

# 合并 template_id 和 value 列
df['EventId_EventTemplate'] = df['EventId'].astype(str) + '_' + df['message']

# 计算每个 template_id 的出现次数
template_counts = df['EventId_EventTemplate'].value_counts().reset_index()

# 重命名列名
template_counts.columns = ['EventId_EventTemplate', 'Occurrences']

# 拆分 EventId_EventTemplate 列为 EventId 和 EventTemplate 列
template_counts[['EventId', 'EventTemplate']] = template_counts['EventId_EventTemplate'].str.split('_', n=1, expand=True)

# 重新排列列的顺序并删除不需要的列
template_counts = template_counts[['EventId', 'EventTemplate', 'Occurrences']]

# %%
template_counts
# Out:
#          EventId                                      EventTemplate  \
# 0       0x6efd58  severity:info,message:conversion request succe...
# 1       0x6c210a             severity:debug,message:request started
# 2       0x6c210a            severity:debug,message:request complete
# 3       0x781d38  severity:info,message:Getting supported curren...
# 4       0x7c1a12    severity:warning,message:failed to retrieve ads
# ...          ...                                                ...
# 335628  0x388a4c  main.(*frontendServer).addToCartHandler(0xc000...
# 335629  0x388a4c  net/http.HandlerFunc.ServeHTTP(0xc00017dc00?, ...
# 335630  0x388a4c  github.com/gorilla/mux.(*Router).ServeHTTP(0xc...
# 335631  0x388a4c  main.(*logHandler).ServeHTTP(0xc000464060, {0x...
# 335632  0x59dd91  severity:info,message:Transaction processed: v...
#
#         Occurrences
# 0           4471004
# 1           2291326
# 2           2290965
# 3           1698561
# 4           1155332
# ...             ...
# 335628            1
# 335629            1
# 335630            1
# 335631            1
# 335632            1
#
# [335633 rows x 3 columns]

# %%
import pandas as pd
import os

# 将日志按照cmdb_id分组

def save_by_cmdb_id(file_path, output_dir):
    # 读取 CSV 文件
    data = pd.read_csv(file_path)
    
    # 检查输出目录是否存在，如果不存在，则创建
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    # 按照 'cmdb_id' 列分组
    grouped = data.groupby('cmdb_id')

    # 遍历每个分组
    for name, group in grouped:
        print(group)
        # 将分组数据保存到对应的文件中
        group.to_csv(os.path.join(output_dir, f"{name}.csv"), index=False)

# 使用函数
file_path = '/Users/fengxiaoyu/Desktop/PDiagnose/平台数据集/log/platform_template.csv'  # CSV文件的路径
output_dir = '/Users/fengxiaoyu/Desktop/PDiagnose/平台数据集/log'  # 输出目录的路径
save_by_cmdb_id(file_path, output_dir)
# Out:
#           Unnamed: 0.2  Unnamed: 0                log_id   timestamp  \
# 25                  25          25  2Rx9X44BgqWVbWTIyH8k  1710950409
# 26                  26          26  4xx9X44BgqWVbWTIyX8g  1710950409
# 27                  27          27  7hx9X44BgqWVbWTIyX8g  1710950419
# 28                  28          28  -xx9X44BgqWVbWTIyX8g  1710950419
# 29                  29          29  _Bx9X44BgqWVbWTIyX8g  1710950429
# ...                ...         ...                   ...         ...
# 20751035       6711159     2467013  1h53aY4BcF1whnmqNV4D  1711166399
# 20751058       6711182     2467036  Dx53aY4BcF1whnmqOmGp  1711166397
# 20751059       6711183     2467037  EB53aY4BcF1whnmqOmGp  1711166396
# 20751060       6711184     2467038  ER53aY4BcF1whnmqOmGp  1711166397
# 20751061       6711185     2467039  Eh53aY4BcF1whnmqOmGp  1711166396
#
#                               date      cmdb_id  \
# 25        2024-03-20T16:00:09.966Z  cartservice
# 26        2024-03-20T16:00:09.966Z  cartservice
# 27        2024-03-20T16:00:19.965Z  cartservice
# 28        2024-03-20T16:00:19.965Z  cartservice
# 29        2024-03-20T16:00:29.966Z  cartservice
# ...                            ...          ...
# 20751035  2024-03-23T03:59:59.992Z  cartservice
# 20751058  2024-03-23T03:59:57.096Z  cartservice
# 20751059  2024-03-23T03:59:56.592Z  cartservice
# 20751060  2024-03-23T03:59:57.096Z  cartservice
# 20751061  2024-03-23T03:59:56.592Z  cartservice
#
#                                                     message  Unnamed: 0.1  \
# 25                              Checking CartService Health           NaN
# 26                              Checking CartService Health           NaN
# 27                              Checking CartService Health           NaN
# 28                              Checking CartService Health           NaN
# 29                              Checking CartService Health           NaN
# ...                                                     ...           ...
# 20751035  GetCartAsync called with userId=2faeee2d-0bf0-...     2467013.0
# 20751058                        Checking CartService Health     2467036.0
# 20751059                        Checking CartService Health     2467037.0
# 20751060                        Checking CartService Health     2467038.0
# 20751061                        Checking CartService Health     2467039.0
#
#            EventId
# 25        0x2718dd
# 26        0x2718dd
# 27        0x2718dd
# 28        0x2718dd
# 29        0x2718dd
# ...            ...
# 20751035  0x4033dc
# 20751058  0x2718dd
# 20751059  0x2718dd
# 20751060  0x2718dd
# 20751061  0x2718dd
#
# [2227261 rows x 9 columns]
#           Unnamed: 0.2  Unnamed: 0                log_id   timestamp  \
# 78                  78          78  thh4X44BgqWVbWTIM_q7  1710950400
# 79                  79          79  6xh4X44BgqWVbWTINPrr  1710950410
# 80                  80          80  IBh4X44BgqWVbWTINPvr  1710950426
# 81                  81          81  VBh4X44BgqWVbWTINPvr  1710950430
# 82                  82          82  iBh4X44BgqWVbWTINfvX  1710950436
# ...                ...         ...                   ...         ...
# 20750632       6710756     2466610  Qx53aY4BcF1whnmqMFxT  1711166397
# 20750643       6710767     2466621  Uh53aY4BcF1whnmqMFxT  1711166397
# 20750644       6710768     2466622  Ux53aY4BcF1whnmqMFxT  1711166397
# 20751066       6711190     2467044  Xx53aY4BcF1whnmqT2yy  1711166396
# 20751067       6711191     2467045  YB53aY4BcF1whnmqT2yy  1711166397
#
#                               date          cmdb_id  \
# 78        2024-03-20T16:00:00.497Z  checkoutservice
# 79        2024-03-20T16:00:10.502Z  checkoutservice
# 80        2024-03-20T16:00:26.967Z  checkoutservice
# 81        2024-03-20T16:00:30.501Z  checkoutservice
# 82        2024-03-20T16:00:36.970Z  checkoutservice
# ...                            ...              ...
# 20750632  2024-03-23T03:59:57.723Z  checkoutservice
# 20750643  2024-03-23T03:59:57.577Z  checkoutservice
# 20750644  2024-03-23T03:59:57.729Z  checkoutservice
# 20751066  2024-03-23T03:59:56.623Z  checkoutservice
# 20751067  2024-03-23T03:59:57.170Z  checkoutservice
#
#                                                     message  Unnamed: 0.1  \
# 78                    level:debug,message:gathering metrics           NaN
# 79        level:debug,message:sent request with 2 transa...           NaN
# 80        level:debug,message:sent request with 2 transa...           NaN
# 81                    level:debug,message:gathering metrics           NaN
# 82        level:debug,message:sent request with 4 transa...           NaN
# ...                                                     ...           ...
# 20750632  severity:info,message:payment went through (tr...     2466610.0
# 20750643  severity:info,message:order confirmation email...     2466621.0
# 20750644  severity:info,message:order confirmation email...     2466622.0
# 20751066  level:debug,message:sent request with 2 transa...     2467044.0
# 20751067              level:debug,message:gathering metrics     2467045.0
#
#            EventId
# 78        0x382a46
# 79        0x762b07
# 80        0x762b07
# 81        0x382a46
# 82        0x762b07
# ...            ...
# 20750632  0x713149
# 20750643  0x4d1459
# 20750644  0x4d1459
# 20751066  0x762b07
# 20751067  0x382a46
#
# [350543 rows x 9 columns]
#           Unnamed: 0.2  Unnamed: 0                log_id   timestamp  \
# 1694              1694        1694  -hh3X44BgqWVbWTI_OIi  1710951548
# 4182              4182        4182  Exh3X44BgqWVbWTI_OMi  1710953346
# 6807              6807        6807  LBh3X44BgqWVbWTI_OMi  1710955235
# 9249              9249        9249  RRh3X44BgqWVbWTI_OMi  1710956986
# 11616            11616       11616  XRh3X44BgqWVbWTI_OMi  1710958654
# ...                ...         ...                   ...         ...
# 20751046       6711170     2467024  OR53aY4BcF1whnmqNl-H  1711166399
# 20751047       6711171     2467025  Oh53aY4BcF1whnmqNl-H  1711166399
# 20751048       6711172     2467026  Ox53aY4BcF1whnmqNl-H  1711166399
# 20751049       6711173     2467027  PB53aY4BcF1whnmqNl-H  1711166399
# 20751050       6711174     2467028  PR53aY4BcF1whnmqNl-H  1711166399
#
#                               date          cmdb_id  \
# 1694      2024-03-20T16:19:08.276Z  currencyservice
# 4182      2024-03-20T16:49:06.097Z  currencyservice
# 6807      2024-03-20T17:20:35.835Z  currencyservice
# 9249      2024-03-20T17:49:46.740Z  currencyservice
# 11616     2024-03-20T18:17:34.609Z  currencyservice
# ...                            ...              ...
# 20751046  2024-03-23T03:59:59.991Z  currencyservice
# 20751047  2024-03-23T03:59:59.992Z  currencyservice
# 20751048  2024-03-23T03:59:59.993Z  currencyservice
# 20751049  2024-03-23T03:59:59.997Z  currencyservice
# 20751050  2024-03-23T03:59:59.999Z  currencyservice
#
#                                                     message  Unnamed: 0.1  \
# 1694      2024-03-20T16:19:08.276006Z\tinfo\txdsproxy\tc...           NaN
# 4182      2024-03-20T16:49:06.096855Z\tinfo\txdsproxy\tc...           NaN
# 6807      2024-03-20T17:20:35.835511Z\tinfo\txdsproxy\tc...           NaN
# 9249      2024-03-20T17:49:46.740720Z\tinfo\txdsproxy\tc...           NaN
# 11616     2024-03-20T18:17:34.609367Z\tinfo\txdsproxy\tc...           NaN
# ...                                                     ...           ...
# 20751046  severity:info,message:conversion request succe...     2467024.0
# 20751047  severity:info,message:conversion request succe...     2467025.0
# 20751048  severity:info,message:conversion request succe...     2467026.0
# 20751049  severity:info,message:conversion request succe...     2467027.0
# 20751050  severity:info,message:conversion request succe...     2467028.0
#
#            EventId
# 1694      0x6eccc2
# 4182      0x6eccc2
# 6807      0x6eccc2
# 9249      0x6eccc2
# 11616     0x6eccc2
# ...            ...
# 20751046  0x6efd58
# 20751047  0x6efd58
# 20751048  0x6efd58
# 20751049  0x6efd58
# 20751050  0x6efd58
#
# [6171185 rows x 9 columns]
#           Unnamed: 0.2  Unnamed: 0                log_id   timestamp  \
# 13                  13          13  tBx9X44BgqWVbWTInWJ6  1710950401
# 14                  14          14  tRx9X44BgqWVbWTInWJ6  1710950406
# 15                  15          15  vxx9X44BgqWVbWTInWJ6  1710950411
# 16                  16          16  yhx9X44BgqWVbWTInWJ6  1710950416
# 17                  17          17  1Bx9X44BgqWVbWTInWJ6  1710950421
# ...                ...         ...                   ...         ...
# 20750564       6710688     2466542  5x53aY4BcF1whnmqL1tw  1711166394
# 20750580       6710704     2466558  _R53aY4BcF1whnmqL1tw  1711166397
# 20751024       6711148     2467002  oB53aY4BcF1whnmqNV4D  1711166396
# 20751025       6711149     2467003  oR53aY4BcF1whnmqNV4D  1711166397
# 20751030       6711154     2467008  px53aY4BcF1whnmqNV4D  1711166399
#
#                               date       cmdb_id  \
# 13        2024-03-20T16:00:01.549Z  emailservice
# 14        2024-03-20T16:00:06.549Z  emailservice
# 15        2024-03-20T16:00:11.550Z  emailservice
# 16        2024-03-20T16:00:16.549Z  emailservice
# 17        2024-03-20T16:00:21.550Z  emailservice
# ...                            ...           ...
# 20750564  2024-03-23T03:59:54.230Z  emailservice
# 20750580  2024-03-23T03:59:57.576Z  emailservice
# 20751024  2024-03-23T03:59:56.503Z  emailservice
# 20751025  2024-03-23T03:59:57.729Z  emailservice
# 20751030  2024-03-23T03:59:59.231Z  emailservice
#
#                                                     message  Unnamed: 0.1  \
# 13        Failed to export traces, error code: StatusCod...           NaN
# 14        Failed to export traces, error code: StatusCod...           NaN
# 15        Failed to export traces, error code: StatusCod...           NaN
# 16        Failed to export traces, error code: StatusCod...           NaN
# 17        Failed to export traces, error code: StatusCod...           NaN
# ...                                                     ...           ...
# 20750564  Failed to export traces, error code: StatusCod...     2466542.0
# 20750580  severity:INFO,message:A request to send order ...     2466558.0
# 20751024  severity:INFO,message:A request to send order ...     2467002.0
# 20751025  severity:INFO,message:A request to send order ...     2467003.0
# 20751030  Failed to export traces, error code: StatusCod...     2467008.0
#
#            EventId
# 13        0x15f85b
# 14        0x15f85b
# 15        0x15f85b
# 16        0x15f85b
# 17        0x15f85b
# ...            ...
# 20750564  0x15f85b
# 20750580  0x34dc24
# 20751024  0x34dc24
# 20751025  0x34dc24
# 20751030  0x15f85b
#
# [143452 rows x 9 columns]
#           Unnamed: 0.2  Unnamed: 0                log_id   timestamp  \
# 37                  37          37  tyGFX44BgqWVbWTICkfW  1710950404
# 38                  38          38  vSGFX44BgqWVbWTICkfW  1710950404
# 39                  39          39  wyGFX44BgqWVbWTICkfW  1710950404
# 40                  40          40  yiGFX44BgqWVbWTICkfW  1710950404
# 41                  41          41  0CGFX44BgqWVbWTICkfW  1710950414
# ...                ...         ...                   ...         ...
# 20751057       6711181     2467035  cR53aY4BcF1whnmqN19N  1711166399
# 20751062       6711186     2467040  Fh53aY4BcF1whnmqOmGp  1711166397
# 20751063       6711187     2467041  Fx53aY4BcF1whnmqOmGp  1711166397
# 20751064       6711188     2467042  GB53aY4BcF1whnmqOmGp  1711166397
# 20751065       6711189     2467043  GR53aY4BcF1whnmqOmGp  1711166397
#
#                               date   cmdb_id  \
# 37        2024-03-20T16:00:04.767Z  frontend
# 38        2024-03-20T16:00:04.767Z  frontend
# 39        2024-03-20T16:00:04.767Z  frontend
# 40        2024-03-20T16:00:04.767Z  frontend
# 41        2024-03-20T16:00:14.768Z  frontend
# ...                            ...       ...
# 20751057  2024-03-23T03:59:59.995Z  frontend
# 20751062  2024-03-23T03:59:57.997Z  frontend
# 20751063  2024-03-23T03:59:57.997Z  frontend
# 20751064  2024-03-23T03:59:57.997Z  frontend
# 20751065  2024-03-23T03:59:57.997Z  frontend
#
#                                           message  Unnamed: 0.1   EventId
# 37         severity:debug,message:request started           NaN  0x6c210a
# 38        severity:debug,message:request complete           NaN  0x6c210a
# 39         severity:debug,message:request started           NaN  0x6c210a
# 40        severity:debug,message:request complete           NaN  0x6c210a
# 41         severity:debug,message:request started           NaN  0x6c210a
# ...                                           ...           ...       ...
# 20751057  severity:debug,message:request complete     2467035.0  0x6c210a
# 20751062   severity:debug,message:request started     2467040.0  0x6c210a
# 20751063  severity:debug,message:request complete     2467041.0  0x6c210a
# 20751064   severity:debug,message:request started     2467042.0  0x6c210a
# 20751065  severity:debug,message:request complete     2467043.0  0x6c210a
#
# [8744914 rows x 9 columns]
#           Unnamed: 0.2  Unnamed: 0                log_id   timestamp  \
# 1008              1008        1008  7Bl4X44BgqWVbWTIQwJa  1710951073
# 3155              3155        3155  Fhl4X44BgqWVbWTIQwNa  1710952624
# 3156              3156        3156  QBl4X44BgqWVbWTIRAMi  1710952624
# 3414              3414        3414  aRl4X44BgqWVbWTIRAMi  1710952813
# 5876              5876        5876  khl4X44BgqWVbWTIRAMi  1710954594
# ...                ...         ...                   ...         ...
# 20750609       6710733     2466587  Ix53aY4BcF1whnmqMFxT  1711166397
# 20751026       6711150     2467004  oh53aY4BcF1whnmqNV4D  1711166396
# 20751027       6711151     2467005  ox53aY4BcF1whnmqNV4D  1711166396
# 20751028       6711152     2467006  pB53aY4BcF1whnmqNV4D  1711166397
# 20751029       6711153     2467007  pR53aY4BcF1whnmqNV4D  1711166397
#
#                               date         cmdb_id  \
# 1008      2024-03-20T16:11:13.722Z  paymentservice
# 3155      2024-03-20T16:37:04.034Z  paymentservice
# 3156      2024-03-20T16:37:04.142Z  paymentservice
# 3414      2024-03-20T16:40:13.618Z  paymentservice
# 5876      2024-03-20T17:09:54.099Z  paymentservice
# ...                            ...             ...
# 20750609  2024-03-23T03:59:57.567Z  paymentservice
# 20751026  2024-03-23T03:59:56.498Z  paymentservice
# 20751027  2024-03-23T03:59:56.498Z  paymentservice
# 20751028  2024-03-23T03:59:57.722Z  paymentservice
# 20751029  2024-03-23T03:59:57.722Z  paymentservice
#
#                                                     message  Unnamed: 0.1  \
# 1008      2024-03-20T16:11:13.722440Z\tinfo\txdsproxy\tc...           NaN
# 3155      2024-03-20T16:37:04.034320Z\tinfo\tads\tXDS: I...           NaN
# 3156      2024-03-20T16:37:04.142500Z\tinfo\tcache\tgene...           NaN
# 3414      2024-03-20T16:40:13.618600Z\tinfo\txdsproxy\tc...           NaN
# 5876      2024-03-20T17:09:54.099023Z\tinfo\txdsproxy\tc...           NaN
# ...                                                     ...           ...
# 20750609  severity:info,message:Transaction processed: v...     2466587.0
# 20751026  severity:info,message:PaymentService#Charge in...     2467004.0
# 20751027  severity:info,message:Transaction processed: v...     2467005.0
# 20751028  severity:info,message:PaymentService#Charge in...     2467006.0
# 20751029  severity:info,message:Transaction processed: v...     2467007.0
#
#            EventId
# 1008      0x6eccc2
# 3155      0x7c68c7
# 3156      0x56f1fc
# 3414      0x6eccc2
# 5876      0x6eccc2
# ...            ...
# 20750609  0x59dd91
# 20751026  0x575010
# 20751027  0x59dd91
# 20751028  0x575010
# 20751029  0x59dd91
#
# [145320 rows x 9 columns]
#           Unnamed: 0.2  Unnamed: 0                log_id   timestamp  \
# 72                  72          72  8Rl4X44BgqWVbWTI_myu  1710950414
# 73                  73          73  Cxl4X44BgqWVbWTI_m2u  1710950414
# 74                  74          74  Jhl4X44BgqWVbWTI_m2u  1710950424
# 75                  75          75  QBl4X44BgqWVbWTI_21f  1710950444
# 76                  76          76  Whl4X44BgqWVbWTI_21f  1710950444
# ...                ...         ...                   ...         ...
# 20750203       6710327     2466181  5h53aY4BcF1whnmqD0qo  1711166391
# 20750204       6710328     2466182  5x53aY4BcF1whnmqD0qo  1711166392
# 20750555       6710679     2466533  Tx53aY4BcF1whnmqKFdH  1711166390
# 20750557       6710681     2466535  Uh53aY4BcF1whnmqKFdH  1711166393
# 20750562       6710686     2466540  5R53aY4BcF1whnmqL1tw  1711166394
#
#                               date                cmdb_id  \
# 72        2024-03-20T16:00:14.271Z  productcatalogservice
# 73        2024-03-20T16:00:14.717Z  productcatalogservice
# 74        2024-03-20T16:00:24.724Z  productcatalogservice
# 75        2024-03-20T16:00:44.270Z  productcatalogservice
# 76        2024-03-20T16:00:44.722Z  productcatalogservice
# ...                            ...                    ...
# 20750203  2024-03-23T03:59:51.425Z  productcatalogservice
# 20750204  2024-03-23T03:59:52.304Z  productcatalogservice
# 20750555  2024-03-23T03:59:50.544Z  productcatalogservice
# 20750557  2024-03-23T03:59:53.227Z  productcatalogservice
# 20750562  2024-03-23T03:59:54.480Z  productcatalogservice
#
#                                                     message  Unnamed: 0.1  \
# 72        level:debug,message:sent request with 4 transa...           NaN
# 73                    level:debug,message:gathering metrics           NaN
# 74        level:debug,message:sent request with 2 transa...           NaN
# 75        level:debug,message:sent request with 4 transa...           NaN
# 76                    level:debug,message:gathering metrics           NaN
# ...                                                     ...           ...
# 20750203  level:debug,message:sent request with 207 tran...     2466181.0
# 20750204              level:debug,message:gathering metrics     2466182.0
# 20750555              level:debug,message:gathering metrics     2466533.0
# 20750557  level:debug,message:sent request with 3 transa...     2466535.0
# 20750562  level:debug,message:sent request with 270 tran...     2466540.0
#
#            EventId
# 72        0x762b07
# 73        0x382a46
# 74        0x762b07
# 75        0x762b07
# 76        0x382a46
# ...            ...
# 20750203  0x762b07
# 20750204  0x382a46
# 20750555  0x382a46
# 20750557  0x762b07
# 20750562  0x762b07
#
# [148039 rows x 9 columns]
#           Unnamed: 0.2  Unnamed: 0                log_id   timestamp  \
# 0                    0           0  hhl5X44BgqWVbWTIbbAR  1710950400
# 1                    1           1  oBl5X44BgqWVbWTIbbAS  1710950405
# 2                    2           2  uhl5X44BgqWVbWTIbbDL  1710950410
# 3                    3           3  1Bl5X44BgqWVbWTIbbDL  1710950415
# 4                    4           4  7hl5X44BgqWVbWTIbbDL  1710950420
# ...                ...         ...                   ...         ...
# 20750965       6711089     2466943  YB53aY4BcF1whnmqM16n  1711166399
# 20750966       6711090     2466944  YR53aY4BcF1whnmqM16n  1711166399
# 20750967       6711091     2466945  Yh53aY4BcF1whnmqM16n  1711166399
# 20750968       6711092     2466946  Yx53aY4BcF1whnmqM16n  1711166399
# 20751031       6711155     2467009  sx53aY4BcF1whnmqNV4D  1711166399
#
#                               date                cmdb_id  \
# 0         2024-03-20T16:00:00.215Z  recommendationservice
# 1         2024-03-20T16:00:05.216Z  recommendationservice
# 2         2024-03-20T16:00:10.217Z  recommendationservice
# 3         2024-03-20T16:00:15.216Z  recommendationservice
# 4         2024-03-20T16:00:20.216Z  recommendationservice
# ...                            ...                    ...
# 20750965  2024-03-23T03:59:59.200Z  recommendationservice
# 20750966  2024-03-23T03:59:59.487Z  recommendationservice
# 20750967  2024-03-23T03:59:59.592Z  recommendationservice
# 20750968  2024-03-23T03:59:59.691Z  recommendationservice
# 20751031  2024-03-23T03:59:59.995Z  recommendationservice
#
#                                                     message  Unnamed: 0.1  \
# 0         Failed to export traces, error code: StatusCod...           NaN
# 1         Failed to export traces, error code: StatusCod...           NaN
# 2         Failed to export traces, error code: StatusCod...           NaN
# 3         Failed to export traces, error code: StatusCod...           NaN
# 4         Failed to export traces, error code: StatusCod...           NaN
# ...                                                     ...           ...
# 20750965  severity:INFO,message:[Recv ListRecommendation...     2466943.0
# 20750966  severity:INFO,message:[Recv ListRecommendation...     2466944.0
# 20750967  severity:INFO,message:[Recv ListRecommendation...     2466945.0
# 20750968  Failed to export traces, error code: StatusCod...     2466946.0
# 20751031  severity:INFO,message:[Recv ListRecommendation...     2467009.0
#
#            EventId
# 0         0x15f85b
# 1         0x15f85b
# 2         0x15f85b
# 3         0x15f85b
# 4         0x15f85b
# ...            ...
# 20750965  0x20999b
# 20750966  0x20999b
# 20750967  0x20999b
# 20750968  0x15f85b
# 20751031  0x20999b
#
# [1520108 rows x 9 columns]
#           Unnamed: 0.2  Unnamed: 0                log_id   timestamp  \
# 65                  65          65  BCOHX44BgqWVbWTI5is7  1710950404
# 66                  66          66  CyOHX44BgqWVbWTI5is7  1710950414
# 67                  67          67  DCOHX44BgqWVbWTI5is7  1710950428
# 68                  68          68  DSOHX44BgqWVbWTI5is7  1710950429
# 69                  69          69  FCOHX44BgqWVbWTI5is7  1710950439
# ...                ...         ...                   ...         ...
# 20750971       6711095     2466949  ax53aY4BcF1whnmqM16n  1711166399
# 20750976       6711100     2466954  cB53aY4BcF1whnmqM16n  1711166399
# 20750977       6711101     2466955  cR53aY4BcF1whnmqNV4D  1711166399
# 20751036       6711160     2467014  1x53aY4BcF1whnmqNV4D  1711166399
# 20751037       6711161     2467015  2R53aY4BcF1whnmqNV4D  1711166399
#
#                               date          cmdb_id  \
# 65        2024-03-20T16:00:04.368Z  shippingservice
# 66        2024-03-20T16:00:14.370Z  shippingservice
# 67        2024-03-20T16:00:28.156Z  shippingservice
# 68        2024-03-20T16:00:29.367Z  shippingservice
# 69        2024-03-20T16:00:39.370Z  shippingservice
# ...                            ...              ...
# 20750971  2024-03-23T03:59:59.372Z  shippingservice
# 20750976  2024-03-23T03:59:59.055Z  shippingservice
# 20750977  2024-03-23T03:59:59.055Z  shippingservice
# 20751036  2024-03-23T03:59:59.996Z  shippingservice
# 20751037  2024-03-23T03:59:59.996Z  shippingservice
#
#                                                     message  Unnamed: 0.1  \
# 65        level:debug,message:sent request with 3 transa...           NaN
# 66        level:debug,message:sent request with 4 transa...           NaN
# 67                    level:debug,message:gathering metrics           NaN
# 68        level:debug,message:sent request with 3 transa...           NaN
# 69        level:debug,message:sent request with 5 transa...           NaN
# ...                                                     ...           ...
# 20750971  level:debug,message:sent request with 21 trans...     2466949.0
# 20750976  severity:info,message:[GetQuote] received request     2466954.0
# 20750977  severity:info,message:[GetQuote] completed req...     2466955.0
# 20751036  severity:info,message:[GetQuote] received request     2467014.0
# 20751037  severity:info,message:[GetQuote] completed req...     2467015.0
#
#            EventId
# 65        0x762b07
# 66        0x762b07
# 67        0x382a46
# 68        0x762b07
# 69        0x762b07
# ...            ...
# 20750971  0x762b07
# 20750976  0xb38467
# 20750977  0xb38467
# 20751036  0xb38467
# 20751037  0xb38467
#
# [1300246 rows x 9 columns]

# %%
import os
import pandas as pd
import time
import json

from datetime import datetime
import pytz
import time

tz = pytz.timezone('Asia/Shanghai')
def ts_to_date(timestamp):
    return datetime.fromtimestamp(timestamp//1000, tz).strftime('%Y-%m-%d')

def time_to_ts(ctime):
    try:
        # 先尝试解析包含小时和分钟的格式
        timeArray = time.strptime(ctime, '%Y/%m/%d %H:%M')
    except ValueError:
        try:
            # 如果失败，尝试只有日期的格式
            timeArray = time.strptime(ctime, '%Y/%m/%d')
        except ValueError:
            # 如果仍然失败，记录错误或返回一个默认值
            print(f"Failed to parse date: {ctime}")
            return None
    return int(time.mktime(timeArray))*1000

class LogAnalysis:
    def __init__(self, cases, log_dir, pid, load , anomaly_templates, dataset='gaia'):
        self.id = pid
        self.cases = cases.iloc[pid*load: (pid+1)*load]
        self.dataset = dataset
        self.data_dir = log_dir
        self.res = dict(zip(list(self.cases.index), [set() for _ in range(len(self.cases))]))
        self.time_used = 0
        self.anomaly_templates = anomaly_templates
        self.services = [service.split('.')[0] for service in os.listdir(
            self.data_dir) if service.split('.')[-1] == 'csv']
        
    def read_by_service(self, service):
        data = pd.read_csv(os.path.join(self.data_dir, f'{service}.csv'))
        if data['timestamp'].values[0] < 1e12:
            data['timestamp'] *= 1000
        return data
    
    def analysis(self):
        for service in self.services:
            log_data = self.read_by_service(service)
            start_time = time.time()
            # print(self.cases)
            for case_id, case in self.cases.iterrows():
                start_ts = int(case['st_time'])*1000
                end_ts = int(case['ed_time'])*1000
                sub_data = log_data[(log_data['timestamp']>=start_ts)&(log_data['timestamp']<end_ts)]
                for _, row in sub_data.iterrows():
                    if row['EventId'] in self.anomaly_templates:
                        self.res[case_id].add(service)
            end_time = time.time()
            self.time_used += (end_time - start_time)
    
    def save_res(self, savepath):
        for key in self.res:
            self.res[key] = list(self.res[key])
        with open(savepath, 'w') as f:
            json.dump(self.res, f)
        print(f'{self.id} Time used: ', self.time_used)
        print('Save successfully!')


import pandas as pd
import numpy as np

# 加载数据
log_path = '/Users/fengxiaoyu/Desktop/PDiagnose/平台数据集/log'
label_path = '/Users/fengxiaoyu/Desktop/PDiagnose/run_table.csv'
demo_labels = pd.read_csv(label_path, index_col=0)
processes = []
# 获取异常模板id
# templates
anomaly_templates = []
for _, row in template_counts.iterrows():
    if ('level:error' in row['EventTemplate'].lower()) or ('error code' in row['EventTemplate'].lower()):
        anomaly_templates.append(row['EventId'])
        
# 只创建一个实例
pid = 0
load = len(demo_labels[(demo_labels['data_type'] == 'test')])
analyzer = LogAnalysis(demo_labels[(demo_labels['data_type'] == 'test') ], log_path, pid, load, anomaly_templates, 'platform')
analyzer.analysis()
analyzer.save_res(f'{analyzer.dataset}/log/{analyzer.dataset}_log_{analyzer.id}.json')
# Out:
# 0 Time used:  3.890899181365967
# Save successfully!

# %%
load
# Out:
# 13
