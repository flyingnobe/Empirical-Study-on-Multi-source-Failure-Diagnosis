# %%
import pandas as pd
import numpy as np
import os

import json
from datetime import datetime
import pytz
import time

tz = pytz.timezone('Asia/Shanghai')
def ts_to_date(timestamp):
    return datetime.fromtimestamp(timestamp//1000, tz).strftime('%Y-%m-%d')

def time_to_ts(ctime):
    try:
        # 先尝试解析包含小时和分钟的格式
        timeArray = time.strptime(ctime, '%Y/%m/%d %H:%M')
    except ValueError:
        try:
            # 如果失败，尝试只有日期的格式
            timeArray = time.strptime(ctime, '%Y/%m/%d')
        except ValueError:
            # 如果仍然失败，记录错误或返回一个默认值
            print(f"Failed to parse date: {ctime}")
            return None
    return int(time.mktime(timeArray))

# %%
# 核密度估计 + 加权滑动平均 + 突变检测
from sklearn.neighbors import KernelDensity
from sklearn import preprocessing

class PDedection:
    def __init__(self, config=None):
        self.config = config
        if config is None:
            self.config = {}
            self.config['w1'] = 0.5
            self.config['w2'] = 0.2
            self.config['w3'] = 0.3
            self.config['threshold'] = 0.4
    
    def ked(self, win_list, test_list):
        win_list = np.array(win_list)
        test_list = np.array(test_list)
        res = []
        kde = KernelDensity(kernel="gaussian", bandwidth=0.5).fit(win_list[:, np.newaxis])
        res = 1 - np.exp(kde.score_samples(test_list[:, np.newaxis]))[0] # 样本的p值
        return np.array(res)

    def wma(self, win_list, test_list):
        # 待检测点包含在滑动窗口内
        win_list, test_list = list(win_list), list(test_list)
        res = []
        T = len(win_list)
        for i in range(len(test_list)):
            del win_list[0]
            win_list.append(test_list[i])
            wma = 2*sum([t*win_list[t-1] for t in range(1, T+1)])/(T*(T+1))
    #         wma = np.mean(win_list)

            res.append(np.abs(test_list[i]-wma))
        return np.array(res)

    def deviation(self, win_list, test_list):
        first_diff = np.diff(np.append(win_list[-1], test_list)) # 一阶差分
        res = []
        for i in range(len(test_list)):
            if first_diff[i] == 0:
                res.append(0)
            elif test_list[i] == 0:
                res.append(0)
            else:
                res.append(np.abs(first_diff[i]/test_list[i]))
        return np.array(res)

    # 需要手动设置阈值
    # config
    def detection(self, win_list, test_list):  
        min_max_scaler = preprocessing.MinMaxScaler()
        X_minMax = min_max_scaler.fit_transform(np.append(win_list, test_list)[:, np.newaxis]).flatten()
        win_list, test_list = X_minMax[: len(win_list)], X_minMax[len(win_list): ]
        scores = self.config['w1']*self.ked(
            win_list, test_list)+self.config['w2']*self.wma(
            win_list, test_list)+self.config['w3']*self.deviation(
            win_list, test_list)
        alarms = [i for i in range(len(scores)) if scores[i] > self.config['threshold']]
        result = {}
        result['alarm'] = alarms
        result['score'] = scores
        return result

# %%
from multiprocessing import Process
import json

# 指标异常信息提取
# 检测时间范围：故障时间段，
# 返回结果：异常KPI队列，包含全部的点 （时间戳，微服务，指标名称，异常分数）
class MetricAnomaly(Process):
    def __init__(self, cases, metric_path, data_dir, pid, load, dataset='gaia', config=None):
        super().__init__()
        self.dataset = dataset
        self.id = pid
        self.cases = cases.iloc[pid*load: (pid+1)*load]
        self.periods = ['2021-07-01_2021-07-15', '2021-07-15_2021-07-31']
        det_config = {}
        if self.dataset == 'gaia':
            self.metrics = self.get_all_metric_names(pd.read_csv(metric_path))
            det_config['w1'] = 0.5
            det_config['w2'] = 0.2
            det_config['w3'] = 0.3
            det_config['threshold'] = 0.4
        elif self.dataset == '21aiops':
#             self.metrics = [metric for metric in os.listdir(data_dir) if metric.endswith('.csv')]
            self.metrics = chosen_metrics
            det_config['w1'] = 0.7
            det_config['w2'] = 0.2
            det_config['w3'] = 0.1
            det_config['threshold'] = 1
        else:
            raise Exception('Unknow Dataset!')
        self.data_dir = data_dir
        self.detector = PDedection(det_config)
        if config is None:
            config = {}
            config['minute'] = 60000
            config['MIN_TRAIN_LENGTH'] = 5
            config['MIN_TEST_LENGTH'] = 1
        self.config = config
        self.res = dict(zip(list(self.cases.index), [[] for _ in range(len(self.cases))]))
        self.time_used = 0
    
    # 读取指标文件
    def read(self, metric):
        data = pd.read_csv(os.path.join(self.data_dir, metric))
        data.index = [ts_to_date(ts) for ts in data['timestamp']]
        return data
    
    # 获取所有的指标信息，筛去zookeeper、system、redis
    def get_all_metric_names(self, metrics_info):
        metric_names = []
        for index, row in metrics_info.iterrows():
            if row['name'].split('_')[0] in ['system', 'zookeeper', 'redis']: # 这三类略过
                continue
            for period in self.periods:
                metric_names.append('_'.join([row['name'], period+'.csv']))
        return metric_names
    
    def get_metric_events(self):
        # 减少文件读取次数
        for metric in self.metrics:
            if not os.path.exists(f'{self.data_dir}/{metric}'):
                continue
            metric_data = self.read(metric)
            start_time = time.time()
            for case_id, case in self.cases.iterrows():
                # 异常开始和故障结束后两分钟
                start_ts = time_to_ts(case['st_time'])
                end_ts = time_to_ts(case['ed_time'])+2*self.config['minute']
                win_start_ts = start_ts - 30*self.config['minute']
                win_data = metric_data[(metric_data['timestamp']>=win_start_ts)&
                                       (metric_data['timestamp']<start_ts)]
                test_data = metric_data[(metric_data['timestamp']>=start_ts)&
                                       (metric_data['timestamp']<end_ts)]
#                 print(len(win_data), len(test_data))
                if len(test_data) < self.config[
                    'MIN_TEST_LENGTH'] or len(win_data) < self.config[
                    'MIN_TRAIN_LENGTH']:
                    continue
                res = self.detector.detection(win_data['value'].values, test_data['value'].values)
                test_ts = test_data['timestamp'].values
                if self.dataset == 'gaia':
                    for i in range(len(res['alarm'])):
                        # （时间戳，微服务，指标名称，异常分数）
                        metric_splits = metric.split('_')
                        service = metric_splits[0]
                        name = '_'.join(metric_splits[2: -2])
                        self.res[case_id].append((int(test_ts[res['alarm'][i]]), service, name, 
                                                  res['score'][res['alarm'][i]]))
                elif self.dataset == '21aiops':
                    for i in range(len(res['alarm'])):
                        # （时间戳，微服务，指标名称，异常分数）
                        metric_splits = metric.split('+')
                        service = metric_splits[0]
                        name = metric_splits[1].split('.csv')[0]
                        self.res[case_id].append((int(test_ts[res['alarm'][i]]), service, name, 
                                                  res['score'][res['alarm'][i]]))
            end_time = time.time()
            self.time_used += (end_time - start_time)
    
    def save_res(self, savepath):
        with open(savepath, 'w') as f:
            json.dump(self.res, f)
        print(f'{self.id} Time used: ', self.time_used)
        print('Save successfully!')
    
    def run(self):
        self.get_metric_events()
#         print(self.res)
        self.save_res(f'{self.dataset}/metric/{self.dataset}_metric_{self.id}.json')
        with open(f'{self.dataset}/metric/time_used_{self.id}', 'w') as f:
            f.write(f'{self.time_used}')

# %%
# gaia 配置
metric_path = '/home/u2120210568/jupyterfiles/xiasibo/GAIA/data/metric_screening/metric.csv' # 筛选出的指标信息
data_dir = '/home/u2120210568/data/MicroSS/metric' # 指标数据保存的位置
# label_path = 'demo.csv' # 故障case的路径
label_path = '/home/u2120210568/multi_rca/case/gaia_resplit.csv'
demo_labels = pd.read_csv(label_path, index_col=0)
demo_labels = demo_labels[demo_labels['data_type']=='test']
processes = []
for pid in range(20):
    processes.append(MetricAnomaly(demo_labels, metric_path, data_dir, pid, 47))
    processes[-1].start()
    print(f'process {pid} starts...')
for pid in range(20):
    processes[pid].join()
    print(f'process {pid} ends.')
# demo_labels

# %%
def load(file):
    with open(file, 'r', encoding='utf-8') as f:
        data = json.load(f)
    return data

groundtruth_path = '../labs_optimize_21aiops/groundtruth_total/system_b' 
groundtruths = [file for file in os.listdir(groundtruth_path) if file.endswith('.json')] 
total_groundtruths = {} 
for groundtruth in groundtruths: 
    temp = dict(load(os.path.join(groundtruth_path, groundtruth)))
    date_ts = time_to_ts(groundtruth.split('.json')[0])//1000 
    for key in temp: 
        total_groundtruths[(key+date_ts)*1000] = temp[key]

def is_groundtruth(ts): 
    if ts in total_groundtruths.keys(): 
        return True 
    return False

# total_groundtruths
data_dir = '/home/u2120210568/jupyterfiles/xiasibo/GAIA/2021-aiops-lab/metric/screen_metrics'
services = set([file.split('+')[0] for file in os.listdir(data_dir) if file.endswith('.csv')])
chosen_metrics = set()
for key in total_groundtruths:
    for item in total_groundtruths[key]:
        metric = f'{item[1]}.csv'
        for service in services:
            chosen_metrics.add(f'{service}+{metric}')
len(chosen_metrics)

# %%
# chosen_metrics

# %%
# 21年挑战赛配置
metric_path = None # 没有筛选指标信息
data_dir = '/home/u2120210568/jupyterfiles/xiasibo/GAIA/2021-aiops-lab/metric/screen_metrics'
label_path = '/home/u2120210568/multi_rca/case/21aiops_resplit.csv'
demo_labels = pd.read_csv(label_path, index_col=0)
processes = []
for pid in range(10):
    processes.append(MetricAnomaly(demo_labels[demo_labels['data_type']=='test'], 
                                   metric_path, data_dir, pid, 8, '21aiops'))
    processes[-1].start()
    print(f'process {pid} starts...')
for pid in range(10):
    processes[pid].join()
    print(f'process {pid} ends.')

# %%
os.listdir(data_dir)[0]
data = pd.read_csv(os.path.join(data_dir, os.listdir(data_dir)[1]))
train_data = data.loc[: 30]
test_data = data.loc[30: ]
res= PDedection().detection(train_data['value'].values, test_data['value'].values)
res['score']

# %%
import os
import pandas as pd

full_list = os.listdir('/Users/fengxiaoyu/Desktop/PDiagnose/22aiops/metric')
metric_list = []
for metric in full_list:
    if metric[-5:] != 'Store':
        metric_list.append(metric)
metric_list

# %%
import json
from datetime import datetime
import pytz
import time
import numpy as np

tz = pytz.timezone('Asia/Shanghai')
def ts_to_date(timestamp):
    return datetime.fromtimestamp(timestamp//1000, tz).strftime('%Y-%m-%d')

def time_to_ts(ctime):
    try:
        # 先尝试解析包含小时和分钟的格式
        timeArray = time.strptime(ctime, '%Y/%m/%d %H:%M')
    except ValueError:
        try:
            # 如果失败，尝试只有日期的格式
            timeArray = time.strptime(ctime, '%Y/%m/%d')
        except ValueError:
            # 如果仍然失败，记录错误或返回一个默认值
            print(f"Failed to parse date: {ctime}")
            return None
    return int(time.mktime(timeArray))


# 核密度估计 + 加权滑动平均 + 突变检测
from sklearn.neighbors import KernelDensity
from sklearn import preprocessing

class PDedection:
    def __init__(self, config=None):
        self.config = config
        if config is None:
            self.config = {}
            self.config['w1'] = 0.5
            self.config['w2'] = 0.2
            self.config['w3'] = 0.3
            self.config['threshold'] = 0.4
    
    def ked(self, win_list, test_list):
        win_list = np.array(win_list)
        test_list = np.array(test_list)
        res = []
        kde = KernelDensity(kernel="gaussian", bandwidth=0.5).fit(win_list[:, np.newaxis])
        res = 1 - np.exp(kde.score_samples(test_list[:, np.newaxis]))[0] # 样本的p值
        return np.array(res)

    def wma(self, win_list, test_list):
        # 待检测点包含在滑动窗口内
        win_list, test_list = list(win_list), list(test_list)
        res = []
        T = len(win_list)
        for i in range(len(test_list)):
            del win_list[0]
            win_list.append(test_list[i])
            wma = 2*sum([t*win_list[t-1] for t in range(1, T+1)])/(T*(T+1))
            res.append(np.abs(test_list[i]-wma))
        return np.array(res)

    def deviation(self, win_list, test_list):
        first_diff = np.diff(np.append(win_list[-1], test_list)) # 一阶差分
        res = []
        for i in range(len(test_list)):
            if first_diff[i] == 0:
                res.append(0)
            elif test_list[i] == 0:
                res.append(0)
            else:
                res.append(np.abs(first_diff[i]/test_list[i]))
        return np.array(res)

    # 需要手动设置阈值
    # config
    def detection(self, win_list, test_list):  
        min_max_scaler = preprocessing.MinMaxScaler()
        X_minMax = min_max_scaler.fit_transform(np.append(win_list, test_list)[:, np.newaxis]).flatten()
        win_list, test_list = X_minMax[: len(win_list)], X_minMax[len(win_list): ]
        scores = self.config['w1']*self.ked(
            win_list, test_list)+self.config['w2']*self.wma(
            win_list, test_list)+self.config['w3']*self.deviation(
            win_list, test_list)
        alarms = [i for i in range(len(scores)) if scores[i] > self.config['threshold']]
        result = {}
        result['alarm'] = alarms
        result['score'] = scores
        return result

# 指标异常信息提取
# 检测时间范围：故障时间段，
# 返回结果：异常KPI队列，包含全部的点 （时间戳，微服务，指标名称，异常分数）
class MetricAnomaly():
    def __init__(self, cases, metric_path, data_dir, pid, load, dataset='gaia', config=None):
        super().__init__()
        self.dataset = dataset
        self.id = pid
        self.cases = cases.iloc[pid*load: (pid+1)*load]
        self.periods = ['2021-07-01_2021-07-15', '2021-07-15_2021-07-31']
        det_config = {}
        if self.dataset == 'gaia':
            self.metrics = self.get_all_metric_names(pd.read_csv(metric_path))
            det_config['w1'] = 0.5
            det_config['w2'] = 0.2
            det_config['w3'] = 0.3
            det_config['threshold'] = 0.4
        elif self.dataset == '21aiops':
            self.metrics = chosen_metrics
            det_config['w1'] = 0.7
            det_config['w2'] = 0.2
            det_config['w3'] = 0.1
            det_config['threshold'] = 1
        elif self.dataset == '22aiops':
            self.metrics = metric_list
            det_config['w1'] = 0.6
            det_config['w2'] = 0.2
            det_config['w3'] = 0.5
            det_config['threshold'] = 0.6
        else:
            raise Exception('Unknow Dataset!')
        self.data_dir = data_dir
        self.detector = PDedection(det_config)
        if config is None:
            config = {}
            config['minute'] = 60000
            config['MIN_TRAIN_LENGTH'] = 5
            config['MIN_TEST_LENGTH'] = 1
        self.config = config
        self.res = dict(zip(list(self.cases.index), [[] for _ in range(len(self.cases))]))
        self.time_used = 0
    
    # 读取指标文件
    def read(self, metric):
        data = pd.read_csv(os.path.join(self.data_dir, metric))
        data.index = [ts_to_date(ts) for ts in data['timestamp']]
        return data
    
    # 获取所有的指标信息，筛去zookeeper、system、redis
    def get_all_metric_names(self, metrics_info):
        metric_names = []
        for index, row in metrics_info.iterrows():
            if row['name'].split('_')[0] in ['system', 'zookeeper', 'redis']: # 这三类略过
                continue
            for period in self.periods:
                metric_names.append('_'.join([row['name'], period+'.csv']))
        return metric_names
    
    def get_metric_events(self):
        # 减少文件读取次数
        for metric in self.metrics:
            if not os.path.exists(f'{self.data_dir}/{metric}'):
                continue
            metric_data = self.read(metric)
            start_time = time.time()
            for case_id, case in self.cases.iterrows():
                # 异常开始和故障结束后两分钟
                start_ts = time_to_ts(case['start'])
                end_ts = time_to_ts(case['end'])+2*self.config['minute']
                win_start_ts = start_ts - 30*self.config['minute']
                win_data = metric_data[(metric_data['timestamp']>=win_start_ts)&
                                       (metric_data['timestamp']<start_ts)]
                test_data = metric_data[(metric_data['timestamp']>=start_ts)&
                                       (metric_data['timestamp']<end_ts)]
                if len(test_data) < self.config[
                    'MIN_TEST_LENGTH'] or len(win_data) < self.config[
                    'MIN_TRAIN_LENGTH']:
                    continue
                res = self.detector.detection(win_data['value'].values, test_data['value'].values)
                test_ts = test_data['timestamp'].values
                if self.dataset == 'gaia':
                    for i in range(len(res['alarm'])):
                        # （时间戳，微服务，指标名称，异常分数）
                        metric_splits = metric.split('_')
                        service = metric_splits[0]
                        name = '_'.join(metric_splits[2: -2])
                        self.res[case_id].append((int(test_ts[res['alarm'][i]]), service, name, 
                                                  res['score'][res['alarm'][i]]))
                elif self.dataset == '21aiops':
                    for i in range(len(res['alarm'])):
                        # （时间戳，微服务，指标名称，异常分数）
                        metric_splits = metric.split('+')
                        service = metric_splits[0]
                        name = metric_splits[1].split('.csv')[0]
                        self.res[case_id].append((int(test_ts[res['alarm'][i]]), service, name, 
                                                  res['score'][res['alarm'][i]]))
                elif self.dataset == '22aiops':
                    for i in range(len(res['alarm'])):
                        # （时间戳，微服务，指标名称，异常分数）
                        metric_splits = metric.split('+')
                        service = metric_splits[0]
                        name = metric_splits[1][:-4]
                        print(name)
                        self.res[case_id].append((int(test_ts[res['alarm'][i]]), service, name, 
                                                  res['score'][res['alarm'][i]]))

            end_time = time.time()
            self.time_used += (end_time - start_time)
    
    def save_res(self, savepath):
        with open(savepath, 'w') as f:
            json.dump(self.res, f)
        print(f'{self.id} Time used: ', self.time_used)
        print('Save successfully!')
    
    def run(self):
        self.get_metric_events()
        self.save_res(f'{self.dataset}/result/metric/{self.dataset}_metric_{self.id}.json')
        with open(f'{self.dataset}/metric/time_used_{self.id}', 'w') as f:
            f.write(f'{self.time_used}')
    
# 22年挑战赛配置
metric_path = None # 没有筛选指标信息
data_dir = '/Users/fengxiaoyu/Desktop/PDiagnose/22aiops/metric'
label_path = '/Users/fengxiaoyu/Desktop/PDiagnose/22AIOps_run_table.csv'
demo_labels = pd.read_csv(label_path, index_col=0)
processes = []
# 只创建一个实例
pid = 0
load = len(demo_labels[(demo_labels['type'] == 'test') & (demo_labels['level'] == 'pod')])
analyzer = MetricAnomaly(demo_labels[(demo_labels['type'] == 'test') & (demo_labels['level'] == 'pod')], metric_path ,data_dir , pid, load, '22aiops')
analyzer.run()

# %%
from metricanomaly import MetricAnomaly
import pandas as pd

# 22年挑战赛配置
metric_path = None # 没有筛选指标信息
data_dir = '/Users/fengxiaoyu/Desktop/PDiagnose/22aiops/metric'
label_path = '/Users/fengxiaoyu/Desktop/PDiagnose/22AIOps_run_table.csv'
demo_labels = pd.read_csv(label_path, index_col=0)
processes = []
for pid in range(12):
    processes.append(MetricAnomaly(demo_labels[(demo_labels['type'] == 'test') & (demo_labels['level'] == 'pod')], metric_path, data_dir, pid, 1, '22aiops'))
    processes[-1].start()
    print(f'process {pid} starts...')
for pid in range(12):
    processes[pid].join()
    print(f'process {pid} ends.')

# %%
from metricanomaly import MetricAnomaly
import pandas as pd

# 平台配置
metric_path = None # 没有筛选指标信息
data_dir = '/Users/fengxiaoyu/Desktop/PDiagnose/平台数据集/metric_1'
label_path = '/Users/fengxiaoyu/Desktop/PDiagnose/run_table.csv'
demo_labels = pd.read_csv(label_path, index_col=0)
processes = []
for pid in range(10):
    processes.append(MetricAnomaly(demo_labels[(demo_labels['data_type'] == 'test')], metric_path, data_dir, pid, 8, 'platform'))
    processes[-1].start()
    print(f'process {pid} starts...')
for pid in range(10):
    processes[pid].join()
    print(f'process {pid} ends.')
# Out:
# shippingservice2-0+kpi_container_network_receive_packets.csv
# cartservice-2+kpi_container_cpu_cfs_throttled_seconds.csv
# productcatalogservice-2+kpi_container_memory_failcnt.csv
# frontend-1+kpi_container_spec_cpu_shares.csv
# frontend-1+kpi_container_fs_writes_MB.csv
# frontend2-0+kpi_container_network_transmit_errors.csv
# currencyservice-2+kpi_container_memory_rss.csv
# recommendationservice2-0+kpi_container_spec_memory_limit_MB.csv
# cartservice-2+kpi_container_network_receive_MB.csv
# cartservice2-0+kpi_container_network_transmit_packets.csv
# productcatalogservice-1+kpi_container_network_receive_packets_dropped.csv
# shippingservice2-0+kpi_container_fs_inodes.csv
# adservice2-0+kpi_container_memory_working_set_MB.csv
# recommendationservice-2+kpi_container_threads_max.csv
# productcatalogservice-0+kpi_container_network_receive_errors.csv
# adservice-0+kpi_container_threads_max.csv
# paymentservice-2+kpi_container_network_transmit_packets_dropped.csv
# emailservice2-0+kpi_container_fs_writes.csv
# frontend-2+kpi_container_network_receive_packets.csv
# currencyservice-0+kpi_container_threads.csv
# recommendationservice-2+kpi_container_memory_failcnt.csv
# productcatalogservice-2+kpi_container_spec_cpu_shares.csv
# recommendationservice-2+kpi_container_spec_cpu_quota.csv
# recommendationservice-0+kpi_container_threads.csv
# checkoutservice-2+kpi_container_threads_max.csv
# recommendationservice-0+kpi_container_fs_writes_merged.csv
# checkoutservice-2+kpi_container_memory_max_usage_MB.csv
# emailservice-2+kpi_container_sockets.csv
# recommendationservice2-0+kpi_container_cpu_cfs_throttled_seconds.csv
# shippingservice2-0+kpi_container_last_seen.csv
# productcatalogservice-0+kpi_container_network_receive_MB.csv
# shippingservice-2+kpi_container_fs_writes.csv
# frontend-2+kpi_container_fs_reads_MB.csv
# adservice-2+kpi_container_memory_working_set_MB.csv
# frontend2-0+kpi_container_cpu_cfs_throttled_periods.csv
# adservice-2+kpi_container_fs_io_time_seconds.csv
# checkoutservice2-0+kpi_container_network_receive_packets.csv
# adservice2-0+kpi_container_network_receive_packets_dropped.csv
# currencyservice-1+kpi_container_fs_reads_MB.csv
# frontend-0+kpi_container_fs_reads.csv
# shippingservice2-0+kpi_container_file_descriptors.csv
# recommendationservice-0+kpi_container_memory_usage_MB.csv
# emailservice-2+kpi_container_memory_working_set_MB.csv
# frontend-1+kpi_container_fs_write_seconds.csv
# frontend-0+kpi_container_network_transmit_errors.csv
# adservice-2+kpi_container_memory_rss.csv
# productcatalogservice-0+kpi_container_fs_writes_merged.csv
# checkoutservice-0+kpi_container_sockets.csv
# cartservice2-0+kpi_container_cpu_cfs_throttled_periods.csv
# cartservice-0+kpi_container_fs_io_time_weighted_seconds.csv
# paymentservice2-0+kpi_container_fs_io_time_seconds.csv
# currencyservice-0+kpi_container_fs_write_seconds.csv
# productcatalogservice-2+kpi_container_spec_cpu_quota.csv
# frontend-2+kpi_container_fs_inodes_free.csv
# currencyservice2-0+kpi_container_start_time_seconds.csv
# recommendationservice2-0+kpi_container_cpu_system_seconds.csv
# productcatalogservice-0+kpi_container_tasks_state.csv
# adservice2-0+kpi_container_start_time_seconds.csv
# currencyservice-1+kpi_container_fs_sector_writes.csv
# adservice-0+kpi_container_fs_sector_reads.csv
# recommendationservice-1+kpi_container_fs_read_seconds.csv
# emailservice2-0+kpi_container_spec_memory_swap_limit_MB.csv
# shippingservice2-0+kpi_container_memory_usage_MB.csv
# adservice-1+kpi_container_network_receive_packets.csv
# frontend-0+kpi_container_network_transmit_packets.csv
# recommendationservice-2+kpi_container_ulimits_soft.csv
# productcatalogservice-1+kpi_container_cpu_usage_seconds.csv
# paymentservice-0+kpi_container_ulimits_soft.csv
# shippingservice-0+kpi_container_spec_cpu_period.csv
# shippingservice2-0+kpi_container_cpu_system_seconds.csv
# paymentservice2-0+kpi_container_cpu_cfs_periods.csv
# currencyservice2-0+kpi_container_spec_cpu_shares.csv
# shippingservice-2+kpi_container_fs_limit_MB.csv
# frontend-0+kpi_container_fs_sector_writes.csv
# currencyservice-0+kpi_container_spec_cpu_shares.csv
# adservice2-0+kpi_container_fs_reads_merged.csv
# cartservice2-0+kpi_container_cpu_cfs_throttled_seconds.csv
# emailservice-2+kpi_container_network_receive_packets_dropped.csv
# currencyservice2-0+kpi_container_ulimits_soft.csv
# emailservice-0+kpi_container_memory_failures.csv
# productcatalogservice-0+kpi_container_threads.csv
# frontend-0+kpi_container_spec_memory_reservation_limit_MB.csv
# adservice-0+kpi_container_cpu_usage_seconds.csv
# checkoutservice-1+kpi_container_memory_max_usage_MB.csv
# adservice-2+kpi_container_network_transmit_packets_dropped.csv
# checkoutservice-0+kpi_container_fs_sector_reads.csv
# recommendationservice2-0+kpi_container_cpu_cfs_throttled_periods.csv
# adservice2-0+kpi_container_memory_mapped_file.csv
# frontend-0+kpi_container_memory_swap.csv
# currencyservice2-0+kpi_container_memory_mapped_file.csv
# frontend-1+kpi_container_network_receive_errors.csv
# adservice2-0+kpi_container_threads_max.csv
# recommendationservice-1+kpi_container_network_receive_packets_dropped.csv
# frontend2-0+kpi_container_threads.csv
# currencyservice-0+kpi_container_network_receive_packets.csv
# currencyservice-0+kpi_container_fs_io_time_weighted_seconds.csv
# checkoutservice-2+kpi_container_fs_write_seconds.csv
# cartservice-1+kpi_container_fs_writes_MB.csv
# paymentservice2-0+kpi_container_spec_cpu_period.csv
# shippingservice-1+kpi_container_memory_cache.csv
# shippingservice-0+kpi_container_cpu_cfs_periods.csv
# shippingservice-1+kpi_container_fs_inodes.csv
# frontend2-0+kpi_container_cpu_cfs_throttled_seconds.csv
# currencyservice-0+kpi_container_network_receive_MB.csv
# currencyservice-2+kpi_container_tasks_state.csv
# emailservice-0+kpi_container_fs_io_current.csv
# paymentservice-0+kpi_container_threads_max.csv
# checkoutservice2-0+kpi_container_memory_usage_MB.csv
# productcatalogservice2-0+kpi_container_fs_usage_MB.csv
# currencyservice-0+kpi_container_network_receive_packets_dropped.csv
# shippingservice-1+kpi_container_memory_working_set_MB.csv
# frontend-1+kpi_container_tasks_state.csv
# shippingservice-1+kpi_container_last_seen.csv
# recommendationservice-0+kpi_container_spec_memory_swap_limit_MB.csv
# cartservice-2+kpi_container_network_receive_errors.csv
# shippingservice-0+kpi_container_ulimits_soft.csv
# paymentservice2-0+kpi_container_network_receive_packets_dropped.csv
# checkoutservice2-0+kpi_container_fs_writes.csv
# shippingservice-2+kpi_container_network_receive_MB.csv
# paymentservice-2+kpi_container_file_descriptors.csv
# emailservice2-0+kpi_container_fs_limit_MB.csv
# frontend-1+kpi_container_threads.csv
# recommendationservice2-0+kpi_container_cpu_load_average_10s.csv
# paymentservice-2+kpi_container_memory_failures.csv
# shippingservice-1+kpi_container_fs_usage_MB.csv
# productcatalogservice-1+kpi_container_memory_swap.csv
# cartservice-2+kpi_container_cpu_cfs_throttled_periods.csv
# frontend-0+kpi_container_cpu_user_seconds.csv
# paymentservice-1+kpi_container_memory_cache.csv
# currencyservice-2+kpi_container_spec_memory_reservation_limit_MB.csv
# adservice-2+kpi_container_fs_inodes_free.csv
# paymentservice-1+kpi_container_fs_sector_reads.csv
# currencyservice-1+kpi_container_cpu_user_seconds.csv
# paymentservice-1+kpi_container_fs_io_time_seconds.csv
# adservice2-0+kpi_container_network_receive_errors.csv
# currencyservice-2+kpi_container_network_transmit_errors.csv
# emailservice-0+kpi_container_threads_max.csv
# shippingservice-2+kpi_container_fs_write_seconds.csv
# checkoutservice-0+kpi_container_memory_max_usage_MB.csv
# paymentservice2-0+kpi_container_network_transmit_packets.csv
# adservice-0+kpi_container_network_receive_packets.csv
# emailservice2-0+kpi_container_cpu_load_average_10s.csv
# recommendationservice-1+kpi_container_file_descriptors.csv
# adservice-2+kpi_container_file_descriptors.csv
# productcatalogservice-0+kpi_container_cpu_cfs_throttled_periods.csv
# emailservice-0+kpi_container_spec_memory_reservation_limit_MB.csv
# frontend-2+kpi_container_network_receive_MB.csv
# productcatalogservice-0+kpi_container_network_transmit_packets.csv
# productcatalogservice-2+kpi_container_memory_rss.csv
# checkoutservice-0+kpi_container_memory_failcnt.csv
# productcatalogservice-2+kpi_container_ulimits_soft.csv
# frontend-1+kpi_container_cpu_cfs_throttled_periods.csv
# paymentservice-2+kpi_container_cpu_cfs_throttled_seconds.csv
# shippingservice2-0+kpi_container_threads.csv
# productcatalogservice-1+kpi_container_fs_io_current.csv
# frontend-2+kpi_container_cpu_usage_seconds.csv
# shippingservice-0+kpi_container_memory_working_set_MB.csv
# recommendationservice2-0+kpi_container_fs_writes_merged.csv
# checkoutservice-1+kpi_container_fs_inodes_free.csv
# checkoutservice-1+kpi_container_memory_swap.csv
# paymentservice-1+kpi_container_network_transmit_MB.csv
# frontend2-0+kpi_container_last_seen.csv
# recommendationservice-0+kpi_container_tasks_state.csv
# cartservice2-0+kpi_container_memory_swap.csv
# adservice-2+kpi_container_tasks_state.csv
# productcatalogservice-1+kpi_container_file_descriptors.csv
# frontend2-0+kpi_container_memory_failures.csv
# shippingservice-2+kpi_container_memory_failcnt.csv
# cartservice-0+kpi_container_memory_usage_MB.csv
# frontend2-0+kpi_container_cpu_system_seconds.csv
# recommendationservice-0+kpi_container_network_receive_packets_dropped.csv
# currencyservice2-0+kpi_container_fs_writes_merged.csv
# currencyservice-1+kpi_container_network_receive_packets.csv
# adservice-1+kpi_container_memory_cache.csv
# adservice2-0+kpi_container_cpu_load_average_10s.csv
# shippingservice2-0+kpi_container_threads_max.csv
# paymentservice-1+kpi_container_fs_writes.csv
# recommendationservice-1+kpi_container_network_transmit_packets_dropped.csv
# adservice-2+kpi_container_fs_io_time_weighted_seconds.csv
# checkoutservice-2+kpi_container_cpu_system_seconds.csv
# paymentservice-2+kpi_container_network_receive_errors.csv
# paymentservice2-0+kpi_container_fs_reads_merged.csv
# adservice-2+kpi_container_network_transmit_errors.csv
# shippingservice-2+kpi_container_spec_cpu_quota.csv
# currencyservice2-0+kpi_container_network_receive_errors.csv
# checkoutservice-1+kpi_container_cpu_cfs_throttled_seconds.csv
# adservice2-0+kpi_container_fs_write_seconds.csv
# currencyservice-1+kpi_container_network_receive_packets_dropped.csv
# recommendationservice-1+kpi_container_memory_swap.csv
# cartservice-0+kpi_container_fs_write_seconds.csv
# checkoutservice-0+kpi_container_tasks_state.csv
# recommendationservice2-0+kpi_container_fs_sector_reads.csv
# cartservice-2+kpi_container_fs_reads_MB.csv
# checkoutservice-2+kpi_container_spec_cpu_shares.csv
# paymentservice2-0+kpi_container_fs_inodes_free.csv
# adservice2-0+kpi_container_cpu_cfs_periods.csv
# recommendationservice2-0+kpi_container_fs_usage_MB.csv
# adservice-0+kpi_container_ulimits_soft.csv
# shippingservice-0+kpi_container_cpu_cfs_throttled_seconds.csv
# paymentservice-1+kpi_container_fs_reads_MB.csv
# frontend2-0+kpi_container_fs_inodes.csv
# paymentservice2-0+kpi_container_threads_max.csv
# cartservice-2+kpi_container_sockets.csv
# currencyservice-1+kpi_container_memory_failures.csv
# currencyservice-2+kpi_container_fs_sector_reads.csv
# emailservice-1+kpi_container_spec_cpu_shares.csv
# checkoutservice-0+kpi_container_spec_cpu_quota.csv
# emailservice-1+kpi_container_fs_reads_MB.csv
# adservice2-0+kpi_container_spec_cpu_period.csv
# paymentservice-0+kpi_container_network_transmit_MB.csv
# shippingservice-0+kpi_container_fs_reads_merged.csv
# currencyservice-1+kpi_container_network_transmit_packets.csv
# checkoutservice-0+kpi_container_fs_reads.csv
# adservice-0+kpi_container_spec_memory_swap_limit_MB.csv
# productcatalogservice2-0+kpi_container_fs_sector_reads.csv
# productcatalogservice-1+kpi_container_fs_io_time_seconds.csv
# cartservice-1+kpi_container_cpu_usage_seconds.csv
# shippingservice-2+kpi_container_fs_read_seconds.csv
# adservice-2+kpi_container_spec_cpu_shares.csv
# currencyservice2-0+kpi_container_fs_limit_MB.csv
# productcatalogservice-2+kpi_container_threads_max.csv
# frontend2-0+kpi_container_memory_swap.csv
# shippingservice2-0+kpi_container_spec_memory_reservation_limit_MB.csv
# emailservice-2+kpi_container_memory_mapped_file.csv
# productcatalogservice2-0+kpi_container_network_transmit_errors.csv
# currencyservice-2+kpi_container_fs_io_current.csv
# emailservice-2+kpi_container_fs_write_seconds.csv
# recommendationservice-2+kpi_container_network_receive_MB.csv
# emailservice-1+kpi_container_memory_failcnt.csv
# productcatalogservice-0+kpi_container_network_receive_packets_dropped.csv
# cartservice2-0+kpi_container_spec_cpu_shares.csv
# checkoutservice-1+kpi_container_cpu_cfs_throttled_periods.csv
# checkoutservice2-0+kpi_container_threads.csv
# emailservice-2+kpi_container_start_time_seconds.csv
# adservice-1+kpi_container_threads.csv
# cartservice-2+kpi_container_fs_reads.csv
# paymentservice-2+kpi_container_last_seen.csv
# emailservice-0+kpi_container_fs_inodes_free.csv
# recommendationservice-0+kpi_container_fs_inodes.csv
# cartservice-0+kpi_container_memory_swap.csv
# checkoutservice2-0+kpi_container_fs_sector_writes.csv
# shippingservice2-0+kpi_container_fs_reads.csv
# checkoutservice-2+kpi_container_network_receive_packets_dropped.csv
# paymentservice2-0+kpi_container_network_transmit_MB.csv
# adservice-1+kpi_container_fs_reads_MB.csv
# recommendationservice-2+kpi_container_memory_working_set_MB.csv
# cartservice-1+kpi_container_fs_sector_writes.csv
# frontend-2+kpi_container_fs_io_time_weighted_seconds.csv
# shippingservice-0+kpi_container_cpu_cfs_throttled_periods.csv
# checkoutservice-0+kpi_container_spec_memory_reservation_limit_MB.csv
# cartservice-1+kpi_container_cpu_user_seconds.csv
# emailservice2-0+kpi_container_spec_memory_limit_MB.csv
# paymentservice-2+kpi_container_network_transmit_MB.csv
# paymentservice-2+kpi_container_tasks_state.csv
# paymentservice2-0+kpi_container_fs_io_current.csv
# emailservice-1+kpi_container_fs_io_time_weighted_seconds.csv
# currencyservice-0+kpi_container_threads_max.csv
# productcatalogservice-0+kpi_container_fs_sector_reads.csv
# shippingservice-2+kpi_container_fs_io_time_weighted_seconds.csv
# shippingservice-0+kpi_container_fs_reads.csv
# currencyservice-2+kpi_container_fs_inodes_free.csv
# cartservice-1+kpi_container_tasks_state.csv
# cartservice-1+kpi_container_fs_read_seconds.csv
# paymentservice-2+kpi_container_fs_inodes.csv
# paymentservice-0+kpi_container_network_receive_MB.csv
# recommendationservice-0+kpi_container_last_seen.csv
# checkoutservice2-0+kpi_container_cpu_user_seconds.csv
# paymentservice-2+kpi_container_cpu_usage_seconds.csv
# frontend-0+kpi_container_memory_failures.csv
# paymentservice-0+kpi_container_memory_rss.csv
# currencyservice-1+kpi_container_fs_io_time_seconds.csv
# frontend-1+kpi_container_network_transmit_errors.csv
# productcatalogservice-0+kpi_container_cpu_cfs_throttled_seconds.csv
# emailservice-1+kpi_container_spec_cpu_quota.csv
# checkoutservice2-0+kpi_container_fs_limit_MB.csv
# emailservice2-0+kpi_container_fs_writes_MB.csv
# frontend2-0+kpi_container_spec_memory_reservation_limit_MB.csv
# emailservice2-0+kpi_container_memory_usage_MB.csv
# emailservice-2+kpi_container_tasks_state.csv
# productcatalogservice-1+kpi_container_fs_io_time_weighted_seconds.csv
# paymentservice-2+kpi_container_cpu_cfs_throttled_periods.csv
# adservice2-0+kpi_container_spec_memory_limit_MB.csv
# frontend-1+kpi_container_cpu_cfs_throttled_seconds.csv
# emailservice-2+kpi_container_network_transmit_packets.csv
# currencyservice-2+kpi_container_spec_memory_limit_MB.csv
# currencyservice-0+kpi_container_fs_writes.csv
# recommendationservice-0+kpi_container_fs_writes_MB.csv
# shippingservice2-0+kpi_container_fs_sector_writes.csv
# shippingservice2-0+kpi_container_start_time_seconds.csv
# recommendationservice-2+kpi_container_fs_io_time_weighted_seconds.csv
# checkoutservice2-0+kpi_container_cpu_cfs_throttled_seconds.csv
# adservice2-0+kpi_container_cpu_system_seconds.csv
# recommendationservice2-0+kpi_container_start_time_seconds.csv
# adservice-2+kpi_container_spec_memory_limit_MB.csv
# paymentservice-2+kpi_container_fs_writes_MB.csv
# currencyservice2-0+kpi_container_cpu_system_seconds.csv
# emailservice2-0+kpi_container_network_transmit_errors.csv
# cartservice-1+kpi_container_fs_reads_merged.csv
# shippingservice2-0+kpi_container_memory_failcnt.csv
# checkoutservice-2+kpi_container_threads.csv
# cartservice-1+kpi_container_fs_usage_MB.csv
# recommendationservice-2+kpi_container_fs_io_time_seconds.csv
# productcatalogservice-1+kpi_container_memory_failures.csv
# emailservice-1+kpi_container_network_receive_packets_dropped.csv
# paymentservice-2+kpi_container_fs_usage_MB.csv
# emailservice-1+kpi_container_fs_reads.csv
# productcatalogservice-2+kpi_container_fs_sector_reads.csv
# recommendationservice2-0+kpi_container_memory_mapped_file.csv
# emailservice-2+kpi_container_network_transmit_errors.csv
# emailservice-2+kpi_container_fs_usage_MB.csv
# cartservice-1+kpi_container_fs_io_time_weighted_seconds.csv
# shippingservice2-0+kpi_container_memory_mapped_file.csv
# currencyservice-1+kpi_container_spec_memory_reservation_limit_MB.csv
# emailservice-0+kpi_container_threads.csv
# recommendationservice-2+kpi_container_network_receive_packets_dropped.csv
# frontend-2+kpi_container_memory_failures.csv
# recommendationservice2-0+kpi_container_fs_inodes.csv
# frontend-1+kpi_container_fs_sector_reads.csv
# recommendationservice-2+kpi_container_sockets.csv
# emailservice-2+kpi_container_last_seen.csv
# paymentservice-2+kpi_container_fs_io_current.csv
# adservice2-0+kpi_container_memory_rss.csv
# shippingservice2-0+kpi_container_memory_working_set_MB.csv
# recommendationservice2-0+kpi_container_last_seen.csv
# emailservice-2+kpi_container_fs_inodes.csv
# shippingservice-1+kpi_container_memory_usage_MB.csv
# currencyservice2-0+kpi_container_fs_reads_MB.csv
# frontend-2+kpi_container_cpu_load_average_10s.csv
# cartservice-2+kpi_container_memory_cache.csv
# emailservice-2+kpi_container_fs_writes_merged.csv
# checkoutservice2-0+kpi_container_network_transmit_packets_dropped.csv
# currencyservice-2+kpi_container_sockets.csv
# paymentservice-0+kpi_container_fs_io_time_seconds.csv
# shippingservice-2+kpi_container_fs_writes_MB.csv
# emailservice-0+kpi_container_spec_memory_swap_limit_MB.csv
# cartservice-1+kpi_container_fs_writes.csv
# emailservice-1+kpi_container_fs_limit_MB.csv
# emailservice-1+kpi_container_memory_working_set_MB.csv
# adservice-1+kpi_container_network_transmit_packets_dropped.csv
# checkoutservice-2+kpi_container_fs_io_current.csv
# adservice-1+kpi_container_memory_working_set_MB.csv
# cartservice-2+kpi_container_fs_limit_MB.csv
# currencyservice-1+kpi_container_network_receive_MB.csv
# emailservice-0+kpi_container_network_receive_packets.csv
# checkoutservice2-0+kpi_container_fs_io_current.csv
# recommendationservice-0+kpi_container_memory_working_set_MB.csv
# paymentservice-1+kpi_container_fs_limit_MB.csv
# frontend-2+kpi_container_spec_memory_swap_limit_MB.csv
# productcatalogservice-1+kpi_container_memory_rss.csv
# recommendationservice-1+kpi_container_spec_memory_limit_MB.csv
# shippingservice2-0+kpi_container_cpu_user_seconds.csv
# shippingservice2-0+kpi_container_spec_cpu_quota.csv
# currencyservice-0+kpi_container_spec_memory_swap_limit_MB.csv
# emailservice-0+kpi_container_spec_memory_limit_MB.csv
# productcatalogservice-2+kpi_container_network_transmit_packets.csv
# checkoutservice-0+kpi_container_spec_cpu_shares.csv
# emailservice-0+kpi_container_memory_cache.csv
# adservice-1+kpi_container_fs_limit_MB.csv
# paymentservice-1+kpi_container_fs_inodes_free.csv
# recommendationservice2-0+kpi_container_tasks_state.csv
# cartservice-0+kpi_container_spec_memory_reservation_limit_MB.csv
# frontend-2+kpi_container_spec_memory_limit_MB.csv
# shippingservice-2+kpi_container_fs_io_current.csv
# paymentservice-1+kpi_container_spec_memory_swap_limit_MB.csv
# cartservice-0+kpi_container_fs_writes_merged.csv
# checkoutservice-0+kpi_container_fs_usage_MB.csv
# recommendationservice-1+kpi_container_cpu_cfs_periods.csv
# frontend-2+kpi_container_fs_io_time_seconds.csv
# adservice2-0+kpi_container_fs_writes_merged.csv
# emailservice2-0+kpi_container_memory_rss.csv
# emailservice-0+kpi_container_network_transmit_packets.csv
# productcatalogservice-0+kpi_container_last_seen.csv
# paymentservice2-0+kpi_container_fs_read_seconds.csv
# recommendationservice2-0+kpi_container_memory_working_set_MB.csv
# checkoutservice2-0+kpi_container_network_transmit_MB.csv
# paymentservice-0+kpi_container_network_receive_packets.csv
# productcatalogservice-2+kpi_container_network_receive_packets_dropped.csv
# recommendationservice-1+kpi_container_spec_cpu_period.csv
# productcatalogservice-2+kpi_container_cpu_usage_seconds.csv
# emailservice-1+kpi_container_fs_writes.csv
# shippingservice-2+kpi_container_fs_reads_merged.csv
# checkoutservice2-0+kpi_container_fs_reads.csv
# paymentservice2-0+kpi_container_memory_rss.csv
# cartservice-2+kpi_container_spec_cpu_quota.csv
# recommendationservice2-0+kpi_container_spec_memory_reservation_limit_MB.csv
# adservice-0+kpi_container_spec_cpu_shares.csv
# shippingservice-0+kpi_container_fs_read_seconds.csv
# checkoutservice-0+kpi_container_network_receive_packets_dropped.csv
# recommendationservice-1+kpi_container_cpu_load_average_10s.csv
# recommendationservice2-0+kpi_container_memory_max_usage_MB.csv
# cartservice-2+kpi_container_fs_inodes.csv
# emailservice-0+kpi_container_cpu_load_average_10s.csv
# paymentservice-0+kpi_container_memory_failcnt.csv
# frontend-0+kpi_container_fs_writes.csv
# currencyservice2-0+kpi_container_fs_sector_reads.csv
# paymentservice-2+kpi_container_fs_sector_writes.csv
# currencyservice-0+kpi_container_fs_sector_reads.csv
# currencyservice-2+kpi_container_cpu_load_average_10s.csv
# cartservice-2+kpi_container_last_seen.csv
# paymentservice-1+kpi_container_spec_cpu_shares.csv
# paymentservice-0+kpi_container_spec_cpu_quota.csv
# paymentservice-2+kpi_container_cpu_user_seconds.csv
# adservice-2+kpi_container_cpu_load_average_10s.csv
# checkoutservice-2+kpi_container_spec_memory_swap_limit_MB.csv
# emailservice2-0+kpi_container_sockets.csv
# paymentservice-2+kpi_container_network_transmit_errors.csv
# cartservice-2+kpi_container_memory_failcnt.csv
# checkoutservice2-0+kpi_container_fs_reads_MB.csv
# currencyservice-1+kpi_container_file_descriptors.csv
# productcatalogservice-2+kpi_container_sockets.csv
# productcatalogservice2-0+kpi_container_memory_cache.csv
# cartservice-2+kpi_container_memory_usage_MB.csv
# currencyservice-1+kpi_container_fs_io_time_weighted_seconds.csv
# paymentservice-1+kpi_container_network_transmit_packets_dropped.csv
# checkoutservice2-0+kpi_container_cpu_cfs_throttled_periods.csv
# emailservice-1+kpi_container_ulimits_soft.csv
# productcatalogservice-0+kpi_container_fs_inodes.csv
# currencyservice2-0+kpi_container_fs_write_seconds.csv
# adservice-2+kpi_container_fs_usage_MB.csv
# recommendationservice-0+kpi_container_fs_usage_MB.csv
# productcatalogservice-1+kpi_container_network_receive_MB.csv
# frontend-0+kpi_container_file_descriptors.csv
# frontend-2+kpi_container_memory_cache.csv
# recommendationservice2-0+kpi_container_fs_write_seconds.csv
# emailservice2-0+kpi_container_fs_inodes_free.csv
# shippingservice-2+kpi_container_memory_working_set_MB.csv
# recommendationservice2-0+kpi_container_network_receive_packets_dropped.csv
# frontend-1+kpi_container_cpu_usage_seconds.csv
# adservice-1+kpi_container_memory_rss.csv
# currencyservice-0+kpi_container_cpu_usage_seconds.csv
# frontend-1+kpi_container_fs_usage_MB.csv
# recommendationservice-0+kpi_container_cpu_usage_seconds.csv
# recommendationservice-2+kpi_container_cpu_load_average_10s.csv
# cartservice-0+kpi_container_threads.csv
# recommendationservice-1+kpi_container_cpu_user_seconds.csv
# productcatalogservice2-0+kpi_container_tasks_state.csv
# currencyservice-2+kpi_container_fs_usage_MB.csv
# adservice-2+kpi_container_cpu_user_seconds.csv
# paymentservice-1+kpi_container_network_receive_packets.csv
# currencyservice-0+kpi_container_memory_cache.csv
# shippingservice-2+kpi_container_fs_writes_merged.csv
# shippingservice-1+kpi_container_threads.csv
# paymentservice2-0+kpi_container_ulimits_soft.csv
# emailservice-2+kpi_container_cpu_system_seconds.csv
# frontend-1+kpi_container_spec_memory_limit_MB.csv
# checkoutservice-1+kpi_container_network_receive_packets_dropped.csv
# paymentservice-0+kpi_container_memory_failures.csv
# adservice-1+kpi_container_fs_writes.csv
# cartservice-0+kpi_container_memory_max_usage_MB.csv
# productcatalogservice-1+kpi_container_cpu_user_seconds.csv
# shippingservice-1+kpi_container_tasks_state.csv
# emailservice-1+kpi_container_fs_sector_reads.csv
# productcatalogservice-0+kpi_container_spec_memory_reservation_limit_MB.csv
# currencyservice-2+kpi_container_spec_cpu_shares.csv
# currencyservice-0+kpi_container_fs_io_time_seconds.csv
# currencyservice-1+kpi_container_ulimits_soft.csv
# productcatalogservice-1+kpi_container_fs_sector_writes.csv
# adservice2-0+kpi_container_fs_read_seconds.csv
# emailservice-2+kpi_container_memory_failures.csv
# productcatalogservice2-0+kpi_container_fs_io_time_weighted_seconds.csv
# adservice-2+kpi_container_fs_sector_reads.csv
# shippingservice2-0+kpi_container_spec_memory_limit_MB.csv
# productcatalogservice-0+kpi_container_cpu_load_average_10s.csv
# checkoutservice-2+kpi_container_fs_writes.csv
# recommendationservice-1+kpi_container_fs_reads_merged.csv
# shippingservice-0+kpi_container_memory_swap.csv
# cartservice-2+kpi_container_cpu_usage_seconds.csv
# shippingservice-2+kpi_container_fs_io_time_seconds.csv
# productcatalogservice2-0+kpi_container_spec_cpu_shares.csv
# shippingservice-2+kpi_container_spec_cpu_period.csv
# paymentservice-1+kpi_container_fs_reads.csv
# productcatalogservice-0+kpi_container_fs_usage_MB.csv
# adservice-1+kpi_container_memory_failures.csv
# cartservice-1+kpi_container_memory_max_usage_MB.csv
# currencyservice-1+kpi_container_cpu_load_average_10s.csv
# frontend-2+kpi_container_fs_limit_MB.csv
# checkoutservice-2+kpi_container_fs_writes_merged.csv
# currencyservice2-0+kpi_container_memory_max_usage_MB.csv
# adservice-2+kpi_container_fs_sector_writes.csv
# shippingservice-2+kpi_container_cpu_cfs_periods.csv
# paymentservice2-0+kpi_container_network_receive_errors.csv
# adservice2-0+kpi_container_memory_max_usage_MB.csv
# checkoutservice-1+kpi_container_network_receive_errors.csv
# adservice-1+kpi_container_cpu_load_average_10s.csv
# recommendationservice-1+kpi_container_fs_sector_writes.csv
# currencyservice-1+kpi_container_fs_limit_MB.csv
# checkoutservice-1+kpi_container_memory_failures.csv
# currencyservice-1+kpi_container_memory_rss.csv
# paymentservice-1+kpi_container_network_receive_MB.csv
# checkoutservice2-0+kpi_container_ulimits_soft.csv
# recommendationservice2-0+kpi_container_spec_cpu_shares.csv
# checkoutservice-2+kpi_container_fs_sector_reads.csv
# cartservice2-0+kpi_container_network_transmit_MB.csv
# frontend2-0+kpi_container_fs_inodes_free.csv
# recommendationservice-1+kpi_container_memory_working_set_MB.csv
# cartservice2-0+kpi_container_fs_sector_reads.csv
# paymentservice-1+kpi_container_threads.csv
# adservice-0+kpi_container_memory_working_set_MB.csv
# cartservice2-0+kpi_container_fs_io_time_weighted_seconds.csv
# cartservice-1+kpi_container_spec_memory_swap_limit_MB.csv
# cartservice-2+kpi_container_memory_max_usage_MB.csv
# productcatalogservice-0+kpi_container_spec_memory_limit_MB.csv
# emailservice2-0+kpi_container_network_receive_errors.csv
# frontend2-0+kpi_container_memory_mapped_file.csv
# shippingservice2-0+kpi_container_cpu_load_average_10s.csv
# emailservice-0+kpi_container_network_receive_packets_dropped.csv
# emailservice-0+kpi_container_fs_io_time_weighted_seconds.csv
# recommendationservice-0+kpi_container_fs_write_seconds.csv
# currencyservice-1+kpi_container_network_receive_errors.csv
# shippingservice2-0+kpi_container_ulimits_soft.csv
# checkoutservice-2+kpi_container_memory_mapped_file.csv
# productcatalogservice-0+kpi_container_fs_writes_MB.csv
# paymentservice2-0+kpi_container_sockets.csv
# cartservice-2+kpi_container_fs_io_time_seconds.csv
# shippingservice-2+kpi_container_fs_reads_MB.csv
# currencyservice-0+kpi_container_fs_writes_merged.csv
# currencyservice-1+kpi_container_spec_memory_limit_MB.csv
# productcatalogservice-0+kpi_container_fs_io_time_weighted_seconds.csv
# adservice-1+kpi_container_spec_memory_limit_MB.csv
# adservice-2+kpi_container_last_seen.csv
# currencyservice2-0+kpi_container_memory_rss.csv
# recommendationservice-2+kpi_container_memory_usage_MB.csv
# productcatalogservice-0+kpi_container_fs_write_seconds.csv
# checkoutservice-2+kpi_container_start_time_seconds.csv
# emailservice-0+kpi_container_memory_working_set_MB.csv
# checkoutservice-0+kpi_container_memory_cache.csv
# frontend-1+kpi_container_fs_writes_merged.csv
# checkoutservice-1+kpi_container_fs_inodes.csv
# frontend2-0+kpi_container_start_time_seconds.csv
# cartservice-1+kpi_container_cpu_cfs_periods.csv
# paymentservice2-0+kpi_container_network_transmit_packets_dropped.csv
# checkoutservice-1+kpi_container_last_seen.csv
# checkoutservice2-0+kpi_container_file_descriptors.csv
# currencyservice-2+kpi_container_network_receive_packets_dropped.csv
# recommendationservice-2+kpi_container_spec_memory_limit_MB.csv
# cartservice-1+kpi_container_file_descriptors.csv
# productcatalogservice-0+kpi_container_fs_io_time_seconds.csv
# shippingservice-0+kpi_container_network_transmit_packets_dropped.csv
# recommendationservice2-0+kpi_container_network_receive_packets.csv
# adservice-2+kpi_container_fs_inodes.csv
# adservice-2+kpi_container_network_receive_MB.csv
# checkoutservice-1+kpi_container_ulimits_soft.csv
# adservice-2+kpi_container_fs_writes_MB.csv
# cartservice2-0+kpi_container_fs_writes.csv
# frontend-2+kpi_container_network_transmit_packets.csv
# productcatalogservice-0+kpi_container_spec_cpu_shares.csv
# emailservice-1+kpi_container_network_receive_packets.csv
# emailservice2-0+kpi_container_fs_reads_MB.csv
# frontend-1+kpi_container_cpu_load_average_10s.csv
# frontend2-0+kpi_container_memory_max_usage_MB.csv
# emailservice-2+kpi_container_network_receive_errors.csv
# cartservice-1+kpi_container_spec_cpu_period.csv
# paymentservice2-0+kpi_container_network_receive_MB.csv
# recommendationservice-2+kpi_container_network_transmit_packets_dropped.csv
# paymentservice-1+kpi_container_cpu_usage_seconds.csv
# adservice-0+kpi_container_network_transmit_MB.csv
# recommendationservice2-0+kpi_container_network_receive_MB.csv
# recommendationservice-1+kpi_container_memory_usage_MB.csv
# currencyservice-1+kpi_container_threads_max.csv
# shippingservice2-0+kpi_container_fs_read_seconds.csv
# currencyservice-2+kpi_container_threads.csv
# currencyservice-0+kpi_container_network_transmit_MB.csv
# cartservice-0+kpi_container_fs_writes_MB.csv
# cartservice-0+kpi_container_tasks_state.csv
# paymentservice-1+kpi_container_fs_io_current.csv
# shippingservice2-0+kpi_container_network_receive_MB.csv
# frontend-2+kpi_container_threads_max.csv
# shippingservice-0+kpi_container_memory_cache.csv
# cartservice2-0+kpi_container_network_receive_packets_dropped.csv
# productcatalogservice2-0+kpi_container_fs_inodes_free.csv
# checkoutservice-2+kpi_container_fs_reads_MB.csv
# checkoutservice-2+kpi_container_cpu_user_seconds.csv
# currencyservice-2+kpi_container_fs_io_time_weighted_seconds.csv
# shippingservice-2+kpi_container_fs_sector_writes.csv
# shippingservice-1+kpi_container_spec_memory_limit_MB.csv
# frontend2-0+kpi_container_tasks_state.csv
# paymentservice-0+kpi_container_fs_writes.csv
# frontend-1+kpi_container_network_transmit_packets_dropped.csv
# emailservice-2+kpi_container_fs_io_time_seconds.csv
# frontend-1+kpi_container_spec_memory_swap_limit_MB.csv
# paymentservice-0+kpi_container_spec_memory_limit_MB.csv
# recommendationservice2-0+kpi_container_spec_cpu_quota.csv
# emailservice-2+kpi_container_memory_max_usage_MB.csv
# cartservice-0+kpi_container_fs_io_current.csv
# frontend-0+kpi_container_memory_rss.csv
# cartservice2-0+kpi_container_memory_failures.csv
# productcatalogservice-0+kpi_container_spec_memory_swap_limit_MB.csv
# paymentservice-1+kpi_container_ulimits_soft.csv
# cartservice2-0+kpi_container_network_receive_packets.csv
# emailservice-2+kpi_container_cpu_usage_seconds.csv
# checkoutservice2-0+kpi_container_fs_read_seconds.csv
# adservice-0+kpi_container_cpu_cfs_throttled_periods.csv
# currencyservice-0+kpi_container_cpu_system_seconds.csv
# recommendationservice2-0+kpi_container_memory_failcnt.csv
# recommendationservice2-0+kpi_container_file_descriptors.csv
# currencyservice-1+kpi_container_memory_mapped_file.csv
# cartservice-2+kpi_container_spec_cpu_period.csv
# currencyservice2-0+kpi_container_memory_cache.csv
# frontend-0+kpi_container_fs_write_seconds.csv
# productcatalogservice-1+kpi_container_fs_writes_merged.csv
# currencyservice2-0+kpi_container_file_descriptors.csv
# paymentservice-0+kpi_container_memory_cache.csv
# shippingservice-2+kpi_container_cpu_user_seconds.csv
# checkoutservice-1+kpi_container_fs_io_current.csv
# emailservice-2+kpi_container_memory_swap.csv
# emailservice-1+kpi_container_memory_rss.csv
# shippingservice-2+kpi_container_cpu_system_seconds.csv
# recommendationservice-2+kpi_container_fs_writes.csv
# recommendationservice-2+kpi_container_memory_cache.csv
# adservice-1+kpi_container_network_transmit_MB.csv
# currencyservice-1+kpi_container_fs_write_seconds.csv
# currencyservice-1+kpi_container_network_transmit_MB.csv
# emailservice-0+kpi_container_fs_reads.csv
# checkoutservice-2+kpi_container_sockets.csv
# emailservice-0+kpi_container_sockets.csv
# shippingservice-1+kpi_container_ulimits_soft.csv
# checkoutservice-2+kpi_container_fs_sector_writes.csv
# paymentservice-2+kpi_container_memory_swap.csv
# recommendationservice-1+kpi_container_fs_writes_merged.csv
# currencyservice-1+kpi_container_start_time_seconds.csv
# recommendationservice-2+kpi_container_threads.csv
# adservice-2+kpi_container_fs_writes_merged.csv
# cartservice-1+kpi_container_memory_swap.csv
# cartservice-2+kpi_container_cpu_cfs_periods.csv
# frontend-0+kpi_container_spec_cpu_shares.csv
# recommendationservice2-0+kpi_container_fs_writes_MB.csv
# adservice-0+kpi_container_fs_reads_MB.csv
# recommendationservice-2+kpi_container_fs_reads_MB.csv
# frontend-0+kpi_container_fs_io_current.csv
# emailservice-0+kpi_container_memory_max_usage_MB.csv
# cartservice-1+kpi_container_memory_failcnt.csv
# shippingservice-0+kpi_container_spec_memory_swap_limit_MB.csv
# emailservice2-0+kpi_container_threads.csv
# paymentservice-0+kpi_container_fs_sector_reads.csv
# checkoutservice-1+kpi_container_tasks_state.csv
# recommendationservice-0+kpi_container_memory_swap.csv
# cartservice2-0+kpi_container_tasks_state.csv
# adservice-2+kpi_container_memory_swap.csv
# paymentservice2-0+kpi_container_fs_inodes.csv
# checkoutservice-1+kpi_container_spec_memory_swap_limit_MB.csv
# cartservice-2+kpi_container_cpu_system_seconds.csv
# paymentservice-0+kpi_container_fs_reads_MB.csv
# checkoutservice-0+kpi_container_cpu_usage_seconds.csv
# frontend-0+kpi_container_fs_writes_MB.csv
# checkoutservice-2+kpi_container_network_receive_packets.csv
# currencyservice-0+kpi_container_fs_sector_writes.csv
# adservice-0+kpi_container_cpu_cfs_throttled_seconds.csv
# frontend2-0+kpi_container_spec_cpu_shares.csv
# checkoutservice-1+kpi_container_memory_rss.csv
# emailservice-0+kpi_container_fs_reads_MB.csv
# frontend-1+kpi_container_fs_sector_writes.csv
# productcatalogservice-2+kpi_container_threads.csv
# cartservice2-0+kpi_container_network_transmit_packets_dropped.csv
# currencyservice-2+kpi_container_network_transmit_MB.csv
# adservice-2+kpi_container_network_transmit_MB.csv
# recommendationservice-1+kpi_container_fs_inodes.csv
# cartservice-0+kpi_container_fs_inodes_free.csv
# shippingservice-1+kpi_container_fs_io_current.csv
# frontend-1+kpi_container_network_transmit_packets.csv
# checkoutservice-2+kpi_container_memory_failures.csv
# recommendationservice-1+kpi_container_last_seen.csv
# frontend-1+kpi_container_cpu_user_seconds.csv
# checkoutservice-1+kpi_container_fs_sector_reads.csv
# cartservice-2+kpi_container_memory_rss.csv
# paymentservice-2+kpi_container_spec_memory_swap_limit_MB.csv
# currencyservice-0+kpi_container_cpu_user_seconds.csv
# productcatalogservice-0+kpi_container_cpu_system_seconds.csv
# checkoutservice-1+kpi_container_memory_working_set_MB.csv
# currencyservice2-0+kpi_container_fs_io_current.csv
# productcatalogservice-1+kpi_container_memory_mapped_file.csv
# paymentservice-2+kpi_container_network_receive_packets_dropped.csv
# shippingservice-1+kpi_container_cpu_cfs_periods.csv
# paymentservice-2+kpi_container_fs_inodes_free.csv
# cartservice-2+kpi_container_fs_io_time_weighted_seconds.csv
# emailservice-2+kpi_container_fs_writes_MB.csv
# emailservice-1+kpi_container_memory_max_usage_MB.csv
# shippingservice2-0+kpi_container_memory_max_usage_MB.csv
# recommendationservice-0+kpi_container_fs_read_seconds.csv
# adservice-1+kpi_container_fs_sector_reads.csv
# checkoutservice-0+kpi_container_network_transmit_errors.csv
# shippingservice-1+kpi_container_cpu_load_average_10s.csv
# recommendationservice-1+kpi_container_tasks_state.csv
# paymentservice-0+kpi_container_cpu_load_average_10s.csv
# recommendationservice-2+kpi_container_fs_reads_merged.csv
# adservice2-0+kpi_container_fs_reads_MB.csv
# checkoutservice-0+kpi_container_memory_swap.csv
# adservice-2+kpi_container_memory_failures.csv
# shippingservice-1+kpi_container_spec_cpu_period.csv
# emailservice-2+kpi_container_fs_sector_reads.csv
# currencyservice-1+kpi_container_spec_cpu_shares.csv
# cartservice-1+kpi_container_spec_cpu_quota.csv
# cartservice-2+kpi_container_network_transmit_packets_dropped.csv
# recommendationservice-1+kpi_container_fs_io_time_weighted_seconds.csv
# productcatalogservice-1+kpi_container_start_time_seconds.csv
# paymentservice2-0+kpi_container_last_seen.csv
# emailservice-1+kpi_container_memory_failures.csv
# recommendationservice-0+kpi_container_cpu_cfs_throttled_seconds.csv
# currencyservice-0+kpi_container_memory_failures.csv
# shippingservice2-0+kpi_container_fs_writes_merged.csv
# paymentservice-1+kpi_container_threads_max.csv
# currencyservice2-0+kpi_container_memory_failures.csv
# frontend-0+kpi_container_tasks_state.csv
# adservice2-0+kpi_container_fs_io_time_seconds.csv
# checkoutservice-1+kpi_container_network_transmit_packets_dropped.csv
# currencyservice2-0+kpi_container_fs_io_time_seconds.csv
# emailservice-0+kpi_container_spec_cpu_shares.csv
# productcatalogservice-0+kpi_container_file_descriptors.csv
# cartservice-2+kpi_container_threads_max.csv
# recommendationservice-2+kpi_container_cpu_system_seconds.csv
# recommendationservice-2+kpi_container_spec_cpu_period.csv
# shippingservice-1+kpi_container_fs_reads_merged.csv
# cartservice2-0+kpi_container_memory_failcnt.csv
# frontend-0+kpi_container_fs_io_time_weighted_seconds.csv
# cartservice2-0+kpi_container_fs_writes_MB.csv
# paymentservice-0+kpi_container_fs_reads.csv
# productcatalogservice2-0+kpi_container_spec_memory_reservation_limit_MB.csv
# productcatalogservice-0+kpi_container_memory_swap.csv
# emailservice-2+kpi_container_cpu_user_seconds.csv
# productcatalogservice-1+kpi_container_network_transmit_packets.csv
# recommendationservice-2+kpi_container_cpu_cfs_periods.csv
# shippingservice-0+kpi_container_fs_usage_MB.csv
# recommendationservice-0+kpi_container_file_descriptors.csv
# productcatalogservice-2+kpi_container_network_transmit_packets_dropped.csv
# emailservice-1+kpi_container_threads_max.csv
# productcatalogservice-2+kpi_container_memory_max_usage_MB.csv
# checkoutservice-0+kpi_container_memory_working_set_MB.csv
# checkoutservice-2+kpi_container_network_receive_errors.csv
# paymentservice2-0+kpi_container_fs_reads_MB.csv
# shippingservice-2+kpi_container_cpu_load_average_10s.csv
# shippingservice-0+kpi_container_network_receive_errors.csv
# productcatalogservice-1+kpi_container_tasks_state.csv
# cartservice2-0+kpi_container_spec_memory_swap_limit_MB.csv
# currencyservice-0+kpi_container_network_transmit_packets.csv
# cartservice-0+kpi_container_sockets.csv
# shippingservice-0+kpi_container_memory_rss.csv
# paymentservice-1+kpi_container_memory_mapped_file.csv
# emailservice2-0+kpi_container_cpu_cfs_throttled_seconds.csv
# cartservice-1+kpi_container_memory_usage_MB.csv
# paymentservice-0+kpi_container_cpu_system_seconds.csv
# emailservice-2+kpi_container_fs_sector_writes.csv
# frontend2-0+kpi_container_fs_writes_MB.csv
# shippingservice-2+kpi_container_network_receive_packets_dropped.csv
# adservice2-0+kpi_container_fs_inodes_free.csv
# recommendationservice-0+kpi_container_fs_io_current.csv
# currencyservice-2+kpi_container_memory_swap.csv
# checkoutservice-1+kpi_container_network_transmit_errors.csv
# cartservice2-0+kpi_container_spec_cpu_quota.csv
# shippingservice2-0+kpi_container_fs_reads_MB.csv
# shippingservice-0+kpi_container_fs_io_time_weighted_seconds.csv
# frontend2-0+kpi_container_spec_memory_swap_limit_MB.csv
# cartservice-1+kpi_container_fs_write_seconds.csv
# frontend-1+kpi_container_memory_swap.csv
# emailservice2-0+kpi_container_fs_read_seconds.csv
# checkoutservice2-0+kpi_container_fs_inodes_free.csv
# paymentservice-2+kpi_container_spec_cpu_shares.csv
# checkoutservice2-0+kpi_container_fs_write_seconds.csv
# shippingservice-1+kpi_container_sockets.csv
# currencyservice-2+kpi_container_fs_writes_MB.csv
# paymentservice-1+kpi_container_start_time_seconds.csv
# adservice-0+kpi_container_memory_cache.csv
# frontend-1+kpi_container_memory_failures.csv
# shippingservice-2+kpi_container_spec_memory_limit_MB.csv
# frontend-2+kpi_container_fs_sector_reads.csv
# recommendationservice-0+kpi_container_spec_memory_reservation_limit_MB.csv
# productcatalogservice-0+kpi_container_memory_max_usage_MB.csv
# adservice2-0+kpi_container_fs_sector_writes.csv
# frontend-2+kpi_container_cpu_system_seconds.csv
# cartservice-0+kpi_container_fs_sector_writes.csv
# currencyservice-0+kpi_container_fs_reads_MB.csv
# recommendationservice2-0+kpi_container_spec_memory_swap_limit_MB.csv
# frontend2-0+kpi_container_fs_io_current.csv
# adservice-0+kpi_container_fs_io_time_weighted_seconds.csv
# recommendationservice-0+kpi_container_network_receive_errors.csv
# shippingservice-0+kpi_container_fs_inodes.csv
# productcatalogservice-2+kpi_container_memory_failures.csv
# emailservice-1+kpi_container_network_transmit_packets_dropped.csv
# recommendationservice2-0+kpi_container_fs_reads.csv
# emailservice-1+kpi_container_network_receive_errors.csv
# shippingservice-2+kpi_container_spec_memory_reservation_limit_MB.csv
# productcatalogservice-1+kpi_container_fs_sector_reads.csv
# frontend2-0+kpi_container_network_receive_MB.csv
# emailservice2-0+kpi_container_cpu_cfs_throttled_periods.csv
# cartservice-0+kpi_container_fs_read_seconds.csv
# paymentservice-2+kpi_container_fs_writes_merged.csv
# cartservice-2+kpi_container_fs_reads_merged.csv
# checkoutservice-2+kpi_container_network_receive_MB.csv
# productcatalogservice-2+kpi_container_memory_cache.csv
# adservice2-0+kpi_container_spec_memory_reservation_limit_MB.csv
# productcatalogservice2-0+kpi_container_network_receive_packets_dropped.csv
# paymentservice2-0+kpi_container_threads.csv
# currencyservice-2+kpi_container_network_receive_errors.csv
# cartservice-2+kpi_container_spec_memory_swap_limit_MB.csv
# shippingservice-0+kpi_container_last_seen.csv
# adservice-2+kpi_container_start_time_seconds.csv
# productcatalogservice-1+kpi_container_memory_max_usage_MB.csv
# productcatalogservice-2+kpi_container_fs_reads_MB.csv
# paymentservice2-0+kpi_container_memory_mapped_file.csv
# paymentservice-1+kpi_container_sockets.csv
# currencyservice2-0+kpi_container_network_transmit_errors.csv
# cartservice-0+kpi_container_cpu_user_seconds.csv
# recommendationservice-0+kpi_container_cpu_cfs_throttled_periods.csv
# adservice2-0+kpi_container_cpu_user_seconds.csv
# adservice-1+kpi_container_ulimits_soft.csv
# checkoutservice-2+kpi_container_fs_writes_MB.csv
# adservice-1+kpi_container_threads_max.csv
# paymentservice2-0+kpi_container_start_time_seconds.csv
# adservice2-0+kpi_container_fs_io_current.csv
# adservice-2+kpi_container_memory_mapped_file.csv
# shippingservice-2+kpi_container_memory_usage_MB.csv
# checkoutservice-2+kpi_container_file_descriptors.csv
# shippingservice-0+kpi_container_network_transmit_errors.csv
# productcatalogservice2-0+kpi_container_fs_writes.csv
# paymentservice2-0+kpi_container_fs_limit_MB.csv
# productcatalogservice2-0+kpi_container_network_transmit_MB.csv
# shippingservice2-0+kpi_container_cpu_cfs_periods.csv
# cartservice-2+kpi_container_start_time_seconds.csv
# currencyservice2-0+kpi_container_threads_max.csv
# recommendationservice-0+kpi_container_sockets.csv
# frontend2-0+kpi_container_network_receive_packets_dropped.csv
# paymentservice2-0+kpi_container_memory_usage_MB.csv
# recommendationservice-1+kpi_container_spec_cpu_quota.csv
# emailservice-2+kpi_container_threads.csv
# adservice-0+kpi_container_fs_io_current.csv
# emailservice-1+kpi_container_cpu_usage_seconds.csv
# checkoutservice-0+kpi_container_threads.csv
# recommendationservice2-0+kpi_container_fs_sector_writes.csv
# productcatalogservice-1+kpi_container_spec_cpu_quota.csv
# recommendationservice-2+kpi_container_network_transmit_errors.csv
# frontend-1+kpi_container_fs_reads.csv
# cartservice-0+kpi_container_cpu_load_average_10s.csv
# shippingservice2-0+kpi_container_spec_cpu_period.csv
# frontend-2+kpi_container_ulimits_soft.csv
# adservice-0+kpi_container_fs_writes.csv
# shippingservice-0+kpi_container_memory_usage_MB.csv
# currencyservice-2+kpi_container_network_transmit_packets.csv
# emailservice-1+kpi_container_memory_cache.csv
# cartservice-1+kpi_container_network_transmit_packets_dropped.csv
# frontend2-0+kpi_container_fs_io_time_seconds.csv
# shippingservice-2+kpi_container_network_transmit_MB.csv
# currencyservice2-0+kpi_container_fs_sector_writes.csv
# recommendationservice-2+kpi_container_network_transmit_MB.csv
# checkoutservice-2+kpi_container_fs_io_time_seconds.csv
# productcatalogservice-0+kpi_container_network_transmit_errors.csv
# productcatalogservice2-0+kpi_container_ulimits_soft.csv
# cartservice-2+kpi_container_memory_mapped_file.csv
# currencyservice2-0+kpi_container_cpu_user_seconds.csv
# shippingservice-2+kpi_container_network_receive_packets.csv
# shippingservice-2+kpi_container_file_descriptors.csv
# adservice2-0+kpi_container_network_receive_packets.csv
# currencyservice2-0+kpi_container_spec_memory_reservation_limit_MB.csv
# recommendationservice-0+kpi_container_fs_inodes_free.csv
# productcatalogservice-1+kpi_container_memory_failcnt.csv
# checkoutservice2-0+kpi_container_cpu_cfs_periods.csv
# paymentservice-1+kpi_container_network_receive_packets_dropped.csv
# recommendationservice2-0+kpi_container_cpu_user_seconds.csv
# shippingservice2-0+kpi_container_fs_limit_MB.csv
# shippingservice-0+kpi_container_network_receive_packets_dropped.csv
# cartservice-1+kpi_container_cpu_cfs_throttled_seconds.csv
# paymentservice2-0+kpi_container_cpu_usage_seconds.csv
# productcatalogservice-0+kpi_container_start_time_seconds.csv
# emailservice-0+kpi_container_ulimits_soft.csv
# frontend-0+kpi_container_fs_sector_reads.csv
# paymentservice-0+kpi_container_spec_memory_reservation_limit_MB.csv
# recommendationservice-0+kpi_container_network_receive_packets.csv
# cartservice-2+kpi_container_fs_read_seconds.csv
# paymentservice-2+kpi_container_fs_write_seconds.csv
# checkoutservice2-0+kpi_container_spec_cpu_period.csv
# cartservice-0+kpi_container_fs_reads_merged.csv
# recommendationservice-1+kpi_container_memory_failcnt.csv
# productcatalogservice-0+kpi_container_fs_inodes_free.csv
# emailservice2-0+kpi_container_network_transmit_packets_dropped.csv
# productcatalogservice-0+kpi_container_memory_mapped_file.csv
# productcatalogservice-0+kpi_container_memory_failures.csv
# productcatalogservice-1+kpi_container_cpu_system_seconds.csv
# productcatalogservice-2+kpi_container_network_receive_packets.csv
# currencyservice-0+kpi_container_sockets.csv
# checkoutservice2-0+kpi_container_threads_max.csv
# shippingservice-0+kpi_container_network_transmit_MB.csv
# cartservice-1+kpi_container_network_receive_errors.csv
# adservice-0+kpi_container_memory_failcnt.csv
# adservice2-0+kpi_container_network_receive_MB.csv
# recommendationservice-0+kpi_container_network_transmit_MB.csv
# frontend-1+kpi_container_sockets.csv
# cartservice-2+kpi_container_ulimits_soft.csv
# frontend2-0+kpi_container_fs_sector_reads.csv
# currencyservice2-0+kpi_container_network_receive_MB.csv
# frontend-0+kpi_container_spec_cpu_quota.csv
# currencyservice-0+kpi_container_network_transmit_packets_dropped.csv
# productcatalogservice-1+kpi_container_fs_usage_MB.csv
# shippingservice-1+kpi_container_memory_swap.csv
# paymentservice-0+kpi_container_spec_cpu_shares.csv
# emailservice-1+kpi_container_network_transmit_packets.csv
# cartservice-2+kpi_container_network_transmit_errors.csv
# recommendationservice-0+kpi_container_fs_io_time_weighted_seconds.csv
# emailservice2-0+kpi_container_fs_reads_merged.csv
# currencyservice-0+kpi_container_fs_limit_MB.csv
# checkoutservice2-0+kpi_container_fs_writes_merged.csv
# checkoutservice-0+kpi_container_fs_inodes.csv
# recommendationservice-1+kpi_container_fs_writes_MB.csv
# cartservice-1+kpi_container_fs_writes_merged.csv
# adservice-1+kpi_container_fs_inodes_free.csv
# ...
# productcatalogservice2-0+kpi_container_fs_read_seconds.csv
# cartservice2-0+kpi_container_cpu_system_seconds.csv
# recommendationservice-2+kpi_container_fs_sector_writes.csv
# checkoutservice-2+kpi_container_cpu_cfs_periods.csv
# frontend-0+kpi_container_spec_memory_swap_limit_MB.csv
# paymentservice-2+kpi_container_fs_reads_MB.csv
# currencyservice-2+kpi_container_fs_read_seconds.csv
# productcatalogservice2-0+kpi_container_memory_failcnt.csv
# currencyservice2-0+kpi_container_fs_reads_merged.csv
# currencyservice-0+kpi_container_memory_working_set_MB.csv
# emailservice-1+kpi_container_spec_cpu_period.csv
# currencyservice-2+kpi_container_spec_memory_swap_limit_MB.csv
# paymentservice-0+kpi_container_network_transmit_packets.csv
# cartservice-1+kpi_container_fs_reads_MB.csv
# adservice2-0+kpi_container_spec_cpu_shares.csv
# checkoutservice2-0+kpi_container_fs_inodes.csv
# currencyservice-0+kpi_container_fs_reads_merged.csv
# emailservice2-0+kpi_container_fs_write_seconds.csv
# recommendationservice-1+kpi_container_network_transmit_packets.csv
# emailservice-2+kpi_container_fs_reads_MB.csv
# checkoutservice-2+kpi_container_spec_cpu_period.csv
# adservice-1+kpi_container_network_receive_MB.csv
# productcatalogservice-2+kpi_container_fs_sector_writes.csv
# shippingservice2-0+kpi_container_fs_io_current.csv
# emailservice-1+kpi_container_cpu_cfs_periods.csv
# recommendationservice2-0+kpi_container_fs_read_seconds.csv
# frontend-1+kpi_container_memory_cache.csv
# emailservice-2+kpi_container_spec_memory_swap_limit_MB.csv
# emailservice-2+kpi_container_ulimits_soft.csv
# productcatalogservice2-0+kpi_container_file_descriptors.csv
# paymentservice-1+kpi_container_memory_rss.csv
# cartservice-1+kpi_container_network_transmit_errors.csv
# adservice-2+kpi_container_cpu_cfs_periods.csv
# cartservice-2+kpi_container_memory_working_set_MB.csv
# frontend-0+kpi_container_ulimits_soft.csv
# productcatalogservice-0+kpi_container_network_transmit_packets_dropped.csv
# checkoutservice-1+kpi_container_start_time_seconds.csv
# frontend-0+kpi_container_network_receive_MB.csv
# currencyservice2-0+kpi_container_fs_usage_MB.csv
# recommendationservice2-0+kpi_container_fs_inodes_free.csv
# frontend-0+kpi_container_threads.csv
# shippingservice-1+kpi_container_fs_writes_merged.csv
# productcatalogservice-1+kpi_container_memory_usage_MB.csv
# checkoutservice2-0+kpi_container_memory_working_set_MB.csv
# productcatalogservice-2+kpi_container_cpu_user_seconds.csv
# adservice-1+kpi_container_tasks_state.csv
# recommendationservice2-0+kpi_container_fs_limit_MB.csv
# checkoutservice-2+kpi_container_memory_swap.csv
# productcatalogservice2-0+kpi_container_spec_cpu_quota.csv
# checkoutservice-0+kpi_container_cpu_system_seconds.csv
# checkoutservice-1+kpi_container_memory_mapped_file.csv
# checkoutservice2-0+kpi_container_last_seen.csv
# cartservice-1+kpi_container_fs_io_time_seconds.csv
# frontend-2+kpi_container_memory_usage_MB.csv
# emailservice-0+kpi_container_file_descriptors.csv
# shippingservice-1+kpi_container_fs_writes.csv
# shippingservice2-0+kpi_container_fs_io_time_weighted_seconds.csv
# recommendationservice-2+kpi_container_cpu_user_seconds.csv
# frontend-1+kpi_container_memory_working_set_MB.csv
# adservice-1+kpi_container_cpu_cfs_throttled_periods.csv
# adservice-1+kpi_container_cpu_user_seconds.csv
# paymentservice-2+kpi_container_network_receive_MB.csv
# cartservice-2+kpi_container_tasks_state.csv
# shippingservice-1+kpi_container_fs_writes_MB.csv
# cartservice-1+kpi_container_memory_cache.csv
# frontend-0+kpi_container_threads_max.csv
# cartservice-1+kpi_container_fs_inodes_free.csv
# paymentservice2-0+kpi_container_network_transmit_errors.csv
# paymentservice-1+kpi_container_tasks_state.csv
# cartservice-2+kpi_container_network_transmit_packets.csv
# productcatalogservice2-0+kpi_container_network_receive_errors.csv
# emailservice2-0+kpi_container_last_seen.csv
# recommendationservice2-0+kpi_container_ulimits_soft.csv
# frontend-1+kpi_container_fs_reads_merged.csv
# adservice-1+kpi_container_cpu_cfs_throttled_seconds.csv
# shippingservice-2+kpi_container_fs_inodes.csv
# adservice2-0+kpi_container_memory_swap.csv
# checkoutservice-0+kpi_container_fs_reads_MB.csv
# adservice2-0+kpi_container_spec_memory_swap_limit_MB.csv
# currencyservice2-0+kpi_container_memory_working_set_MB.csv
# frontend-2+kpi_container_fs_io_current.csv
# cartservice-2+kpi_container_memory_failures.csv
# paymentservice-2+kpi_container_spec_cpu_quota.csv
# shippingservice-1+kpi_container_fs_io_time_seconds.csv
# checkoutservice-0+kpi_container_spec_memory_swap_limit_MB.csv
# cartservice-1+kpi_container_fs_sector_reads.csv
# shippingservice2-0+kpi_container_network_receive_errors.csv
# cartservice-2+kpi_container_file_descriptors.csv
# productcatalogservice-0+kpi_container_network_transmit_MB.csv
# productcatalogservice-0+kpi_container_fs_read_seconds.csv
# emailservice2-0+kpi_container_fs_io_time_seconds.csv
# currencyservice-1+kpi_container_threads.csv
# shippingservice-1+kpi_container_spec_memory_swap_limit_MB.csv
# cartservice-0+kpi_container_memory_failcnt.csv
# emailservice-1+kpi_container_tasks_state.csv
# productcatalogservice-2+kpi_container_fs_reads_merged.csv
# recommendationservice-1+kpi_container_network_transmit_errors.csv
# paymentservice2-0+kpi_container_spec_memory_reservation_limit_MB.csv
# recommendationservice-0+kpi_container_network_receive_MB.csv
# productcatalogservice-1+kpi_container_threads_max.csv
# cartservice-0+kpi_container_spec_cpu_quota.csv
# cartservice-0+kpi_container_network_receive_packets_dropped.csv
# checkoutservice2-0+kpi_container_fs_usage_MB.csv
# cartservice2-0+kpi_container_spec_cpu_period.csv
# frontend-2+kpi_container_fs_writes_merged.csv
# shippingservice-0+kpi_container_spec_memory_reservation_limit_MB.csv
# paymentservice-1+kpi_container_fs_writes_MB.csv
# shippingservice-1+kpi_container_network_receive_packets.csv
# emailservice-0+kpi_container_memory_mapped_file.csv
# paymentservice-2+kpi_container_memory_failcnt.csv
# shippingservice-1+kpi_container_cpu_usage_seconds.csv
# productcatalogservice-0+kpi_container_memory_working_set_MB.csv
# emailservice-1+kpi_container_cpu_system_seconds.csv
# emailservice-0+kpi_container_memory_swap.csv
# recommendationservice-1+kpi_container_threads.csv
# paymentservice2-0+kpi_container_fs_reads.csv
# productcatalogservice-1+kpi_container_network_receive_packets.csv
# emailservice2-0+kpi_container_fs_inodes.csv
# cartservice2-0+kpi_container_cpu_cfs_periods.csv
# productcatalogservice-1+kpi_container_network_transmit_MB.csv
# checkoutservice-1+kpi_container_sockets.csv
# shippingservice-2+kpi_container_last_seen.csv
# cartservice-0+kpi_container_ulimits_soft.csv
# shippingservice2-0+kpi_container_fs_writes.csv
# cartservice-2+kpi_container_fs_io_current.csv
# paymentservice-0+kpi_container_memory_swap.csv
# adservice-0+kpi_container_fs_write_seconds.csv
# emailservice-0+kpi_container_start_time_seconds.csv
# recommendationservice-2+kpi_container_spec_memory_reservation_limit_MB.csv
# adservice-2+kpi_container_fs_reads_MB.csv
# recommendationservice-0+kpi_container_fs_reads_MB.csv
# recommendationservice+kpi_container_cpu_user_seconds_total.csv
# emailservice+kpi_container_cpu_cfs_periods_total.csv
# checkoutservice+kpi_container_cpu_cfs_throttled_seconds_total.csv
# emailservice+kpi_container_memory_usage_bytes.csv
# frontend+kpi_container_spec_cpu_shares.csv
# cartservice+kpi_container_spec_cpu_shares.csv
# currencyservice+kpi_container_spec_cpu_period.csv
# paymentservice+kpi_container_memory_mapped_file.csv
# frontend+kpi_container_memory_rss.csv
# checkoutservice+kpi_container_cpu_load_average_10s.csv
# checkoutservice+kpi_container_spec_memory_limit_bytes.csv
# frontend+kpi_container_cpu_user_seconds_total.csv
# shippingservice+kpi_container_memory_rss.csv
# currencyservice+kpi_container_cpu_system_seconds_total.csv
# frontend+kpi_container_memory_working_set_bytes.csv
# shippingservice+kpi_container_cpu_usage_seconds_total.csv
# productcatalogservice+kpi_container_cpu_cfs_periods_total.csv
# recommendationservice+kpi_container_spec_cpu_shares.csv
# currencyservice+kpi_container_cpu_user_seconds_total.csv
# checkoutservice+kpi_container_cpu_system_seconds_total.csv
# checkoutservice+kpi_container_memory_usage_bytes.csv
# shippingservice+kpi_container_memory_usage_bytes.csv
# checkoutservice+kpi_container_memory_rss.csv
# recommendationservice+kpi_container_cpu_usage_seconds_total.csv
# checkoutservice+kpi_container_cpu_cfs_throttled_periods_total.csv
# emailservice+kpi_container_spec_cpu_quota.csv
# currencyservice+kpi_container_memory_working_set_bytes.csv
# frontend+kpi_container_cpu_system_seconds_total.csv
# checkoutservice+kpi_container_memory_working_set_bytes.csv
# emailservice+kpi_container_cpu_load_average_10s.csv
# checkoutservice+kpi_container_spec_cpu_period.csv
# paymentservice+kpi_container_spec_cpu_period.csv
# checkoutservice+kpi_container_spec_cpu_quota.csv
# paymentservice+kpi_container_memory_cache.csv
# currencyservice+kpi_container_spec_cpu_quota.csv
# shippingservice+kpi_container_spec_cpu_period.csv
# emailservice+kpi_container_cpu_usage_seconds_total.csv
# checkoutservice+kpi_container_cpu_cfs_periods_total.csv
# emailservice+kpi_container_spec_cpu_shares.csv
# productcatalogservice+kpi_container_cpu_cfs_throttled_periods_total.csv
# cartservice+kpi_container_cpu_system_seconds_total.csv
# frontend+kpi_container_cpu_load_average_10s.csv
# emailservice+kpi_container_memory_working_set_bytes.csv
# paymentservice+kpi_container_spec_cpu_quota.csv
# emailservice+kpi_container_cpu_cfs_throttled_seconds_total.csv
# emailservice+kpi_container_memory_rss.csv
# recommendationservice+kpi_container_cpu_load_average_10s.csv
# shippingservice+kpi_container_spec_cpu_quota.csv
# shippingservice+kpi_container_spec_memory_limit_bytes.csv
# recommendationservice+kpi_container_memory_cache.csv
# cartservice+kpi_container_cpu_load_average_10s.csv
# checkoutservice+kpi_container_cpu_usage_seconds_total.csv
# paymentservice+kpi_container_memory_rss.csv
# shippingservice+kpi_container_cpu_load_average_10s.csv
# paymentservice+kpi_container_cpu_system_seconds_total.csv
# shippingservice+kpi_container_cpu_user_seconds_total.csv
# emailservice+kpi_container_cpu_cfs_throttled_periods_total.csv
# checkoutservice+kpi_container_memory_mapped_file.csv
# frontend+kpi_container_memory_cache.csv
# productcatalogservice+kpi_container_spec_cpu_period.csv
# recommendationservice+kpi_container_spec_memory_limit_bytes.csv
# shippingservice+kpi_container_memory_mapped_file.csv
# productcatalogservice+kpi_container_cpu_cfs_throttled_seconds_total.csv
# paymentservice+kpi_container_memory_working_set_bytes.csv
# emailservice+kpi_container_memory_mapped_file.csv
# shippingservice+kpi_container_memory_cache.csv
# emailservice+kpi_container_cpu_system_seconds_total.csv
# paymentservice+kpi_container_memory_usage_bytes.csv
# cartservice+kpi_container_memory_working_set_bytes.csv
# emailservice+kpi_container_spec_memory_limit_bytes.csv
# cartservice+kpi_container_cpu_cfs_periods_total.csv
# cartservice+kpi_container_memory_usage_bytes.csv
# checkoutservice+kpi_container_memory_cache.csv
# productcatalogservice+kpi_container_spec_cpu_shares.csv
# recommendationservice+kpi_container_cpu_cfs_periods_total.csv
# shippingservice+kpi_container_cpu_cfs_periods_total.csv
# cartservice+kpi_container_spec_memory_limit_bytes.csv
# emailservice+kpi_container_memory_cache.csv
# currencyservice+kpi_container_memory_usage_bytes.csv
# paymentservice+kpi_container_cpu_user_seconds_total.csv
# paymentservice+kpi_container_cpu_usage_seconds_total.csv
# productcatalogservice+kpi_container_cpu_system_seconds_total.csv
# frontend+kpi_container_cpu_cfs_periods_total.csv
# checkoutservice+kpi_container_cpu_user_seconds_total.csv
# emailservice+kpi_container_spec_cpu_period.csv
# frontend+kpi_container_memory_mapped_file.csv
# frontend+kpi_container_spec_memory_limit_bytes.csv
# paymentservice+kpi_container_cpu_load_average_10s.csv
# recommendationservice+kpi_container_memory_usage_bytes.csv
# currencyservice+kpi_container_cpu_cfs_periods_total.csv
# productcatalogservice+kpi_container_memory_working_set_bytes.csv
# productcatalogservice+kpi_container_memory_usage_bytes.csv
# currencyservice+kpi_container_memory_rss.csv
# cartservice+kpi_container_memory_cache.csv
# currencyservice+kpi_container_spec_memory_limit_bytes.csv
# productcatalogservice+kpi_container_cpu_load_average_10s.csv
# frontend+kpi_container_spec_cpu_quota.csv
# productcatalogservice+kpi_container_memory_rss.csv
# recommendationservice+kpi_container_memory_rss.csv
# cartservice+kpi_container_cpu_user_seconds_total.csv
# currencyservice+kpi_container_cpu_load_average_10s.csv
# cartservice+kpi_container_spec_cpu_quota.csv
# productcatalogservice+kpi_container_spec_memory_limit_bytes.csv
# recommendationservice+kpi_container_cpu_system_seconds_total.csv
# productcatalogservice+kpi_container_spec_cpu_quota.csv
# cartservice+kpi_container_cpu_cfs_throttled_periods_total.csv
# shippingservice+kpi_container_cpu_system_seconds_total.csv
# cartservice+kpi_container_cpu_usage_seconds_total.csv
# frontend+kpi_container_memory_usage_bytes.csv
# shippingservice+kpi_container_cpu_cfs_throttled_seconds_total.csv
# paymentservice+kpi_container_cpu_cfs_throttled_periods_total.csv
# recommendationservice+kpi_container_cpu_cfs_throttled_periods_total.csv
# frontend+kpi_container_cpu_cfs_throttled_periods_total.csv
# paymentservice+kpi_container_spec_cpu_shares.csv
# recommendationservice+kpi_container_memory_mapped_file.csv
# productcatalogservice+kpi_container_memory_mapped_file.csv
# checkoutservice+kpi_container_spec_cpu_shares.csv
# currencyservice+kpi_container_cpu_cfs_throttled_seconds_total.csv
# shippingservice+kpi_container_spec_cpu_shares.csv
# paymentservice+kpi_container_spec_memory_limit_bytes.csv
# cartservice+kpi_container_memory_rss.csv
# recommendationservice+kpi_container_spec_cpu_quota.csv
# cartservice+kpi_container_cpu_cfs_throttled_seconds_total.csv
# currencyservice+kpi_container_spec_cpu_shares.csv
# cartservice+kpi_container_spec_cpu_period.csv
# currencyservice+kpi_container_memory_mapped_file.csv
# productcatalogservice+kpi_container_cpu_user_seconds_total.csv
# productcatalogservice+kpi_container_memory_cache.csv
# frontend+kpi_container_cpu_usage_seconds_total.csv
# frontend+kpi_container_spec_cpu_period.csv
# emailservice+kpi_container_cpu_user_seconds_total.csv
# currencyservice+kpi_container_cpu_usage_seconds_total.csv
# recommendationservice+kpi_container_memory_working_set_bytes.csv
# shippingservice+kpi_container_memory_working_set_bytes.csv
# cartservice+kpi_container_memory_mapped_file.csv
# productcatalogservice+kpi_container_cpu_usage_seconds_total.csv
# currencyservice+kpi_container_cpu_cfs_throttled_periods_total.csv
# paymentservice+kpi_container_cpu_cfs_periods_total.csv
# shippingservice+kpi_container_cpu_cfs_throttled_periods_total.csv
# currencyservice+kpi_container_memory_cache.csv
# frontend+kpi_container_cpu_cfs_throttled_seconds_total.csv
# recommendationservice+kpi_container_cpu_cfs_throttled_seconds_total.csv
# paymentservice+kpi_container_cpu_cfs_throttled_seconds_total.csv
# recommendationservice+kpi_container_spec_cpu_period.csv
# {'w1': 0.6, 'w2': 0.2, 'w3': 0.5, 'threshold': 0.4}
# {'w1': 0.6, 'w2': 0.2, 'w3': 0.5, 'threshold': 0.4}
# {'w1': 0.6, 'w2': 0.2, 'w3': 0.5, 'threshold': 0.4}
# {'w1': 0.6, 'w2': 0.2, 'w3': 0.5, 'threshold': 0.4}
# {'w1': 0.6, 'w2': 0.2, 'w3': 0.5, 'threshold': 0.4}
# {'w1': 0.6, 'w2': 0.2, 'w3': 0.5, 'threshold': 0.4}
# {'w1': 0.6, 'w2': 0.2, 'w3': 0.5, 'threshold': 0.4}
# {'w1': 0.6, 'w2': 0.2, 'w3': 0.5, 'threshold': 0.4}
# {'w1': 0.6, 'w2': 0.2, 'w3': 0.5, 'threshold': 0.4}
# {'w1': 0.6, 'w2': 0.2, 'w3': 0.5, 'threshold': 0.4}
# 9 Time used:  108.44981265068054
# Save successfully!
# 8 Time used:  281.62551617622375
# Save successfully!
# 7 Time used:  423.48187136650085
# Save successfully!
# 0 Time used:  540.233128786087
# Save successfully!
# process 0 ends.
# 6 Time used:  547.3991212844849
# Save successfully!
# 1 Time used:  650.5431776046753
# Save successfully!
# process 1 ends.
# 5 Time used:  689.4940865039825
# Save successfully!
# 2 Time used:  718.631876707077
# Save successfully!
# process 2 ends.
# 4 Time used:  778.6706085205078
# Save successfully!
# 3 Time used:  797.2775504589081
# Save successfully!
# process 3 ends.
# process 4 ends.
# process 5 ends.
# process 6 ends.
# process 7 ends.
# process 8 ends.
# process 9 ends.
